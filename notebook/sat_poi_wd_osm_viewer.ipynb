# %% [markdown]
# # 🗺️ SAT POI Viewer with WD + OSM
# This notebook loads POIs (e.g. toilets, water points) from Wikidata with optional OSM matches and renders them on a Folium map with filtering options.

# %%
import time
from datetime import datetime

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-07-24 19:14:39

# %%
import folium
import pandas as pd
from folium import FeatureGroup
from shapely.geometry import Point
from IPython.display import display

# Sample POIs (normally loaded via SPARQL)
data = [
    {"label": "Toilet WD", "lat": 59.75, "lon": 18.85, "source": "WD", "osm_url": None},
    {"label": "Toilet OSM", "lat": 59.752, "lon": 18.855, "source": "OSM", "osm_url": "https://www.openstreetmap.org/node/123"},
    {"label": "Water both", "lat": 59.76, "lon": 18.82, "source": "both", "osm_url": "https://www.openstreetmap.org/node/456"},
]
df = pd.DataFrame(data)

# %%
# Create map
m = folium.Map(location=[59.75, 18.85], zoom_start=13)

# Add groups
fg_wd = FeatureGroup(name="Wikidata")
fg_osm = FeatureGroup(name="OSM")
fg_both = FeatureGroup(name="WD + OSM")

# Add markers to appropriate group
for _, row in df.iterrows():
    marker = folium.Marker(
        [row["lat"], row["lon"]],
        popup=f"<b>{row['label']}</b><br>{row['osm_url'] or ''}",
        icon=folium.Icon(color="blue" if row["source"] == "WD" else "green" if row["source"] == "OSM" else "purple")
    )
    if row["source"] == "WD":
        marker.add_to(fg_wd)
    elif row["source"] == "OSM":
        marker.add_to(fg_osm)
    else:
        marker.add_to(fg_both)

# Add groups to map
fg_wd.add_to(m)
fg_osm.add_to(m)
fg_both.add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0637dd07ba1252b1a4d1cef7091509bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0637dd07ba1252b1a4d1cef7091509bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0637dd07ba1252b1a4d1cef7091509bd = L.map(
#                 &quot;map_0637dd07ba1252b1a4d1cef7091509bd&quot;,
#                 {
#                     center: [59.75, 18.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9e45e4c7f692c3e7f45952844df9ac2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9e45e4c7f692c3e7f45952844df9ac2.addTo(map_0637dd07ba1252b1a4d1cef7091509bd);
#
#
#             var feature_group_8084c364ad101d41d0956db21d23397b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9094f32bd08f12f5a335a00ebaa07b4f = L.marker(
#                 [59.75, 18.85],
#                 {
# }
#             ).addTo(feature_group_8084c364ad101d41d0956db21d23397b);
#
#
#             var icon_3e240b468d6c8c57fa2c353bf6ed5f19 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4a4df599b6d174f076f90ead8149ea4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_400b57a5035bf19dcf8c01a3953a65ad = $(`&lt;div id=&quot;html_400b57a5035bf19dcf8c01a3953a65ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toilet WD&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_4a4df599b6d174f076f90ead8149ea4e.setContent(html_400b57a5035bf19dcf8c01a3953a65ad);
#
#
#
#         marker_9094f32bd08f12f5a335a00ebaa07b4f.bindPopup(popup_4a4df599b6d174f076f90ead8149ea4e)
#         ;
#
#
#
#
#                 marker_9094f32bd08f12f5a335a00ebaa07b4f.setIcon(icon_3e240b468d6c8c57fa2c353bf6ed5f19);
#
#
#             feature_group_8084c364ad101d41d0956db21d23397b.addTo(map_0637dd07ba1252b1a4d1cef7091509bd);
#
#
#             var feature_group_176e229102be7e93b63ac6e50ffa450b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_aacbd7888ac4177bc6d18905f3d4e635 = L.marker(
#                 [59.752, 18.855],
#                 {
# }
#             ).addTo(feature_group_176e229102be7e93b63ac6e50ffa450b);
#
#
#             var icon_89ddde4ebd20b10d5e055706aaff5cb1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3f604f9922fc1f0bb8cd719a8ac3d6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04872967b5b26f08120eceb4a54527e5 = $(`&lt;div id=&quot;html_04872967b5b26f08120eceb4a54527e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toilet OSM&lt;/b&gt;&lt;br&gt;https://www.openstreetmap.org/node/123&lt;/div&gt;`)[0];
#                 popup_a3f604f9922fc1f0bb8cd719a8ac3d6f.setContent(html_04872967b5b26f08120eceb4a54527e5);
#
#
#
#         marker_aacbd7888ac4177bc6d18905f3d4e635.bindPopup(popup_a3f604f9922fc1f0bb8cd719a8ac3d6f)
#         ;
#
#
#
#
#                 marker_aacbd7888ac4177bc6d18905f3d4e635.setIcon(icon_89ddde4ebd20b10d5e055706aaff5cb1);
#
#
#             feature_group_176e229102be7e93b63ac6e50ffa450b.addTo(map_0637dd07ba1252b1a4d1cef7091509bd);
#
#
#             var feature_group_b75614e66351b7e5948311a198ec1c16 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_160925506180e8c66b815bb242b25e2f = L.marker(
#                 [59.76, 18.82],
#                 {
# }
#             ).addTo(feature_group_b75614e66351b7e5948311a198ec1c16);
#
#
#             var icon_5141d18bc9525006a4de12b11c64718b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_621bfff480ee950faebe0f8b44a

# %%
# End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print("Total time elapsed: {:.2f} seconds".format(elapsed_time))
# Out:
# Date: 2025-07-24 19:14:40
# Total time elapsed: 0.70 seconds
