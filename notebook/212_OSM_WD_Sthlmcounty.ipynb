# %% [markdown]
# # 212 check links
# * [#212](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/212)

# %%
import requests
import pandas as pd

# 1. Load your list of länsstyrelsen.se links
with open("lansstyrelsen_se_links.txt") as f:
    links = [line.strip() for line in f if line.strip()]

links_df = pd.DataFrame({"url": links})

# %%
links_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     367 non-null    object
# dtypes: object(1)
# memory usage: 3.0+ KB

# %%
import requests
import pandas as pd

# 1. Load your list of länsstyrelsen.se links
print("Step 1: Loading länsstyrelsen.se links...")
with open("lansstyrelsen_se_links.txt") as f:
    links = [line.strip() for line in f if line.strip()]

links_df = pd.DataFrame({"url": links})
print(f"  Loaded {len(links_df)} links from file")

# 2. Query Wikidata
print("Step 2: Querying Wikidata for nature reserves in Stockholms län...")
sparql = """
SELECT ?item ?itemLabel ?ref ?osm_rel ?osm_way WHERE {
  # ?item wdt:P31 wd:Q179049;
        (wdt:P131/wdt:P131) wd:Q104231;
        wdt:P856 ?ref.
  OPTIONAL { ?item wdt:P402 ?osm_rel. }   # OSM relation ID
  OPTIONAL { ?item wdt:P10689 ?osm_way. } # OSM way ID
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
"""

url = "https://query.wikidata.org/sparql"
r = requests.get(url, params={'query': sparql, 'format': 'json'})
data = r.json()

rows = []
for b in data["results"]["bindings"]:
    rows.append({
        "item": b["item"]["value"],
        "label": b.get("itemLabel", {}).get("value", ""),
        "ref": b.get("ref", {}).get("value", ""),
        "osm_rel": b.get("osm_rel", {}).get("value", None),
        "osm_way": b.get("osm_way", {}).get("value", None)
    })

wd_df = pd.DataFrame(rows)
print(f"  Retrieved {len(wd_df)} reserves from Wikidata")

# 3. Merge Wikidata results with länsstyrelsen list
print("Step 3: Merging Wikidata results with länsstyrelsen links...")
merged = links_df.merge(wd_df, left_on="url", right_on="ref", how="left")
merged["in_wikidata"] = merged["item"].notna()
print(f"  {merged['in_wikidata'].sum()} links found in Wikidata, {len(merged) - merged['in_wikidata'].sum()} missing")

# 4. For those with OSM references, query Overpass
print("Step 4: Checking OSM backlinks with Overpass API...")
overpass_url = "https://overpass-api.de/api/interpreter"

def check_osm(osm_id, osm_type="relation"):
    """
    osm_type: "relation" or "way"
    """
    if osm_id is None:
        return None, None
    
    q = f"""
    [out:json][timeout:25];
    {osm_type}({osm_id});
    out tags;
    """
    r = requests.get(overpass_url, params={'data': q})
    if r.status_code != 200:
        return None, None
    js = r.json()
    if "elements" not in js or len(js["elements"]) == 0:
        return None, None
    tags = js["elements"][0].get("tags", {})
    return tags.get("wikidata"), tags.get("website")

merged["osm_backlink_wd"] = None
merged["osm_backlink_site"] = None

for idx, row in merged.iterrows():
    if pd.notna(row["osm_rel"]):
        print(f"  Checking OSM relation {row['osm_rel']} ({row['label']})...")
        wd, site = check_osm(row["osm_rel"], "relation")
    elif pd.notna(row["osm_way"]):
        print(f"  Checking OSM way {row['osm_way']} ({row['label']})...")
        wd, site = check_osm(row["osm_way"], "way")
    else:
        wd, site = None, None
    
    merged.at[idx, "osm_backlink_wd"] = wd
    merged.at[idx, "osm_backlink_site"] = site

# 5. Consistency checks
merged["osm_ref_matches_wd"] = merged["osm_backlink_wd"] == merged["item"].str.replace("http://www.wikidata.org/entity/", "")
merged["osm_ref_matches_site"] = merged["osm_backlink_site"] == merged["url"]

print("Step 5: Finished cross-checks ✅")
print(merged[["url", "in_wikidata", "osm_rel", "osm_way", "osm_backlink_wd", "osm_backlink_site", "osm_ref_matches_wd", "osm_ref_matches_site"]].head(20))

# Save results
merged.to_csv("wikidata_osm_check.csv", index=False)
print("Results written to wikidata_osm_check.csv")
# Out:
# Step 1: Loading länsstyrelsen.se links...
#   Loaded 367 links from file
# Step 2: Querying Wikidata for nature reserves in Stockholms län...
#   Retrieved 190 reserves from Wikidata
# Step 3: Merging Wikidata results with länsstyrelsen links...
#   150 links found in Wikidata, 222 missing
# Step 4: Checking OSM backlinks with Overpass API...
#   Checking OSM relation 1381602 (Abborrträsks naturreservat)...
#   Checking OSM relation 2651046 (Alby naturreservat)...
#   Checking OSM way 103228501 (Angarnssjöängens naturreservat)...
#   Checking OSM relation 10626317 (Angödrommens naturreservat)...
#   Checking OSM relation 1463750 (Arholma-Idö naturreservat)...
#   Checking OSM way 103224764 (Arsläjans naturreservat)...
#   Checking OSM way 103249546 (Askarehage naturreservat)...
#   Checking OSM relation 9769162 (Aspdalssjön)...
#   Checking OSM relation 18265864 (Barnens Ö naturreservat)...
#   Checking OSM relation 10626309 (Biskopsö naturreservat)...
#   Checking OSM way 103225890 (Björinge)...
#   Checking OSM relation 1463772 (Björkby-Kyrkvikens naturreservat)...
#   Checking OSM relation 1463778 (Björksättrahalvöns naturreservat)...
#   Checking OSM relation 1463786 (Björnö naturreservat)...
#   Checking OSM relation 1464357 (Bonaviks naturreservat)...
#   Checking OSM relation 1463757 (Bornsjöns naturreservat)...
#   Checking OSM relation 1463757 (Bornsjöns naturreservat)...
#   Checking OSM relation 1463757 (Bornsjöns naturreservat)...
#   Checking OSM relation 9367179 (Boskapsön naturreservat)...
#   Checking OSM way 103223724 (Brinkbäcken)...
#   Checking OSM relation 12865306 (Bullerskärs naturreservat)...
#   Checking OSM relation 10626306 (Bullerö naturreservat)...
#   Checking OSM relation 10626959 (Djurgård)...
#   Checking OSM way 103227702 (Dyviks naturreservat)...
#   Checking OSM relation 10626315 (Dävelsöfjärdens naturreservat)...
#   Checking OSM relation 10626958 (Eldgarnsö naturreservat)...
#   Checking OSM relation 8521592 (Fifångs naturreservat)...
#   Checking OSM relation 1463800 (Finnhamns naturreservat)...
#   Checking OSM relation 1463788 (Fjärdlångs naturreservat)...
#   Checking OSM relation 10631432 (Flemingsbergsskogens naturreservat)...
#   Checking OSM way 103224343 (Furusundsfjärdens naturreservat)...
#   Checking OSM relation 13929199 (Fårholmen)...
#   Checking OSM relation 10631433 (Gladöskogens naturreservat)...
#   Checking OSM way 103224703 (Granholmen naturreservat)...
#   Checking OSM relation 1463789 (Grinda naturreservat)...
#   Checking OSM way 103225642 (Gymmerholmen naturreservat)...
#   Checking OSM relation 1463746 (Gålö naturreservat)...
#   Checking OSM relation 8723574 (Gällnö naturreservat)...
#   Checking OSM relation 10626461 (Gälnans naturreservat)...
#   Checking OSM relation 9344353 (Gärdesuddens naturreservat)...
#   Checking OSM relation 1463764 (Gömmarens naturreservat)...
#   Checking OSM way 209686481 (Gömsta ängs naturreservat)...
#   Checking OSM relation 1463802 (Hallonstenarnas naturreservat)...
#   Checking OSM relation 10626052 (Hallskärets naturreservat)...
#   Checking OSM relation 10626460 (Halsfambakens naturreservat)...
#   Checking OSM relation 11901220 (Hamnskogen-Eriksberg naturreservat)...
#   Checking OSM relation 1463749 (Hjälmö-Lådna naturreservat)...
#   Checking OSM relation 1463779 (Huvudskär)...
#   Checking OSM relation 9348944 (Huvudholmens naturreservat)...
#   Checking OSM relation 1463765 (Hälsingholmarna naturreservat)...
#   Checking OSM relation 10626313 (Hästholmen naturreservat)...
#   Checking OSM way 103228133 (Häverö prästängs naturreservat)...
#   Checking OSM relation 1463774 (Jungfruskärs naturreservat)...
#   Checking OSM relation 1463796 (Järflotta naturreservat)...
#   Checking OSM relation 8723575 (Karklö naturreservat)...
#   Checking OSM relation 15425988 (Korshamns naturreservat)...
#   Checking OSM relation 10626049 (Kudoxa naturreservat)...
#   Checking OSM relation 8537591 (Kullö naturreservat)...
#   Checking OSM way 1154068359 (Kursöskogen Södra naturreservat)...
#   Checking OSM relation 10626459 (Kålgårdsöns naturreservat)...
#   Checking OSM relation 9348947 (Mörtö-Bunsö naturreservat)...
#   Checking OSM relation 1463795 (Käringboda naturreservat)...
#   Checking OSM relation 10631429 (Lida naturreservat)...
#   Checking OSM relation 1463761 (Lidö naturreservat)...
#   Checking OSM relation 10626305 (Lilla Husarns naturreservat)...
#   Checking OSM relation 8467810 (Lovö naturreservat)...
#   Checking OSM relation 10626307 (Långskärs naturreservat)...
#   Checking OSM relation 5823084 (Långviksskärs naturreservat)...
#   Checking OSM relation 10626048 (Marums naturreservat)...
#   Checking OSM way 1154068368 (Mjölnarkärrskogens naturreservat)...
#   Checking OSM way 103224309 (Munkö naturreservat)...
#   Checking OSM relation 8718929 (Möja Björndalen naturreservat)...
#   Checking OSM relation 10627924 (Norra Törnskogens naturreservat)...
#   Checking OSM way 103226306 (Norrholmens naturreservat)...
#   Checking OSM relation 10626047 (Norrpada naturreservat)...
#   Checking OSM relation 1463792 (Nåttarö naturreservat)...
#   Checking OSM relation 1463777 (Nämdö naturreservat)...
#   Checking OSM way 103249601 (Näsuddens naturreservat)...
#   Checking OSM relation 1463797 (Orlångens naturreservat)...
#   Checking OSM way 103223586 (Oxnäsets naturreservat)...
#   Checking OSM relation 1463782 (Paradisets naturreservat)...
#   Checking OSM relation 1463762 (Revskärs natur reservat)...
#   Checking OSM relation 1463752 (Riddersholms naturreservat)...
#   Checking OSM relation 10626565 (Rudans naturreservat)...
#   Checking OSM relation 13011640 (Råstasjöns naturreservat)...
#   Checking OSM way 103224118 (Rönninge by-Skavlötens naturreservat)...
#   Checking OSM way 103226455 (Rörviks naturreservat)...
#   Checking OSM relation 10519502 (Rösjöskogens naturreservat)...
#   Checking OSM way 103223949 (Salskärens naturreservat)...
#   Checking OSM relation 1463793 (Sandemars naturreservat)...
#   Checking OSM relation 1463798 (Sandholmarnas naturreservat)...
#   Checking OSM way 103228602 (Skansholmens naturreservat)...
#   Checking OSM relation 10626311 (Skogsskär-Vindalsö naturreservat)...
#   Checking OSM relation 1463747 (Skogsö naturreservat)...
#   Checking OSM relation 10626683 (Slätmossen - Borgberget)...
#   Checking OSM way 103227976 (Stavsudda-Tjägö naturreservat)...
#   Checking OSM way 103228399 (Stensholmens naturreservat)...
#   Checking OSM relation 7149246 (Stickelsbergs naturreservat)...
#   Checking OSM way 103226202 (Stora Envätterns naturreservat)...
#   Checking OSM relation 1463785 (Stora Nassa naturreservat)...
#   Checking OSM relation 10626045 (Stora Sunnkobben naturreservat)...
#   Checking OSM relation 10626318 (Stor-Kunnan naturreservat)...
#   Checking OSM way 103224006 (Storskärs naturreservat)...
#   Checking OSM relation 6182188 (Storängsudd naturreservat)...
#   Checking OSM way 103228650 (Storö naturreservat)...
#   Checking OSM relation 1463758 (Storö-Bockö-Lökaö naturreservat)...
#   Checking OSM way 103225003 (Stångskärs naturreservat)...
#   Checking OSM relation 1463756 (Sundby naturreservat)...
#   Checking OSM way 836005558 (Svartsjöns naturreservat)...
#   Checking OSM way 103223783 (Svenska Björns naturreservat)...
#   Checking OSM relation 13212844 (Svenska Högarna)...
#   Checking OSM relation 16033881 (Svärdsö naturreservat)...
#   Checking OSM relation 8494866 (Södra Törnskogens naturreservat)...
#   Checking OSM relation 6376975 (Tollare naturreservat)...
#   Checking OSM relation 1464356 (Tornberget)...
#   Checking OSM relation 1463744 (Tranviks naturreservat)...
#   Checking OSM relation 1463794 (Tullviksbäcken)...
#   Checking OSM relation 1463760 (Tyresta naturreservat)...
#   Checking OSM relation 1463760 (Tyresta naturreservat)...
#   Checking OSM way 793248665 (Täby prästgård naturreservat)...
#   Checking OSM relation 1463748 (Utö naturreservat)...
#   Checking OSM way 103226642 (Vattgruvsmossens naturreservat)...
#   Checking OSM relation 10626043 (Vidinge naturreservat)...
#   Checking OSM relation 10626054 (Vidingsöra naturreservat)...
#   Checking OSM way 103228738 (Villinge Boskapsö)...
#   Checking OSM relation 10626316 (Vindalsö naturreservat)...
#   Checking OSM relation 3820244 (Vinterskogens naturreservat)...
#   Checking OSM relation 10992515 (Vånsholmens naturreservat)...
#   Checking OSM relation 10627922 (Västra Järvafältets naturreservat)...
#   Checking OSM way 1331135983 (Ålandets naturreservat)...
#   Checking OSM relation 1463767 (Ålö-Rånö naturreservat)...
#   Checking OSM relation 1463780 (Äpplarö naturreservat)...
#   Checking OSM relation 8537631 (Öarna i Stora Värtan naturreservat)...
#   Checking OSM way 103228585 (Öja-Landsort Naturvårdsområde)...
#   Checking OSM relation 1463783 (Örens naturreservat)...
#   Checking OSM way 103227521 (Österby)...
#   Checking OSM relation 10627921 (Östra Järvafältets naturreservat)...
# Step 5: Finished cross-checks ✅
#                                                   url  in_wikidata   osm_rel  \
# 0   https://www.lansstyrelsen.se/stockholm/besoksm...         True   1381602
# 1   https://www.lansstyrelsen.se/stockholm/besoksm...        False       NaN
# 2   https://www.lansstyrelsen.se/stockholm/besoksm...         True   2651046
# 3   https://www.lansstyrelsen.se/stockholm/besoksm...         True      None
# 4   https://www.lansstyrelsen.se/stockholm/besoksm...         True  10626317
# 5   https://www.lansstyrelsen.se/stockholm/besoksm...         True   1463750
# 6   https://www.lansstyrelsen.se/stockholm/besoksm...         True      None
# 7   https://www.lansstyrelsen.se/stockholm/besoksm...         True      None
# 8   https://www.lansstyrelsen.se/stockholm/besoksm...         True   9769162
# 9   https://www.lansstyrelsen.se/stockholm/besoksm...         True  18265864
# 10  https://www.lansstyrelsen.se/stockholm/besoksm...         True      None
# 11  https://www.lansstyrelsen.se/stockholm/besoksm...         True  10626309
# 12  https://www.lansstyrelsen.se/stockholm/besoksm...         True      None
# 13  https://www.lansstyrelsen.se/stockholm/besoksm...         True   1463772
# 14  https://www.lansstyrelsen.se/stockholm/besoksm...         True   1463778
# 15  https://www.lansstyrelsen.se/stockholm/besoksm...        False       NaN
# 16  https://www.lansstyrelsen.se/stockholm/besoksm...        False       NaN
# 17  https://www.lansstyrelsen.se/stockholm/besoksm...         True   1463786
# 18  https://www.lansstyrelsen.se/stockholm/besoksm...        False       NaN
# 19  https://www.lansstyrelsen.se/stockholm/besoksm...        False       NaN
#
#       osm_way osm_backlink_wd  \
# 0        None       Q10397880
# 1         NaN            None
# 2        None       Q10404424
# 3   103228501       Q10411714
# 4        None       Q30162836
# 5        None       Q30165452
# 6   103224764       Q30199650
# 7   103249546       Q30159126
# 8        None       Q30161455
# 9        None       Q30164851
# 10       None            None
# 11       None       Q30161889
# 12  103225890       Q30160668
# 13       None       Q30161744
# 14       None       Q10430621
# 15        NaN            None
# 16        NaN            None
# 17       None       Q26196467
# 18        NaN            None
# 19        NaN            None
#
#                                     osm_backlink_site  osm_ref_matches_wd  \
# 0   https://www.nacka.se/boende-miljo/natur-och-pa...                True
# 1                                                None               False
# 2                                                None                True
# 3   https://www.lansstyrelsen.se/stockholm/besoksm...                True
# 4                                                None                True
# 5   https://www.lansstyrelsen.se/stockholm/besoksm...                True
# 6   https://www.lansstyrelsen.se/stockholm/besoksm...                True
# 7                                                None                True
# 8                                                None                True
# 9   https://www.lansstyrelsen.se/stockholm/besoksm...                True
# 10                                               None               False
# 11  https://www.lansstyrelsen.se/stockholm/besoksm...                True
# 12                                               None                True
# 13                                               None                True
# 14                                               None                True
# 15                                               None               False
# 16                                               None               False
# 17                                               None                True
# 18                                               None               False
# 19                                               None               False
#
#     osm_ref_matches_site
# 0                  False
# 1                  False
# 2                  False
# 3                   True
# 4                  False
# 5                   True
# 6                   True
# 7                  False
# 8                  False
# 9                   True
# 10                 False
# 11                  True
# 12                 False
# 13                 False
# 14                 False
# 15                 False
# 16                 False
# 17                 False
# 18                 False
# 19                 False
# Results written to wikidata_osm_check.csv

# %%
# 5. Check consistency
merged["osm_ref_matches_wd"] = merged["osm_backlink_wd"] == merged["item"].str.replace("http://www.wikidata.org/entity/", "")
merged["osm_ref_matches_site"] = merged["osm_backlink_site"] == merged["url"]

# %%
# 6. Save results
merged.to_csv("wikidata_osm_check.csv", index=False)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   372 non-null    object
#  1   item                  150 non-null    object
#  2   label                 150 non-null    object
#  3   ref                   150 non-null    object
#  4   osm_rel               102 non-null    object
#  5   osm_way               36 non-null     object
#  6   in_wikidata           372 non-null    bool
#  7   osm_backlink_wd       132 non-null    object
#  8   osm_backlink_site     53 non-null     object
#  9   osm_ref_matches_wd    372 non-null    bool
#  10  osm_ref_matches_site  372 non-null    bool
# dtypes: bool(3), object(8)
# memory usage: 24.5+ KB

# %%
# Add QID column for convenience
merged["qid"] = merged["item"].str.replace("http://www.wikidata.org/entity/", "", regex=False)

# --- 1. Wikidata TODOs ---
wikidata_todos = []

# Missing in Wikidata -> add new item or at least add P856
missing_wd = merged[~merged["in_wikidata"]]
for _, row in missing_wd.iterrows():
    wikidata_todos.append({
        "url": row["url"],
        "todo": f"❌ Not in Wikidata → Create item for naturreservat and add P856: {row['url']}"
    })

# In Wikidata but missing OSM reference
missing_osm = merged[merged["in_wikidata"] & merged["osm_rel"].isna() & merged["osm_way"].isna()]
for _, row in missing_osm.iterrows():
    wikidata_todos.append({
        "url": row["url"],
        "qid": row["qid"],
        "todo": f"⚠️ {row['qid']} missing OSM reference → add P402 or P10689"
    })

# --- 2. OSM TODOs ---
osm_todos = []

# Missing Wikidata backlink in OSM
bad_wd_backlink = merged[merged["in_wikidata"] & (merged["osm_backlink_wd"].isna() | ~merged["osm_ref_matches_wd"])]
for _, row in bad_wd_backlink.iterrows():
    osm_todos.append({
        "qid": row["qid"],
        "osm_rel": row["osm_rel"],
        "osm_way": row["osm_way"],
        "todo": f"🔗 Add/Correct wikidata={row['qid']} in OSM relation/way"
    })

# Missing website backlink in OSM
bad_site_backlink = merged[(merged["osm_backlink_site"].isna() | ~merged["osm_ref_matches_site"])]
for _, row in bad_site_backlink.iterrows():
    osm_todos.append({
        "qid": row.get("qid", None),
        "osm_rel": row["osm_rel"],
        "osm_way": row["osm_way"],
        "todo": f"🌐 Add/Correct website={row['url']} in OSM relation/way"
    })

# --- 3. Export TODOs ---
wikidata_todo_df = pd.DataFrame(wikidata_todos)
osm_todo_df = pd.DataFrame(osm_todos)

wikidata_todo_df.to_csv("wikidata_todo.csv", index=False)
osm_todo_df.to_csv("osm_todo.csv", index=False)

print("Wikidata TODOs:")
print(wikidata_todo_df.head(20))
print("\nOSM TODOs:")
print(osm_todo_df.head(20))
# Out:
# Wikidata TODOs:
#                                                   url  \
# 0   https://www.lansstyrelsen.se/stockholm/besoksm...
# 1   https://www.lansstyrelsen.se/stockholm/besoksm...
# 2   https://www.lansstyrelsen.se/stockholm/besoksm...
# 3   https://www.lansstyrelsen.se/stockholm/besoksm...
# 4   https://www.lansstyrelsen.se/stockholm/besoksm...
# 5   https://www.lansstyrelsen.se/stockholm/besoksm...
# 6   https://www.lansstyrelsen.se/stockholm/besoksm...
# 7   https://www.lansstyrelsen.se/stockholm/besoksm...
# 8   https://www.lansstyrelsen.se/stockholm/besoksm...
# 9   https://www.lansstyrelsen.se/stockholm/besoksm...
# 10  https://www.lansstyrelsen.se/stockholm/besoksm...
# 11  https://www.lansstyrelsen.se/stockholm/besoksm...
# 12  https://www.lansstyrelsen.se/stockholm/besoksm...
# 13  https://www.lansstyrelsen.se/stockholm/besoksm...
# 14  https://www.lansstyrelsen.se/stockholm/besoksm...
# 15  https://www.lansstyrelsen.se/stockholm/besoksm...
# 16  https://www.lansstyrelsen.se/stockholm/besoksm...
# 17  https://www.lansstyrelsen.se/stockholm/besoksm...
# 18  https://www.lansstyrelsen.se/stockholm/besoksm...
# 19  https://www.lansstyrelsen.se/stockholm/besoksm...
#
#                                                  todo  qid
# 0   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 1   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 2   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 3   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 4   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 5   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 6   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 7   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 8   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 9   ❌ Not in Wikidata → Create item for naturreser...  NaN
# 10  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 11  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 12  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 13  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 14  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 15  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 16  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 17  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 18  ❌ Not in Wikidata → Create item for naturreser...  NaN
# 19  ❌ Not in Wikidata → Create item for naturreser...  NaN
#
# OSM TODOs:
#            qid   osm_rel    osm_way  \
# 0    Q55693495      None       None
# 1    Q10435627      None  103223724
# 2    Q30163211  13929199       None
# 3    Q55693510      None       None
# 4    Q30176892      None       None
# 5    Q29580017      None       None
# 6    Q30172530      None       None
# 7    Q29580026      None  103228133
# 8    Q30158662      None       None
# 9    Q30165417      None       None
# 10   Q91870846      None       None
# 11   Q10572699   5823084       None
# 12   Q30158607      None       None
# 13  Q134587569   1463792       None
# 14   Q91914178      None       None
# 15   Q10669326      None       None
# 16   Q10669326      None       None
# 17  Q121433503      None       None
# 18   Q30160002      None  793248665
# 19   Q10397880   1381602       None
#
#                                                  todo
# 0   🔗 Add/Correct wikidata=Q55693495 in OSM relati...
# 1   🔗 Add/Correct wikidata=Q10435627 in OSM relati...
# 2   🔗 Add/Correct wikidata=Q30163211 in OSM relati...
# 3   🔗 Add/Correct wikidata=Q55693510 in OSM relati...
# 4   🔗 Add/Correct wikidata=Q30176892 in OSM relati...
# 5   🔗 Add/Correct wikidata=Q29580017 in OSM relati...
# 6   🔗 Add/Correct wikidata=Q30172530 in OSM relati...
# 7   🔗 Add/Correct wikidata=Q29580026 in OSM relati...
# 8   🔗 Add/Correct wikidata=Q30158662 in OSM relati...
# 9   🔗 Add/Correct wikidata=Q30165417 in OSM relati...
# 10  🔗 Add/Correct wikidata=Q91870846 in OSM relati...
# 11  🔗 Add/Correct wikidata=Q10572699 in OSM relati...
# 12  🔗 Add/Correct wikidata=Q30158607 in OSM relati...
# 13  🔗 Add/Correct wikidata=Q134587569 in OSM relat...
# 14  🔗 Add/Correct wikidata=Q91914178 in OSM relati...
# 15  🔗 Add/Correct wikidata=Q10669326 in OSM relati...
# 16  🔗 Add/Correct wikidata=Q10669326 in OSM relati...
# 17  🔗 Add/Correct wikidata=Q121433503 in OSM relat...
# 18  🔗 Add/Correct wikidata=Q30160002 in OSM relati...
# 19  🌐 Add/Correct website=https://www.lansstyrelse...

# %%
# Add QuickStatements column for Wikidata fixes
def make_qs(row):
    if pd.isna(row["qid"]):  
        # Item missing entirely → can’t build QS (needs new item creation)
        return f'CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nLAST|P856|"{row["url"]}"'
    else:
        # Item exists, just add missing website
        return f'{row["qid"]}|P856|"{row["url"]}"'

wikidata_todos = []

# Case 1: Missing in Wikidata
missing_wd = merged[~merged["in_wikidata"]]
for _, row in missing_wd.iterrows():
    wikidata_todos.append({
        "url": row["url"],
        "qid": None,
        "todo": f"❌ Not in Wikidata → Create item",
        "quickstatement": make_qs(row)
    })

# Case 2: In Wikidata but missing OSM ref
missing_osm = merged[merged["in_wikidata"] & merged["osm_rel"].isna() & merged["osm_way"].isna()]
for _, row in missing_osm.iterrows():
    wikidata_todos.append({
        "url": row["url"],
        "qid": row["qid"],
        "todo": f"⚠️ Missing OSM reference → add P402/P10689",
        "quickstatement": None  # QS not possible automatically
    })

wikidata_todo_df = pd.DataFrame(wikidata_todos)
wikidata_todo_df.to_csv("wikidata_todo.csv", index=False)

print("Wikidata TODOs with QuickStatements:")
print(wikidata_todo_df.head(20))
# Out:
# Wikidata TODOs with QuickStatements:
#                                                   url   qid  \
# 0   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 1   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 2   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 3   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 4   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 5   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 6   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 7   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 8   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 9   https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 10  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 11  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 12  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 13  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 14  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 15  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 16  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 17  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 18  https://www.lansstyrelsen.se/stockholm/besoksm...  None
# 19  https://www.lansstyrelsen.se/stockholm/besoksm...  None
#
#                                todo  \
# 0   ❌ Not in Wikidata → Create item
# 1   ❌ Not in Wikidata → Create item
# 2   ❌ Not in Wikidata → Create item
# 3   ❌ Not in Wikidata → Create item
# 4   ❌ Not in Wikidata → Create item
# 5   ❌ Not in Wikidata → Create item
# 6   ❌ Not in Wikidata → Create item
# 7   ❌ Not in Wikidata → Create item
# 8   ❌ Not in Wikidata → Create item
# 9   ❌ Not in Wikidata → Create item
# 10  ❌ Not in Wikidata → Create item
# 11  ❌ Not in Wikidata → Create item
# 12  ❌ Not in Wikidata → Create item
# 13  ❌ Not in Wikidata → Create item
# 14  ❌ Not in Wikidata → Create item
# 15  ❌ Not in Wikidata → Create item
# 16  ❌ Not in Wikidata → Create item
# 17  ❌ Not in Wikidata → Create item
# 18  ❌ Not in Wikidata → Create item
# 19  ❌ Not in Wikidata → Create item
#
#                                        quickstatement
# 0   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 1   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 2   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 3   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 4   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 5   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 6   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 7   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 8   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 9   CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 10  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 11  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 12  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 13  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 14  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 15  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 16  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 17  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 18  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
# 19  CREATE\nLAST|P31|Q179049\nLAST|P131|Q104231\nL...
