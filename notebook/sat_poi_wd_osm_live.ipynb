# %% [markdown]
# # 🗺️ SAT POI Viewer with WD + OSM
# This notebook loads POIs (e.g. toilets, water points) from Wikidata with optional OSM matches and renders them on a Folium map with filtering options.

# %%
import time
from datetime import datetime

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-07-24 19:14:44

# %%
import pandas as pd

# %%
# Run a live SPARQL query to get SAT POIs with optional OSM links
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"
query = """
SELECT ?item ?itemLabel ?coord ?OSMnode ?OSMway ?OSMrel WHERE {
  # ?item wdt:P6104 wd:Q134294510; wdt:P625 ?coord.
  OPTIONAL { ?item wdt:P10689 ?OSMway. }
  OPTIONAL { ?item wdt:P402 ?OSMrel. }
  OPTIONAL { ?item wdt:P11693 ?OSMnode. }
  SERVICE wikibase:label { bd:serviceParam wikibase:language 'sv,en'. }
}
"""

sparql = SPARQLWrapper(endpoint_url)
sparql.setQuery(query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

import re

data = []
for res in results["results"]["bindings"]:
    label = res["itemLabel"]["value"]
    coord = res["coord"]["value"]  # e.g. Point(18.858 59.756)
    lon, lat = map(float, re.findall(r"[-+]?\d+\.\d+", coord))
    node = res.get("OSMnode", {}).get("value")
    way = res.get("OSMway", {}).get("value")
    rel = res.get("OSMrel", {}).get("value")

    if node:
        source = "OSM"
        osm_url = f"https://www.openstreetmap.org/node/{node}"
    elif way:
        source = "OSM"
        osm_url = f"https://www.openstreetmap.org/way/{way}"
    elif rel:
        source = "OSM"
        osm_url = f"https://www.openstreetmap.org/relation/{rel}"
    else:
        source = "WD"
        osm_url = None

    if node or way or rel:
        source = "both"

    data.append({"label": label, "lat": lat, "lon": lon, "source": source, "osm_url": osm_url})

df = pd.DataFrame(data)
df.head()
# Out:
#                   label        lat        lon source  \
# 0  Knicksand grillplats  58.917789  18.165038   both
# 1  Knicksand grillplats  58.917563  18.165444   both
# 2    Sandön, grillplats  59.278198  18.909647   both
# 3  Myrudden, grillplats  59.664687  18.911037   both
# 4           Lidö brygga  59.770089  19.079149   both
#
#                                           osm_url
# 0  https://www.openstreetmap.org/node/12722761765
# 1  https://www.openstreetmap.org/node/12722789034
# 2  https://www.openstreetmap.org/node/12752418489
# 3  https://www.openstreetmap.org/node/12873021137
# 4   https://www.openstreetmap.org/node/1823005981

# %%
df
# Out:
#         label     lat     lon source                                 osm_url
# 0   Toilet WD  59.750  18.850     WD                                    None
# 1  Toilet OSM  59.752  18.855    OSM  https://www.openstreetmap.org/node/123
# 2  Water both  59.760  18.820   both  https://www.openstreetmap.org/node/456

# %%
import folium
import pandas as pd
from folium import FeatureGroup
from shapely.geometry import Point
from IPython.display import display

# Sample POIs (normally loaded via SPARQL)
data = [
    {"label": "Toilet WD", "lat": 59.75, "lon": 18.85, "source": "WD", "osm_url": None},
    {"label": "Toilet OSM", "lat": 59.752, "lon": 18.855, "source": "OSM", "osm_url": "https://www.openstreetmap.org/node/123"},
    {"label": "Water both", "lat": 59.76, "lon": 18.82, "source": "both", "osm_url": "https://www.openstreetmap.org/node/456"},
]
df = pd.DataFrame(data)

# %%
# Create map
m = folium.Map(location=[59.75, 18.85], zoom_start=13)

# Add groups
fg_wd = FeatureGroup(name="Wikidata")
fg_osm = FeatureGroup(name="OSM")
fg_both = FeatureGroup(name="WD + OSM")

# Add markers to appropriate group
for _, row in df.iterrows():
    marker = folium.Marker(
        [row["lat"], row["lon"]],
        popup=f"<b>{row['label']}</b><br>{row['osm_url'] or ''}",
        icon=folium.Icon(color="blue" if row["source"] == "WD" else "green" if row["source"] == "OSM" else "purple")
    )
    if row["source"] == "WD":
        marker.add_to(fg_wd)
    elif row["source"] == "OSM":
        marker.add_to(fg_osm)
    else:
        marker.add_to(fg_both)

# Add groups to map
fg_wd.add_to(m)
fg_osm.add_to(m)
fg_both.add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_038e36a93bc14cecd01c31bd17d3537b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_038e36a93bc14cecd01c31bd17d3537b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_038e36a93bc14cecd01c31bd17d3537b = L.map(
#                 &quot;map_038e36a93bc14cecd01c31bd17d3537b&quot;,
#                 {
#                     center: [59.75, 18.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b65020e1d22ab5610a175877bdb014d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b65020e1d22ab5610a175877bdb014d.addTo(map_038e36a93bc14cecd01c31bd17d3537b);
#
#
#             var feature_group_952ffb2b8aafe19d280bdea16aa443f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4ccc2c55a574b89e6b69fc97e2e57716 = L.marker(
#                 [59.75, 18.85],
#                 {
# }
#             ).addTo(feature_group_952ffb2b8aafe19d280bdea16aa443f0);
#
#
#             var icon_7a896dd43e9f72ed85fa88ecb826a87a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_93c050b25bb4aadf5143b6885e31c93f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b1e992ebb90872ac33815684c0dbd71 = $(`&lt;div id=&quot;html_7b1e992ebb90872ac33815684c0dbd71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toilet WD&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_93c050b25bb4aadf5143b6885e31c93f.setContent(html_7b1e992ebb90872ac33815684c0dbd71);
#
#
#
#         marker_4ccc2c55a574b89e6b69fc97e2e57716.bindPopup(popup_93c050b25bb4aadf5143b6885e31c93f)
#         ;
#
#
#
#
#                 marker_4ccc2c55a574b89e6b69fc97e2e57716.setIcon(icon_7a896dd43e9f72ed85fa88ecb826a87a);
#
#
#             feature_group_952ffb2b8aafe19d280bdea16aa443f0.addTo(map_038e36a93bc14cecd01c31bd17d3537b);
#
#
#             var feature_group_40683d0b0ea43d04b8346c6e2bf4ff43 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ccefd23b53b0ece5dc07d89a4cba2ac4 = L.marker(
#                 [59.752, 18.855],
#                 {
# }
#             ).addTo(feature_group_40683d0b0ea43d04b8346c6e2bf4ff43);
#
#
#             var icon_88d3335ea6617b3cf1bd8c27a0bcffec = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bb9c09ed6c16b3575ec072e4b806d202 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_143798bc331068b7998f5771de68c2ba = $(`&lt;div id=&quot;html_143798bc331068b7998f5771de68c2ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toilet OSM&lt;/b&gt;&lt;br&gt;https://www.openstreetmap.org/node/123&lt;/div&gt;`)[0];
#                 popup_bb9c09ed6c16b3575ec072e4b806d202.setContent(html_143798bc331068b7998f5771de68c2ba);
#
#
#
#         marker_ccefd23b53b0ece5dc07d89a4cba2ac4.bindPopup(popup_bb9c09ed6c16b3575ec072e4b806d202)
#         ;
#
#
#
#
#                 marker_ccefd23b53b0ece5dc07d89a4cba2ac4.setIcon(icon_88d3335ea6617b3cf1bd8c27a0bcffec);
#
#
#             feature_group_40683d0b0ea43d04b8346c6e2bf4ff43.addTo(map_038e36a93bc14cecd01c31bd17d3537b);
#
#
#             var feature_group_fa6e34e98573484371070f30640485ff = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_28fbd38edae343c3323df33364632cc7 = L.marker(
#                 [59.76, 18.82],
#                 {
# }
#             ).addTo(feature_group_fa6e34e98573484371070f30640485ff);
#
#
#             var icon_72f0b2a609ad1f3d62e855ee8fb7489d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cc07b09d4d920e894eb128324ea

# %%
# End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print("Total time elapsed: {:.2f} seconds".format(elapsed_time))
# Out:
# Date: 2025-07-24 19:14:52
# Total time elapsed: 7.46 seconds
