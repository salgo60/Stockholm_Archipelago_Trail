# %% [markdown]
# # 🗺️ SAT POI Viewer with WD + OSM
# This notebook loads POIs (e.g. toilets, water points) from Wikidata with optional OSM matches and renders them on a Folium map with filtering options.

# %%
import time
from datetime import datetime

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-07-24 19:13:55

# %%
import folium
import pandas as pd
from folium import FeatureGroup
from shapely.geometry import Point
from IPython.display import display

# Sample POIs (normally loaded via SPARQL)
data = [
    {"label": "Toilet WD", "lat": 59.75, "lon": 18.85, "source": "WD", "osm_url": None},
    {"label": "Toilet OSM", "lat": 59.752, "lon": 18.855, "source": "OSM", "osm_url": "https://www.openstreetmap.org/node/123"},
    {"label": "Water both", "lat": 59.76, "lon": 18.82, "source": "both", "osm_url": "https://www.openstreetmap.org/node/456"},
]
df = pd.DataFrame(data)

# %%
# Create map
m = folium.Map(location=[59.75, 18.85], zoom_start=13)

# Add groups
fg_wd = FeatureGroup(name="Wikidata")
fg_osm = FeatureGroup(name="OSM")
fg_both = FeatureGroup(name="WD + OSM")

# Add markers to appropriate group
for _, row in df.iterrows():
    marker = folium.Marker(
        [row["lat"], row["lon"]],
        popup=f"<b>{row['label']}</b><br>{row['osm_url'] or ''}",
        icon=folium.Icon(color="blue" if row["source"] == "WD" else "green" if row["source"] == "OSM" else "purple")
    )
    if row["source"] == "WD":
        marker.add_to(fg_wd)
    elif row["source"] == "OSM":
        marker.add_to(fg_osm)
    else:
        marker.add_to(fg_both)

# Add groups to map
fg_wd.add_to(m)
fg_osm.add_to(m)
fg_both.add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc78eca76f089ad2a09d86f79b26da1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc78eca76f089ad2a09d86f79b26da1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc78eca76f089ad2a09d86f79b26da1d = L.map(
#                 &quot;map_cc78eca76f089ad2a09d86f79b26da1d&quot;,
#                 {
#                     center: [59.75, 18.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_589dd4f275f480dc2ec9427435862f4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_589dd4f275f480dc2ec9427435862f4c.addTo(map_cc78eca76f089ad2a09d86f79b26da1d);
#
#
#             var feature_group_9ba9876888459ae6cb67f030ebf63e09 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7a21eb587f1041f3823dc8e73286b39a = L.marker(
#                 [59.75, 18.85],
#                 {
# }
#             ).addTo(feature_group_9ba9876888459ae6cb67f030ebf63e09);
#
#
#             var icon_78f4aea9a7606c38bb0f004cb107a24f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_457adb2ef0d307183469d87351c4c9b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_335e46f2e5f7fac211c320b7b49c7a87 = $(`&lt;div id=&quot;html_335e46f2e5f7fac211c320b7b49c7a87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toilet WD&lt;/b&gt;&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_457adb2ef0d307183469d87351c4c9b0.setContent(html_335e46f2e5f7fac211c320b7b49c7a87);
#
#
#
#         marker_7a21eb587f1041f3823dc8e73286b39a.bindPopup(popup_457adb2ef0d307183469d87351c4c9b0)
#         ;
#
#
#
#
#                 marker_7a21eb587f1041f3823dc8e73286b39a.setIcon(icon_78f4aea9a7606c38bb0f004cb107a24f);
#
#
#             feature_group_9ba9876888459ae6cb67f030ebf63e09.addTo(map_cc78eca76f089ad2a09d86f79b26da1d);
#
#
#             var feature_group_523ffd5170ba04be52285383b89a0700 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9fddabe501c56b4a1d470d0f1b603bda = L.marker(
#                 [59.752, 18.855],
#                 {
# }
#             ).addTo(feature_group_523ffd5170ba04be52285383b89a0700);
#
#
#             var icon_a0fa134758b33a79716d95253f9b8611 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_517be86d0ab3d22fbf77faebf48ff1d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8380ec404af03b799ce3b63e9df03afb = $(`&lt;div id=&quot;html_8380ec404af03b799ce3b63e9df03afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toilet OSM&lt;/b&gt;&lt;br&gt;https://www.openstreetmap.org/node/123&lt;/div&gt;`)[0];
#                 popup_517be86d0ab3d22fbf77faebf48ff1d6.setContent(html_8380ec404af03b799ce3b63e9df03afb);
#
#
#
#         marker_9fddabe501c56b4a1d470d0f1b603bda.bindPopup(popup_517be86d0ab3d22fbf77faebf48ff1d6)
#         ;
#
#
#
#
#                 marker_9fddabe501c56b4a1d470d0f1b603bda.setIcon(icon_a0fa134758b33a79716d95253f9b8611);
#
#
#             feature_group_523ffd5170ba04be52285383b89a0700.addTo(map_cc78eca76f089ad2a09d86f79b26da1d);
#
#
#             var feature_group_7aebfa66a5cd4a6b5779b30fe9dcf4c3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1491386ed7deac758cfe11d4b01a2bf8 = L.marker(
#                 [59.76, 18.82],
#                 {
# }
#             ).addTo(feature_group_7aebfa66a5cd4a6b5779b30fe9dcf4c3);
#
#
#             var icon_3cdb007bef5ea9ccaa7f81ec870a6b61 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_30b7a3a71b68456f643dd2d54d4

# %%
# End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print("Total time elapsed: {:.2f} seconds".format(elapsed_time))
# Out:
# Date: 2025-07-24 19:14:10
# Total time elapsed: 14.79 seconds
