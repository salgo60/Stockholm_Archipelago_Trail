# %%
# 📌 Install required packages
# !pip install SPARQLWrapper osmtogeojson folium
# Out:
# Requirement already satisfied: SPARQLWrapper in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: osmtogeojson in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.0.2)
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.20.0)
# Requirement already satisfied: rdflib>=6.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from SPARQLWrapper) (7.0.0)
# Requirement already satisfied: branca>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (2.4.7)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->folium) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->folium) (2024.12.14)

# %%
# ✅ Import libraries
from SPARQLWrapper import SPARQLWrapper, JSON
import requests
import folium
from folium import LayerControl
from osmtogeojson import osmtogeojson
import json

# %%
# ✅ 1. Query Wikidata for SAT-connected nature reserves with OSM relation/way
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)
sparql.setQuery("""
SELECT DISTINCT ?item ?itemLabel ?SATLabel ?P402 ?P10689 WHERE {
  wd:Q131318799 wdt:P3018 ?item.
  OPTIONAL { ?item wdt:P402 ?P402. }
  OPTIONAL { ?item wdt:P10689 ?P10689. }
  OPTIONAL {
    # ?item wdt:P2789 ?SATid.
    # ?SATid wdt:P361 wd:Q131318799.
    # ?SATid rdfs:label ?SATLabel. FILTER(LANG(?SATLabel)="sv")
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
""")
results = sparql.query().convert()

# %%
#results

# %%
# ✅ 2. Build list of features with OSM IDs
items = []
for r in results["results"]["bindings"]:
    def val(k): return r[k]["value"] if k in r else None
    label = val("itemLabel")
    sat = val("SATLabel")
    rel = val("P402")
    way = val("P10689")

    if rel:
        overpass = f"relation({rel});"
    elif way:
        overpass = f"way({way});"
    else:
        continue

    items.append({
        "label": label,
        "sat": sat or "Okänt avsnitt",
        "overpass": overpass
    })

print(f"Loaded {len(items)} reserves with OSM geometry.")
# Out:
# Loaded 13 reserves with OSM geometry.

# %%
items
# Out:
# [{'label': 'Fjärdlångs naturreservat',
#   'sat': 'SAT Fjärdlång',
#   'overpass': 'relation(1463788);'},
#  {'label': 'Nämdö naturreservat',
#   'sat': 'SAT Nämdö',
#   'overpass': 'relation(1463777);'},
#  {'label': 'Utö naturreservat',
#   'sat': 'SAT Utö',
#   'overpass': 'relation(1463748);'},
#  {'label': 'Grinda naturreservat',
#   'sat': 'SAT Grinda',
#   'overpass': 'relation(1463789);'},
#  {'label': 'Lidö naturreservat',
#   'sat': 'SAT Lidö',
#   'overpass': 'relation(1463761);'},
#  {'label': 'Norra skogens naturreservat',
#   'sat': 'SAT Ornö',
#   'overpass': 'way(1331536835);'},
#  {'label': 'Arholma-Idö naturreservat',
#   'sat': 'SAT Arholma',
#   'overpass': 'relation(1463750);'},
#  {'label': 'Ålö-Rånö naturreservat',
#   'sat': 'SAT Ålö',
#   'overpass': 'relation(1463767);'},
#  {'label': 'Ålö-Rånö naturreservat',
#   'sat': 'SAT Rånö',
#   'overpass': 'relation(1463767);'},
#  {'label': 'Finnhamns naturreservat',
#   'sat': 'SAT Finnhamn',
#   'overpass': 'relation(1463800);'},
#  {'label': 'Öja-Landsort Naturvårdsområde',
#   'sat': 'SAT Landsort',
#   'overpass': 'way(103228585);'},
#  {'label': 'Kålgårdsöns naturreservat',
#   'sat': 'SAT Ingmarsö',
#   'overpass': 'relation(10626459);'},
#  {'label': 'Nåttarö naturreservat',
#   'sat': 'SAT Nåttarö',
#   'overpass': 'relation(1463792);'}]

# %%
# ✅ 3. Fetch geometry from Overpass
query_body = "[out:json][timeout:25];(" + "".join(item["overpass"] for item in items) + ");(._;>;);out body;>;out skel qt;"
overpass_url = "https://overpass-api.de/api/interpreter"
response = requests.post(overpass_url, data={"data": query_body})
osm_data = response.json()

# %%
query = """
[out:json][timeout:25];
relation(1463748);
(._;>;);
out body;
"""

# %%
#osm_data

# %%
ways = [el for el in osm_data['elements'] if el['type'] == 'way']
relations = [el for el in osm_data['elements'] if el['type'] == 'relation']
print(f"Ways: {len(ways)}, Relations: {len(relations)}")
# Out:
# Ways: 274, Relations: 10

# %%
missing_nodes = False
node_ids = {n["id"] for n in osm_data["elements"] if n["type"] == "node"}
for way in ways:
    for nid in way.get("nodes", []):
        if nid not in node_ids:
            print(f"Missing node {nid} for way {way['id']}")
            missing_nodes = True
if not missing_nodes:
    print("✅ All nodes required for ways are present.")
# Out:
# ✅ All nodes required for ways are present.

# %%
geojson = json2geojson(osm_data)

# %%
import json
#print(json.dumps(geojson, indent=2))

# %%
ways_with_tags = [w for w in ways if 'tags' in w and w['tags']]
print(f"Ways with tags: {len(ways_with_tags)}")
# Out:
# Ways with tags: 41

# %%
relations_with_tags = [r for r in relations if 'tags' in r and r['tags']]
print(f"Relations with tags: {len(relations_with_tags)}")
# Out:
# Relations with tags: 10

# %%
from osm2geojson import json2geojson

try:
    geojson = json2geojson(osm_data)
    features = geojson['features']
    print(f"✅ Converted {len(features)} features to GeoJSON.")
    for i, feat in enumerate(features[:5]):  # show first 5
        print(f"- Feature {i}: {feat['properties'].get('name')}")
except Exception as e:
    print("❌ Failed to convert OSM to GeoJSON:", e)
# Out:
# ✅ Converted 12 features to GeoJSON.
# - Feature 0: None
# - Feature 1: None
# - Feature 2: None
# - Feature 3: None
# - Feature 4: None

# %%
import geojson

nodes_by_id = {el["id"]: el for el in osm_data["elements"] if el["type"] == "node"}
features = []

for way in ways_with_tags:
    coords = []
    for nid in way.get("nodes", []):
        node = nodes_by_id.get(nid)
        if node:
            coords.append((node["lon"], node["lat"]))
    if coords and coords[0] == coords[-1] and len(coords) >= 4:
        features.append(geojson.Feature(
            geometry=geojson.Polygon([coords]),
            properties=way["tags"]
        ))

print(f"✅ Manually created {len(features)} features.")
geojson_data = geojson.FeatureCollection(features)
# Out:
# ✅ Manually created 27 features.

# %%
import folium

m = folium.Map(location=[59.3, 18.5], zoom_start=9)

folium.GeoJson(
    geojson_data,
    name="Nature Reserves",
    tooltip=folium.GeoJsonTooltip(fields=["name"]),
    style_function=lambda feature: {
        'fillColor': '#228B22',
        'color': '#006400',
        'weight': 2,
        'fillOpacity': 0.5,
    }
).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdb7b61003ab5be5e4e2dc673b4b2a5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdb7b61003ab5be5e4e2dc673b4b2a5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdb7b61003ab5be5e4e2dc673b4b2a5c = L.map(
#                 &quot;map_fdb7b61003ab5be5e4e2dc673b4b2a5c&quot;,
#                 {
#                     center: [59.3, 18.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb50d4e256cfd43642f2f91b436bd223 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb50d4e256cfd43642f2f91b436bd223.addTo(map_fdb7b61003ab5be5e4e2dc673b4b2a5c);
#
#
#         function geo_json_c75c2cfea706a741c50ff9d48deee6b7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#006400&quot;, &quot;fillColor&quot;: &quot;#228B22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_c75c2cfea706a741c50ff9d48deee6b7_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c75c2cfea706a741c50ff9d48deee6b7 = L.geoJson(null, {
#                 onEachFeature: geo_json_c75c2cfea706a741c50ff9d48deee6b7_onEachFeature,
#
#                 style: geo_json_c75c2cfea706a741c50ff9d48deee6b7_styler,
#             ...{
# }
#         });
#
#         function geo_json_c75c2cfea706a741c50ff9d48deee6b7_add (data) {
#             geo_json_c75c2cfea706a741c50ff9d48deee6b7
#                 .addData(data);
#         }
#             geo_json_c75c2cfea706a741c50ff9d48deee6b7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[18.803677, 59.470562], [18.803608, 59.470582], [18.803402, 59.470649], [18.803262, 59.470657], [18.80319, 59.47065], [18.803061, 59.470581], [18.802936, 59.470565], [18.80261, 59.470573], [18.802427, 59.470595], [18.802224, 59.4706], [18.802087, 59.470549], [18.80199, 59.470551], [18.80184, 59.470451], [18.801739, 59.470404], [18.801548, 59.470346], [18.80145, 59.47033], [18.801353, 59.470332], [18.801227, 59.470299], [18.801167, 59.470224], [18.801119, 59.470082], [18.800998, 59.470008], [18.800639, 59.469944], [18.800341, 59.469862], [18.800076, 59.46976], [18.799981, 59.469686], [18.799974, 59.469605], [18.800002, 59.469524], [18.800044, 59.4695], [18.80027, 59.469468], [18.800416, 59.469415], [18.800338, 59.469341], [18.800354, 59.469313], [18.800413, 59.469285], [18.800588, 59.469263], [18.800646, 59.46923], [18.800666, 59.46905], [18.800715, 59.469009], [18.80081, 59.46898], [18.80081, 59.46898], [18.800881, 59.468987], [18.801, 59.469034], [18.801077, 59.469108], [18.801169, 59.469151], [18.801266, 59.469149], [18.801655, 59.469059], [18.801753, 59.469066], [18.801987, 59.469123], [18.802444, 59.469297], [18.80277, 59.469388], [18.802853, 59.469427], [18.803095, 59.469673], [18.803485, 59.469893], [18.80358, 59.469962], [18.803754, 59.470134], [18.803817, 59.470249], [18.803815, 59.470429], [18.80377, 59.470511], [18.803677, 59.470562]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Klippingen&quot;, &quot;natural&quot;: &quot;coastline&quot;, &quot;place&quot;: &quot;islet&quot;, &quot;source&quot;: &quot;L\u00e4nsstyrelsen i Stockholms l\u00e4n (gis.lst.se)&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[19.129879, 59.862795], [19.129923, 59.862695], [19.129937, 59.862569], [19.13052, 59.862689], [19.130373, 59.862863], [19.129879, 59.862795]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;source&quot;: &quot;Naturv\u00e5rdsverket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[18.797137, 59.468363], [18.797236, 59.468388], [18.797292, 59.468418], [18.797278, 59.468463], [18.797319, 59.46853], [18.797269, 59.468567],

# %%
import json

with open("nature_reserves.geojson", "w") as f:
    json.dump(geojson_data, f)

# %%
import geojson

# Index all elements
nodes_by_id = {el["id"]: el for el in osm_data["elements"] if el["type"] == "node"}
ways_by_id = {el["id"]: el for el in osm_data["elements"] if el["type"] == "way"}
relations = [el for el in osm_data["elements"] if el["type"] == "relation"]
ways = [el for el in osm_data["elements"] if el["type"] == "way"]

features = []

# --- Convert tagged, closed ways to polygons ---
for way in ways:
    if "tags" not in way:
        continue
    node_coords = []
    for nid in way.get("nodes", []):
        node = nodes_by_id.get(nid)
        if node:
            node_coords.append((node["lon"], node["lat"]))
    if len(node_coords) >= 4 and node_coords[0] == node_coords[-1]:
        features.append(geojson.Feature(
            geometry=geojson.Polygon([node_coords]),
            properties=way["tags"]
        ))

# --- Convert relations with multipolygon or boundary type ---
for rel in relations:
    if "tags" not in rel or rel.get("tags", {}).get("type") not in {"multipolygon", "boundary"}:
        continue

    outer_rings = []
    inner_rings = []

    for member in rel.get("members", []):
        if member["type"] != "way":
            continue
        way = ways_by_id.get(member["ref"])
        if not way:
            continue
        coords = []
        for nid in way.get("nodes", []):
            node = nodes_by_id.get(nid)
            if node:
                coords.append((node["lon"], node["lat"]))
        if len(coords) >= 4 and coords[0] == coords[-1]:
            if member.get("role") == "outer":
                outer_rings.append(coords)
            elif member.get("role") == "inner":
                inner_rings.append(coords)

    if outer_rings:
        features.append(geojson.Feature(
            geometry=geojson.Polygon([*outer_rings, *inner_rings]) if len(outer_rings) == 1
            else geojson.MultiPolygon([([*outer_rings[0], *inner_rings])]),
            properties=rel["tags"]
        ))

# Wrap as GeoJSON FeatureCollection
geojson_data = geojson.FeatureCollection(features)
print(f"✅ Created {len(features)} features (ways + relations).")
# Out:
# ✅ Created 30 features (ways + relations).

# %%
import folium

m = folium.Map(location=[59.2, 18.5], zoom_start=9)

folium.GeoJson(
    geojson_data,
    name="Nature Reserves",
    style_function=lambda feature: {
        'fillColor': '#228B22',
        'color': '#006400',
        'weight': 2,
        'fillOpacity': 0.4,
    },
    tooltip=folium.GeoJsonTooltip(fields=["name"], aliases=["Reservat"])
).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_219e60698974b0a389e5b2ddb62308c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_219e60698974b0a389e5b2ddb62308c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_219e60698974b0a389e5b2ddb62308c8 = L.map(
#                 &quot;map_219e60698974b0a389e5b2ddb62308c8&quot;,
#                 {
#                     center: [59.2, 18.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d1d4cb2f001d493f193f9507815b194 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d1d4cb2f001d493f193f9507815b194.addTo(map_219e60698974b0a389e5b2ddb62308c8);
#
#
#         function geo_json_16e711b9f62fc272721428faa58091ce_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#006400&quot;, &quot;fillColor&quot;: &quot;#228B22&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_16e711b9f62fc272721428faa58091ce_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_16e711b9f62fc272721428faa58091ce = L.geoJson(null, {
#                 onEachFeature: geo_json_16e711b9f62fc272721428faa58091ce_onEachFeature,
#
#                 style: geo_json_16e711b9f62fc272721428faa58091ce_styler,
#             ...{
# }
#         });
#
#         function geo_json_16e711b9f62fc272721428faa58091ce_add (data) {
#             geo_json_16e711b9f62fc272721428faa58091ce
#                 .addData(data);
#         }
#             geo_json_16e711b9f62fc272721428faa58091ce_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[18.803677, 59.470562], [18.803608, 59.470582], [18.803402, 59.470649], [18.803262, 59.470657], [18.80319, 59.47065], [18.803061, 59.470581], [18.802936, 59.470565], [18.80261, 59.470573], [18.802427, 59.470595], [18.802224, 59.4706], [18.802087, 59.470549], [18.80199, 59.470551], [18.80184, 59.470451], [18.801739, 59.470404], [18.801548, 59.470346], [18.80145, 59.47033], [18.801353, 59.470332], [18.801227, 59.470299], [18.801167, 59.470224], [18.801119, 59.470082], [18.800998, 59.470008], [18.800639, 59.469944], [18.800341, 59.469862], [18.800076, 59.46976], [18.799981, 59.469686], [18.799974, 59.469605], [18.800002, 59.469524], [18.800044, 59.4695], [18.80027, 59.469468], [18.800416, 59.469415], [18.800338, 59.469341], [18.800354, 59.469313], [18.800413, 59.469285], [18.800588, 59.469263], [18.800646, 59.46923], [18.800666, 59.46905], [18.800715, 59.469009], [18.80081, 59.46898], [18.80081, 59.46898], [18.800881, 59.468987], [18.801, 59.469034], [18.801077, 59.469108], [18.801169, 59.469151], [18.801266, 59.469149], [18.801655, 59.469059], [18.801753, 59.469066], [18.801987, 59.469123], [18.802444, 59.469297], [18.80277, 59.469388], [18.802853, 59.469427], [18.803095, 59.469673], [18.803485, 59.469893], [18.80358, 59.469962], [18.803754, 59.470134], [18.803817, 59.470249], [18.803815, 59.470429], [18.80377, 59.470511], [18.803677, 59.470562]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Klippingen&quot;, &quot;natural&quot;: &quot;coastline&quot;, &quot;place&quot;: &quot;islet&quot;, &quot;source&quot;: &quot;L\u00e4nsstyrelsen i Stockholms l\u00e4n (gis.lst.se)&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[19.129879, 59.862795], [19.129923, 59.862695], [19.129937, 59.862569], [19.13052, 59.862689], [19.130373, 59.862863], [19.129879, 59.862795]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;source&quot;: &quot;Naturv\u00e5rdsverket&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[18.797137, 59.468363], [18.797236, 59.468388], [18.797292, 59.468418], [18.797278, 59.468463], [18.797319, 59.46853], [18.797269, 59.468567],
