# %% [markdown]
# # Check https://geodata.naturvardsverket.se/nedladdning/friluftsliv
# * [#504](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/504)
# * Denna Notebook [504_naturvardsverket.se_nedladdning_friluftsliv](https://github.com/salgo60/Stockholm_Archipelago_Trail/blob/main/Notebook/504_naturvardsverket.se_nedladdning_friluftsliv.ipynb)

# %%
import time
import datetime  
start_time = time.time()
start_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
print(f"Started: {start_str}")
