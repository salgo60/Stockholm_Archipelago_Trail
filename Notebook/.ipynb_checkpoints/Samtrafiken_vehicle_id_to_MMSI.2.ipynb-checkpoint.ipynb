# %%
from zipfile import ZipFile
import pandas as pd

GTFS_ZIP = "sweden_api.zip"

with ZipFile(GTFS_ZIP) as z:
    agencies = pd.read_csv(z.open("agency.txt"), dtype=str)
    routes   = pd.read_csv(z.open("routes.txt"), dtype=str)
    trips    = pd.read_csv(z.open("trips.txt"), dtype=str)

print("Agencies:", len(agencies))
print("Routes:", len(routes))
print("Trips:", len(trips))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 import pandas as pd
#       4 GTFS_ZIP = "sweden_api.zip"
# ----> 6 with ZipFile(GTFS_ZIP) as z:
#       7     agencies = pd.read_csv(z.open("agency.txt"), dtype=str)
#       8     routes   = pd.read_csv(z.open("routes.txt"), dtype=str)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipfile/__init__.py:1323, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1321 while True:
#    1322     try:
# -> 1323         self.fp = io.open(file, filemode)
#    1324     except OSError:
#    1325         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sweden_api.zip'
