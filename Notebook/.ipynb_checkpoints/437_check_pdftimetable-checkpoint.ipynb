# %% [markdown]
# ## Analysera tidtabeller
# * [#437](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/437)

# %%
from pathlib import Path
import requests
import pdfplumber
import pandas as pd
from tqdm.notebook import tqdm

# %%
BASE_URL = "https://kund.printhuset-sthlm.se/wa"

DOWNLOAD_DIR = Path("waxholm_pdf")
DOWNLOAD_DIR.mkdir(exist_ok=True)

routes = [str(i) for i in range(2, 32)] + [
    "40",
    "60a",
    "60b",
    "60d",
    "60e",
    "60f",
    "60g",
    "61",
    "65",
]

# %%
for route in tqdm(routes):

    url = f"{BASE_URL}/s{route}.pdf"

    filename = DOWNLOAD_DIR / f"s{route}.pdf"

    if filename.exists():
        continue

    r = requests.get(url)

    if r.status_code == 200:
        filename.write_bytes(r.content)
        print("Downloaded", filename.name)
    else:
        print("Missing", url)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# Missing https://kund.printhuset-sthlm.se/wa/s6.pdf
# Missing https://kund.printhuset-sthlm.se/wa/s61.pdf
# Missing https://kund.printhuset-sthlm.se/wa/s65.pdf

# %%
pdf = DOWNLOAD_DIR / "s3.pdf"

text = ""

with pdfplumber.open(pdf) as p:

    for page in p.pages:
        page_text = page.extract_text()

        if page_text:
            text += page_text + "\n"

print(text[:4000])
# Out:
# GÄLLER 19 JUNI 2026 – 16 AUGUSTI 2026 Uppdaterad 24 juni 2026
# 3A
# STOCKHOLM – VAXHOLM – NORRA LAGNÖ – ÅLSTÄKET
# DAG MÅNDAG–TORSDAG FREDAG
# FARTYG
# TURNUMMER
# ANMÄRKNING
# Strömkajen (Stockholm)
# Slussen (Stockholm)
# Nacka strand
# Hasseludden
# Gåshaga brygga
# Vaxholm ank.
# Vaxholm avg.
# Grenadjärbryggan (Rindö)
# Knutsholmen
# Skogsö södra
# Hästholmen
# Skogsö udde
# Norra Lagnö
# Ålstäket
# HELGTRAFIK ANSLUTANDE SL-TRAFIK
# Vid jul, nyår, påsk, midsommar samt övriga storhelger Sök hela din resa på sl.se för att få tider för både
# förekommer förändringar i trafiken. Se information anslutande SL-trafik och skärgårdstrafiken.
# och sök din resa på waxholmsbolaget.se eller i appen.
# NERAXAS
# 0303
# 06.28
# 06.45
# ÖREVLIS
# 0300
# 06.45
# 07.00b
# X
# X
# 07.10
# 07.20
# NEGGIV
# 0309
# 08.10
# 08.32
# 08.37b
# X
# X
# 08.47
# 08.55
# 09.10
# TÅB-V
# 1401
# 07.45
# 08.00
# 08.10
# ÖREVLIS
# 0320
# 08.15z
# 08.10z
# 08.50
# NEGGIV
# 0309
# 09.32z
# 09.29z
# 09.26z
# 09.25z
# 08.55z
# 09.10
# TÅB-V
# 1405
# 13.00
# 13.17
# 13.27
# 13.32
# 14.00
# NEGGIV
# 0315
# 14.10
# 14.30
# 14.35b
# X
# X
# 14.45
# 14.55
# 15.10
# TÅB-V
# 1305
# 17.00
# 17.03p
# 17.19
# 17.32
# 17.37
# 18.09
# NEGGIV
# 0319
# 18.10
# 18.30
# 18.40b
# X
# X
# 18.50
# 19.00
# 19.15
# ÖREBIV
# 0303
# 06.28
# 06.45
# ÖREVLIS
# 0300
# 06.45
# 07.00b
# X
# X
# 07.10
# 07.20
# NEGGIV
# 0309
# 08.10
# 08.32
# 08.37b
# X
# X
# 08.47
# 08.55
# 09.10
# ÖDMRÄV
# 1421
# 07.45
# 08.00
# 08.10
# ÖREVLIS
# 0320
# 08.15z
# 08.10z
# 08.50
# NEGGIV
# 0309
# 09.32z
# 09.29z
# 09.26z
# 09.25z
# 08.55z
# 09.10
# ÖXAV
# 1425
# 13.00
# 13.17
# 13.27
# 13.32
# 14.00
# NEGGIV
# 0315
# 14.10
# 14.30
# 14.35b
# X
# X
# 14.45
# 14.55
# 15.10
# ÖREBIV
# 1225
# 16.47
# 16.57
# 17.02
# 17.30
# RÄKSROTS
# 0925
# 16.45
# 17.15
# 17.20
# 17.55
# ANMÄRKNING BRYGGA OCH FARTYG
# X Bryggorna trafikeras utan fast avgångstid.
# | Bryggan trafikeras inte.
# b Beställ resan i SL-appen, på
# Waxholmsbolagets webb eller via kundtjänst
# 08-600 10 00 minst 1 timme innan avgång
# från aktuell brygga, dock senast kl. 17.00.
# p Endast påstigning.
# z Bryggan trafikeras i omvänd ordning.
# V-BÅT innebär att Värmdö, Vånö, Väddö, Viberö
# eller Vaxö kör turen.
# NEGGIV
# 0319
# 18.10
# 18.30
# 18.40b
# X
# X
# 18.50
# 19.00
# 19.15
# GÄLLER 19 JUNI 2026 – 16 AUGUSTI 2026 Uppdaterad 24 juni 2026
# 3A
# STOCKHOLM – VAXHOLM – NORRA LAGNÖ – ÅLSTÄKET
# DAG LÖRDAG SÖNDAG
# FARTYG
# TURNUMMER
# ANMÄRKNING
# Strömkajen (Stockholm)
# Slussen (Stockholm)
# Nacka strand
# Hasseludden
# Gåshaga brygga
# Vaxholm ank.
# Vaxholm avg.
# Knutsholmen
# Skogsö södra
# Hästholmen
# Skogsö udde
# Norra Lagnö
# Ålstäket
# HELGTRAFIK ANSLUTANDE SL-TRAFIK
# Vid jul, nyår, påsk, midsommar samt övriga storhelger Sök hela din resa på sl.se för att få tider för både
# förekommer förändringar i trafiken. Se information anslutande SL-trafik och skärgårdstrafiken.
# och sök din resa på waxholmsbolaget.se eller i appen.
# NEGGIV
# 0353
# 08.55
# 09.10b
# X
# X
# 09.20
# 09.30
# ÖREBIV
# 1457
# 13.00
# 13.17
# 13.30
# 13.35
# 14.00
# ÖREVLIS
# 0357
# 14.10
# 14.37b
# X
# X
# 14.47
# 15.00
# ÖDMRÄV
# 1357
# 15.00
# 15.17
# 15.30
# 15.35
# 15.57
# NEGGIV
# 0359
# 16.05
# 16.30b
# X
# X
# 16.40
# 17.00
# NEGGIV
# 0373
# 08.35
# 09.05b
# X
# X
# 09.20
# 09.30
# 09.45
# NEGALSOR
# 0975
# 15.00
# 15.17
# 15.28
# 15.33
# 15.58
# NEGGIV
# 0379
# 16.00
# 16.30b
# X
# X
# 16.40
# 16.50
# 17.05
# ÖRALAD
# 0875
# 17.10
# 17.45
# 17.50
# 18.22
# ÖREVLIS
# ANMÄRKNING BRYGGA
# X Bryggorna trafikeras utan fast avgångstid.
# | Bryggan trafikeras inte.
# b Beställ resan i SL-appen, på
# Waxholmsbolagets webb eller via kundtjänst
# 08-600 10 00 minst 1 timme innan avgång
# från aktuell brygga, dock senast kl. 17.00.
# 0381
# 18.25
# 18.50b
# X
# X
# 19.00
# 19.10
# GÄLLER 19 JUNI 2026 – 16 AUGUSTI 2026 Uppdaterad 24 juni 2026
# 3B
# ÅLSTÄKET – NORRA LAGNÖ – VAXHOLM – STOCKHOLM
# DAG MÅNDAG–TORSDAG
# FARTYG
# TURNUMMER
# ANMÄRKNING
# Ålstäket
# Norra Lagnö
# Skogsö udde
# Hästholmen
# Skogsö södra
# Knutsholmen
# Vaxholm ank.
# Vaxholm avg.
# Gåshaga brygga
# Hasseludden
# Nacka strand
# Slussen (Stockholm)
# Strömkajen (Stockholm)
# HELGTRAFIK ANSLUTANDE SL-TRAFIK
# Vid jul, nyår, påsk, midsommar samt övriga storhelger Sök hela din resa på sl.se för att få tider för både
# förekommer förändringar i trafiken. Se information anslutande SL-trafik och skärgårdstrafiken.
# och sök din resa på waxholmsbolaget.se eller i appen.
# ÖREVLIS
# 0300
# 07.20z
# 07.10z
# 07.07z
# 07.05z
# 07.00bz
# 08.10
# 08.15
# NEGALSOR
# ÖREBIV
# RELLE
# 0406
# 08.16
# 08.21
# 08.36
# 08.53a
# 08.56
# ÖREVLIS
# 0306
# 08.50
# 09.37
# NEGGIV
# 0308

# %%
documents = {}

for pdf in DOWNLOAD_DIR.glob("*.pdf"):

    txt = ""

    with pdfplumber.open(pdf) as p:

        for page in p.pages:

            t = page.extract_text()

            if t:
                txt += t + "\n"

    documents[pdf.stem] = txt

print(len(documents), "PDF loaded")
# Out:
# 36 PDF loaded

# %%
import pdfplumber

pdf = DOWNLOAD_DIR / "s3.pdf"

with pdfplumber.open(pdf) as p:

    page = p.pages[0]

    tables = page.extract_tables()

print(f"{len(tables)} tables found")
# Out:
# 1 tables found

# %%
table = tables[0]

for row in table[:20]:
    print(row)

import pandas as pd

df = pd.DataFrame(table)

print(df.shape)
df.head(20)
# Out:
# [None, 'MÅNDAG–TORSDAG', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ['FARTYG', 'NERAXAS', 'ÖREVLIS', 'NEGGIV', 'TÅB-V', None, 'ÖREVLIS', None, 'NEGGIV', 'TÅB-V', None, 'NEGGIV', 'TÅB-V', 'NEGGIV', 'ÖREBIV', 'ÖREVLIS', 'NEGGIV', 'ÖDMRÄV', None, 'ÖREVLIS', None, 'NEGGIV', 'ÖXAV', None, 'NEGGIV', 'ÖREBIV', 'RÄKSROTS', None]
# ['TURNUMMER', '0303', '0300', '0309', '1401', None, '0320', None, '0309', '1405', None, '0315', '1305', '0319', '0303', '0300', '0309', '1421', None, '0320', None, '0309', '1425', None, '0315', '1225', '0925', None]
# ['ANMÄRKNING', '', '', '', '', None, '', None, '', '', None, '', '', '', '', '', '', '', None, '', None, '', '', None, '', '', '', None]
# [None, '', '', '', '07.45', None, '', None, '', '13.00', None, '', '17.00', '', '', '', '', '07.45', None, '', None, '', '13.00', None, '', '', '16.45', None]
# [None, '', '', '', '', '', '', None, '', '', '', '', '17.03p', '', '', '', '', '', '', '', None, '', '', '', '', '', '', '']
# [None, '', '', '', '08.00', None, '', None, '', '13.17', None, '', '17.19', '', '', '', '', '08.00', None, '', None, '', '13.17', None, '', '16.47', '', '']
# [None, '', '', '', '08.10', None, '08.15z', None, '', '13.27', None, '', '17.32', '', '', '', '', '08.10', None, '08.15z', None, '', '13.27', None, '', '16.57', '17.15', None]
# [None, '', '', '', '', None, '08.10z', None, '', '13.32', None, '', '17.37', '', '', '', '', '', None, '08.10z', None, '', '13.32', None, '', '17.02', '17.20', None]
# [None, '', '', '', '', None, '', '', '', '14.00', None, '', '18.09', '', '', '', '', '', None, '', '', '', '14.00', None, '', '17.30', '17.55', None]
# [None, '06.28', '', '08.10', '', None, '', '', '', '', None, '14.10', '', '18.10', '06.28', '', '08.10', '', None, '', '', '', '', None, '14.10', '', '', None]
# [None, '06.45', '06.45', '08.32', '', None, '', '', '', '', None, '14.30', '', '18.30', '06.45', '06.45', '08.32', '', None, '', '', '', '', None, '14.30', '', '', None]
# [None, '', '07.00b', '08.37b', '', None, '', '', '09.32z', '', None, '14.35b', '', '18.40b', '', '07.00b', '08.37b', '', None, '', '', '09.32z', '', None, '14.35b', '', '', None]
# [None, '', 'X', 'X', '', None, '', '', '09.29z', '', None, 'X', '', 'X', '', 'X', 'X', '', None, '', '', '09.29z', '', None, 'X', '', '', None]
# [None, '', 'X', 'X', '', None, '', '', '09.26z', '', None, 'X', '', 'X', '', 'X', 'X', '', None, '', '', '09.26z', '', None, 'X', '', '', None]
# [None, '', '07.10', '08.47', '', None, '', '', '09.25z', '', None, '14.45', '', '18.50', '', '07.10', '08.47', '', None, '', '', '09.25z', '', None, '14.45', '', '', None]
# [None, '', '07.20', '08.55', '', None, '08.50', None, '08.55z', '', None, '14.55', '', '19.00', '', '07.20', '08.55', '', None, '08.50', None, '08.55z', '', None, '14.55', '', '', None]
# [None, '', '', '09.10', '', None, '', None, '09.10', '', None, '15.10', '', '19.15', '', '', '09.10', '', None, '', None, '09.10', '', None, '15.10', '', '', None]
# (18, 28)
#             0               1        2       3      4     5        6     7   \
# 0         None  MÅNDAG–TORSDAG     None    None   None  None     None  None
# 1       FARTYG         NERAXAS  ÖREVLIS  NEGGIV  TÅB-V  None  ÖREVLIS  None
# 2    TURNUMMER            0303     0300    0309   1401  None     0320  None
# 3   ANMÄRKNING                                          None           None
# 4         None                                   07.45  None           None
# 5         None                                                         None
# 6         None                                   08.00  None           None
# 7         None                                   08.10  None   08.15z  None
# 8         None                                          None   08.10z  None
# 9         None                                          None
# 10        None           06.28            08.10         None
# 11        None           06.45    06.45   08.32         None
# 12        None                   07.00b  08.37b         None
# 13        None                        X       X         None
# 14        None                        X       X         None
# 15        None                    07.10   08.47         None
# 16        None                    07.20   08.55         None    08.50  None
# 17        None                            09.10         None           None
#
#         8      9   ...    18       19    20      21     22    23      24  \
# 0     None   None  ...  None     None  None    None   None  None    None
# 1   NEGGIV  TÅB-V  ...  None  ÖREVLIS  None  NEGGIV   ÖXAV  None  NEGGIV
# 2     0309   1405  ...  None     0320  None    0309   1425  None    0315
# 3                  ...  None           None                 None
# 4           13.00  ...  None           None          13.00  None
# 5                  ...                 None
# 6           13.17  ...  None           None          13.17  None
# 7           13.27  ...  None   08.15z  None          13.27  None
# 8           13.32  ...  None   08.10z  None          13.32  None
# 9           14.00  ...  None                         14.00  None
# 10                 ...  None                                None   14.10
# 11                 ...  None                                None   14.30
# 12  09.32z         ...  None                 09.32z         None  14.35b
# 13  09.29z         ...  None                 09.29z         None       X
# 14  09.26z         ...  None                 09.26z         None       X
# 15  09.25z         ...  None                 09.25z         None   14.45
# 16  08.55z         ...  None    08.50  None  08.55z         None   14.55
# 17   09.10         ...  None           None   09.10         None   15.10
#
#         25        26    27
# 0     None      None  None
# 1   ÖREBIV  RÄKSROTS  None
# 2     1225      0925  None
# 3                     None
# 4              16.45  None
# 5
# 6    16.47
# 7    16.57     17.15  None
# 8    17.02     17.20  None
# 9    17.30     17.55  None
# 10                    None
# 11                    None
# 12                    None
# 13                    None
# 14                    None
# 15                    None
# 16                    None
# 17                    None
#
# [18 rows x 28 columns]
