# %% [markdown]
# ## 391_SAT_ID_ref_stockholmarchipelagotrail
# * [#391](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/391)
# * denna Notebook [391_SAT_ID_ref_stockholmarchipelagotrail.ipynb](https://github.com/salgo60/Stockholm_Archipelago_Trail/tree/main/Notebook/391_SAT_ID_ref_stockholmarchipelagotrail.ipynb)
# * [ref:stockholmarchipelagotrail](https://wiki.openstreetmap.org/wiki/Sv:Key:ref:stockholmarchipelagotrail)
#
# ### Statistik
#
#
# | Tidpunkt | SAT | OSM `unknown` | OSM med värde |
# |----------|----:|--------------:|--------------:|
# | 2026-06-13 13:31 | 326 | 126 | 436 |
# | 2026-06-13 17:08 | 326 | 139 | 437 |
# | 2026-06-15 22:27 | 338 | 216 | 656 |

# %%
import time
import datetime  
start_time = time.time()
start_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
print(f"Started: {start_str}")
# Out:
# Started: 2026-06-15 22:27

# %% [markdown]
# ### antal objekt OSM
# * antal unknow

# %%
import requests

OVERPASS_URL = "https://overpass-api.de/api/interpreter"

query = """
[out:json][timeout:120];

// Alla objekt med ref:stockholmarchipelagotrail
nwr["ref:stockholmarchipelagotrail"]->.all;

// De med värdet "unknown"
nwr["ref:stockholmarchipelagotrail"="unknown"]->.unknown;

// Alla övriga
(.all; - .unknown;)->.known;

// Returnera endast räkningar
.unknown out count;
.known out count;
.all out count;
"""

headers = {
    "User-Agent": "MagnusOSMTools/1.0 (https://github.com/salgo60 salgo60@msn.com)"
}

response = requests.post(
    OVERPASS_URL,
    data={"data": query},
    headers=headers,
    timeout=180,
)

response.raise_for_status()

results = response.json()["elements"]

labels = [
    "unknown",
    "known (ej unknown)",
    "alla med ref:stockholmarchipelagotrail",
]

for label, result in zip(labels, results):
    tags = result["tags"]
    print(f"\n{label}")
    print(f"  Nodes:     {tags['nodes']}")
    print(f"  Ways:      {tags['ways']}")
    print(f"  Relations: {tags['relations']}")
    print(f"  Total:     {tags['total']}")
# Out:
# unknown
#   Nodes:     123
#   Ways:      77
#   Relations: 16
#   Total:     216
#
# known (ej unknown)
#   Nodes:     343
#   Ways:      94
#   Relations: 3
#   Total:     440
#
# alla med ref:stockholmarchipelagotrail
#   Nodes:     466
#   Ways:      171
#   Relations: 19
#   Total:     656

# %%
OSM_unknown_nodes = results[0]["tags"]["total"]
OSM_nodes_with_SAT = results[1]["tags"]["total"]
all_OSM_nodes = results[2]["tags"]["total"]

print(f"Unknown nodes: {OSM_unknown_nodes}")
print(f"Nodes with SAT:   {OSM_nodes_with_SAT}")
print(f"All nodes:    {all_OSM_nodes}")
# Out:
# Unknown nodes: 216
# Nodes with SAT:   440
# All nodes:    656

# %% [markdown]
# ### Antal objekt SAT geojson fil

# %%
# Läs GeoJSON
url = "https://map.stockholmarchipelagotrail.com/data/geojson/pois.geojson"
geojson = requests.get(url).json()

checksSAT = []

for feature in geojson["features"]:
    props = feature["properties"]

    sat_id = props["id"]

    osm_ref = None
    for item in props.get("sameAs", []):
        if item.startswith("osm:"):
            osm_ref = item
            break

    if osm_ref is None:
        continue

    _, osm_type, osm_id = osm_ref.split(":")

    checksSAT.append({
        "type": osm_type,
        "id": osm_id,
        "expected_ref": sat_id
    })

all_SAT_nodes = len(checksSAT)
print(f"Antal SAT objekt att kontrollera: {all_SAT_nodes}")
# Out:
# Antal SAT objekt att kontrollera: 338

# %% [markdown]
# ## Resultat sista körningen
# * antal noder [SAT geojson](https://map.stockholmarchipelagotrail.com/data/geojson/pois.geojson)
# * OSM ref_stockholmarchipelagotrail = unknown
#   * noder med ref_stockholmarchipelagotrail som ej finns kopplade till SAT = unknown
# * antal noder i OSM med [ref_stockholmarchipelagotrail](https://overpass-turbo.eu/s/2rzp) / [karta](https://overpass-turbo.eu/s/2rzr)
#
# Se även tags

# %%
print(f"| {start_str} | {all_SAT_nodes} | {OSM_unknown_nodes} | {all_OSM_nodes} |")
# Out:
# | 2026-06-15 22:27 | 338 | 216 | 656 |

# %% [markdown]
# * jämför objekt i SAT geojson med OSM

# %%
from IPython.display import HTML, display

osm_lookup = {e["expected_ref"]: e for e in checksSAT}

rows = []

for feature in geojson["features"]:
    props = feature["properties"]
    sat_id = props["id"]

    if sat_id in osm_lookup:
        status = "✅ ok"
        osm = osm_lookup[sat_id]

        osm_link = (
            f"<a href='https://www.openstreetmap.org/{osm['type']}/{osm['id']}' "
            f"target='_blank'>{osm['type']}/{osm['id']}</a>"
        )

        unknown = (
            "⚠️ unknown"
            if osm.get("osm_ref") == "unknown"
            else ""
        )
    else:
        status = "❌ false"
        osm_link = ""
        unknown = ""

    rows.append(
        f"""
        <tr>
            <td>{status}</td>
            <td>{unknown}</td>
            <td>{sat_id}</td>
            <td>{props.get('name', '')}</td>
            <td>{osm_link}</td>
        </tr>
        """
    )

html = f"""
<table border="1">
    <tr>
        <th>Status</th>
        <th>OSM ref=unknown</th>
        <th>SAT ID</th>
        <th>Namn</th>
        <th>OSM</th>
    </tr>
    {''.join(rows)}
</table>
"""

display(HTML(html))
# Out:
# <table border="1">
#     <tr>
#         <th>Status</th>
#         <th>OSM ref=unknown</th>
#         <th>SAT ID</th>
#         <th>Namn</th>
#         <th>OSM</th>
#     </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:y2cyg</td>
#             <td>STF Finnhamns Vandrarhem</td>
#             <td><a href='https://www.openstreetmap.org/node/268908517' target='_blank'>node/268908517</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:n6mfb</td>
#             <td>Finnhamm Lanthandel</td>
#             <td><a href='https://www.openstreetmap.org/node/268910308' target='_blank'>node/268910308</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:w3rmg</td>
#             <td>Finnhamns café-krog</td>
#             <td><a href='https://www.openstreetmap.org/node/268910309' target='_blank'>node/268910309</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:sjwtd</td>
#             <td>Hamnboden</td>
#             <td><a href='https://www.openstreetmap.org/node/424073481' target='_blank'>node/424073481</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:z3q4b</td>
#             <td>Toalett</td>
#             <td><a href='https://www.openstreetmap.org/node/426925731' target='_blank'>node/426925731</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:9rwwe</td>
#             <td>Utö bykrog</td>
#             <td><a href='https://www.openstreetmap.org/node/435190209' target='_blank'>node/435190209</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:ftdh5</td>
#             <td>Svartsö Lanthandel</td>
#             <td><a href='https://www.openstreetmap.org/node/436368336' target='_blank'>node/436368336</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:jwkmw</td>
#             <td>Hamncaféet</td>
#             <td><a href='https://www.openstreetmap.org/node/443132453' target='_blank'>node/443132453</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:5a9dh</td>
#             <td>Hotell Furusund</td>
#             <td><a href='https://www.openstreetmap.org/node/443132454' target='_blank'>node/443132454</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:zt9z4</td>
#             <td>Furusundsmacken</td>
#             <td><a href='https://www.openstreetmap.org/node/443132455' target='_blank'>node/443132455</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:ca4g2</td>
#             <td>Vårdkasen</td>
#             <td><a href='https://www.openstreetmap.org/node/683821642' target='_blank'>node/683821642</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:dht6w</td>
#             <td>Sandhamns bageri</td>
#             <td><a href='https://www.openstreetmap.org/node/794630735' target='_blank'>node/794630735</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:5wbha</td>
#             <td>Tempo Sandhamn Westerberg</td>
#             <td><a href='https://www.openstreetmap.org/node/794630737' target='_blank'>node/794630737</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:8bqsq</td>
#             <td>Dykarbaren</td>
#             <td><a href='https://www.openstreetmap.org/node/794630742' target='_blank'>node/794630742</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:enxxz</td>
#             <td>Sandhamns värdshus</td>
#             <td><a href='https://www.openstreetmap.org/node/794630763' target='_blank'>node/794630763</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:agrak</td>
#             <td>Sandhamns värdshus</td>
#             <td><a href='https://www.openstreetmap.org/node/794630768' target='_blank'>node/794630768</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:nhheb</td>
#             <td>Vandrarhem Bull-August gård</td>
#             <td><a href='https://www.openstreetmap.org/node/802627515' target='_blank'>node/802627515</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:t5tb5</td>
#             <td>Arholma Nord</td>
#             <td><a href='https://www.openstreetmap.org/node/802627527' target='_blank'>node/802627527</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:embmb</td>
#             <td>Svartsö Krog</td>
#             <td><a href='https://www.openstreetmap.org/node/822527382' target='_blank'>node/822527382</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:f6vsy</td>
#             <td>Dricksvatten</td>
#             <td><a href='https://www.openstreetmap.org/node/822563176' target='_blank'>node/822563176</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:mxxwb</td>
#             <td>Dricksvatten</td>
#             <td><a href='https://www.openstreetmap.org/node/863394662' target='_blank'>node/863394662</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:x5n34</td>
#             <td>Framfickan</td>
#             <td><a href='https://www.openstreetmap.org/node/863394727' target='_blank'>node/863394727</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:hr6cm</td>
#             <td>Hulda</td>
#             <td><a href='https://www.openstreetmap.org/node/863394740' target='_blank'>node/863394740</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:qkzkf</td>
#             <td>Jenny</td>
#             <td><a href='https://www.openstreetmap.org/node/863394751' target='_blank'>node/863394751</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:5t7sg</td>
#             <td>Linn</td>
#             <td><a href='https://www.openstreetmap.org/node/863394827' target='_blank'>node/863394827</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:s5w7y</td>
#             <td>Elsa</td>
#             <td><a href='https://www.openstreetmap.org/node/863423228' target='_blank'>node/863423228</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:36hxc</td>
#             <td>Misse</td>
#             <td><a href='https://www.openstreetmap.org/node/863423239' target='_blank'>node/863423239</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:nc7p6</td>
#             <td>Sara</td>
#             <td><a href='https://www.openstreetmap.org/node/863423311' target='_blank'>node/863423311</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:69m8t</td>
#             <td>Sandhamns Hotell</td>
#             <td><a href='https://www.openstreetmap.org/node/864356451' target='_blank'>node/864356451</a></td>
#         </tr>
#
#         <tr>
#             <td>✅ ok</td>
#             <td></td>
#             <td>sat:poi:nmey8</td>
#             <td>Strindbergsgården</td>
#             <td><a

# %% [markdown]
# ### Sök ut wd och kolla om koppling osm finns
# * kolla om OSM har ref:stockholmarchipelagotrail
# * [SPARQL](https://w.wiki/R9Q2)

# %%
# saknar OSM 
import requests
import pandas as pd

query = """
SELECT DISTINCT
  # ?id
  # ?idLabel
  # ?geo
WHERE {
  # ?id wdt:P6104 wd:Q134294510 ;
      wdt:P625 ?geo .

  FILTER NOT EXISTS { ?id wdt:P11693 ?osmNode . }
  FILTER NOT EXISTS { ?id wdt:P10689 ?osmWay . }
  FILTER NOT EXISTS { ?id wdt:P402 ?osmRelation . }

  OPTIONAL { ?id wdt:P18 ?img . }

  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,de,en" .
  }
}
"""

url = "https://query.wikidata.org/sparql"
headers = {
    "Accept": "application/sparql-results+json",
    "User-Agent": "MagnusOSMTools/1.0 salgo60@msn.com"
}

response = requests.get(
    url,
    params={"query": query},
    headers=headers
)
response.raise_for_status()

data = response.json()["results"]["bindings"]

rows = []
for row in data:
    rows.append({
        "QID": row["id"]["value"].split("/")[-1],
        "Wikidata": row["id"]["value"],
        "idLabel": row.get("idLabel", {}).get("value", ""),
        "Koordinater": row.get("geo", {}).get("value", ""),
    })

df = pd.DataFrame(rows)

df["Wikidata"] = df["QID"].apply(
    lambda q: f'<a href="https://www.wikidata.org/wiki/{q}" target="_blank">{q}</a>'
)

from IPython.display import HTML
print("Saknar OSM objekt")
HTML(df.to_html(escape=False, index=False))
# Out:
# Saknar OSM objekt
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>QID</th>
#       <th>Wikidata</th>
#       <th>idLabel</th>
#       <th>Koordinater</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Q115371401</td>
#       <td><a href="https://www.wikidata.org/wiki/Q115371401" target="_blank">Q115371401</a></td>
#       <td>Arholma kyrkogård</td>
#       <td>Point(19.110433 59.846011)</td>
#     </tr>
#     <tr>
#       <td>Q32301589</td>
#       <td><a href="https://www.wikidata.org/wiki/Q32301589" target="_blank">Q32301589</a></td>
#       <td>Nåttaröhals</td>
#       <td>Point(18.104166666 58.858333333)</td>
#     </tr>
#     <tr>
#       <td>Q136756996</td>
#       <td><a href="https://www.wikidata.org/wiki/Q136756996" target="_blank">Q136756996</a></td>
#       <td>Gamla skolhuset</td>
#       <td>Point(18.321663 58.969196)</td>
#     </tr>
#     <tr>
#       <td>Q134580717</td>
#       <td><a href="https://www.wikidata.org/wiki/Q134580717" target="_blank">Q134580717</a></td>
#       <td>Solberga gård Runmarö kajak uthyrning</td>
#       <td>Point(18.758125 59.255867)</td>
#     </tr>
#     <tr>
#       <td>Q1480015</td>
#       <td><a href="https://www.wikidata.org/wiki/Q1480015" target="_blank">Q1480015</a></td>
#       <td>Landsort</td>
#       <td>Point(17.8658 58.739603)</td>
#     </tr>
#     <tr>
#       <td>Q31895480</td>
#       <td><a href="https://www.wikidata.org/wiki/Q31895480" target="_blank">Q31895480</a></td>
#       <td>Edesnäs</td>
#       <td>Point(18.280694 58.954111)</td>
#     </tr>
#     <tr>
#       <td>Q133884947</td>
#       <td><a href="https://www.wikidata.org/wiki/Q133884947" target="_blank">Q133884947</a></td>
#       <td>Brottö kulturreservat</td>
#       <td>Point(18.727369 59.465922)</td>
#     </tr>
#     <tr>
#       <td>Q33108886</td>
#       <td><a href="https://www.wikidata.org/wiki/Q33108886" target="_blank">Q33108886</a></td>
#       <td>Yxlö</td>
#       <td>Point(18.838957892 59.607897461)</td>
#     </tr>
#     <tr>
#       <td>Q30315439</td>
#       <td><a href="https://www.wikidata.org/wiki/Q30315439" target="_blank">Q30315439</a></td>
#       <td>Sandhamns tullhus</td>
#       <td>Point(18.9147 59.28964)</td>
#     </tr>
#     <tr>
#       <td>Q135087816</td>
#       <td><a href="https://www.wikidata.org/wiki/Q135087816" target="_blank">Q135087816</a></td>
#       <td>Runmarö rum</td>
#       <td>Point(18.738225 59.277144)</td>
#     </tr>
#     <tr>
#       <td>Q133848057</td>
#       <td><a href="https://www.wikidata.org/wiki/Q133848057" target="_blank">Q133848057</a></td>
#       <td>Telegrafberget</td>
#       <td>Point(18.392811 59.078534)</td>
#     </tr>
#     <tr>
#       <td>Q135091732</td>
#       <td><a href="https://www.wikidata.org/wiki/Q135091732" target="_blank">Q135091732</a></td>
#       <td>Christiansborg</td>
#       <td>Point(18.915802 59.661619)</td>
#     </tr>
#     <tr>
#       <td>Q136750853</td>
#       <td><a href="https://www.wikidata.org/wiki/Q136750853" target="_blank">Q136750853</a></td>
#       <td>Fartyget Heimdal grundstötning på Stångskär</td>
#       <td>Point(17.866902 58.736027)</td>
#     </tr>
#     <tr>
#       <td>Q136750195</td>
#       <td><a href="https://www.wikidata.org/wiki/Q136750195" target="_blank">Q136750195</a></td>
#       <td>Pegelhus, Landsort</td>
#       <td>Point(17.865311 58.742244)</td>
#     </tr>
#     <tr>
#       <td>Q136747873</td>
#       <td><a href="https://www.wikidata.org/wiki/Q136747873" target="_blank">Q136747873</a></td>
#       <td>Fiskodling Ålö</td>
#       <td>Point(18.192544 58.91826)</td>
#     </tr>
#     <tr>
#       <td>Q136207068</td>
#       <td><a href="https://www.wikidata.org/wiki/Q136207068" target="_blank">Q136207068</a></td>
#       <td>Bastuflotte Sandhamn</td>
#       <td>Point(18.919787 59.288055)</td>
#     </tr>
#     <tr>
#       <td>Q30242782</td>
#       <td><a href="https://www.wikidata.org/wiki/Q30242782" target="_blank">Q30242782</a></td>
#       <td>Berg</td>
#       <td>Point(18.880555314 59.406674892)</td>
#     </tr>
#     <tr>
#       <td>Q136207103</td>
#       <td><a href="https://www.wikidata.org/wiki/Q136207103" target="_blank">Q136207103</a></td>
#       <td>Sandhamns hotell, bastu</td>
#       <td>Point(18.9190525 59.2875587)</td>
#     </tr>
#     <tr>
#       <td>Q133864464</td>
#       <td><a href="https://www.wikidata.org/wiki/Q133864464" target="_blank">Q133864464</a></td>
#       <td>Svartsö Hembygdsgård</td>
#       <td>Point(18.659173888 59.438761111)</td>
#     </tr>
#     <tr>
#       <td>Q10531797</td>
#       <td><a href="https://www.wikidata.org/wiki/Q10531797" target="_blank">Q10531797</a></td>
#       <td>Hässelmara</td>
#       <td>Point(18.40277778 59.0825)</td>
#     </tr>
#     <tr>
#       <td>Q134691316</td>
#       <td><a href="https://www.wikidata.org/wiki/Q134691316" target="_blank">Q134691316</a></td>
#       <td>Nåttarö gård och resort</td>
#       <td>Point(18.113120096 58.879360239)</td>
#     </tr>
#     <tr>
#       <td>Q133567320</td>
#       <td><a href="https://www.wikidata.org/wiki/Q133567320" target="_blank">Q133567320</a></td>
#       <td>Vita stigen, Nämdö</td>
#       <td>Point(18.671023 59.185289)</td>
#     </tr>
#     <tr>
#       <td>Q136437056</td>
#       <td><a href="https://www.wikidata.org/wiki/Q136437056" target="_blank">Q136437056</a></td>
#       <td>Affärshuset, Utö</td>
#       <td>Point(18.321682 58.969177)</td>
#     </tr>
#     <tr>
#       <td>Q81263800</td>
#       <td><a href="https://www.wikidata.org/wiki/Q81263800" target="_blank">Q81263800</a></td>
#       <td>Batteri Sandö-Oxudde</td>
#       <td>Point(18.904166666 59.280555555)</td>
#     </tr>
#     <tr>
#       <td>Q134713455</td>
#       <td><a href="https://www.wikidata.org/wiki/Q134713455" target="_blank">Q134713455</a></td>
#       <td>Möja gästhamn kyrkviken</td>
#       <td>Point(18.883862 59.406021)</td>
#     </tr>
#     <tr>
#       <td>Q134721504</td>
#       <td><a href="https://www.wikidata.org/wiki/Q134721504" target="_blank">Q134721504</a></td>
#       <td>Idholmens bondgård</td>
#       <td>Point(18.815439 59.482821)</td>
#     </tr>
#     <tr>
#       <td>Q134727664</td>
#       <td><a href="https://www.wikidata.org/wiki/Q134727664" target="_blank">Q134727664</a></td>
#       <td>minkfarm, Lidö</td>
#       <td>Point(19.08162 59.78115)</td>
#     </tr>
#     <tr>
#       <td>Q135012404</td>
#       <td><a href="https://www.wikidata.org/wiki/Q135012404" target="_blank">Q135012404</a></td>
#       <td>Landsort badplats</td>
#       <td>Point(17.868624 58.748143)</td>
#     </tr>
#     <tr>
#       <td>Q10711619</td>
#       <td><a href="https://www.wikidata.org/wiki/Q10711619" target="_blank">Q10711619</a></td>
#       <td>Utö gruvor</td>
#       <td>Point(18.32972222 58.96611111)</td>
#     </tr>
#     <tr>
#       <td>Q135226435</td>
#       <td><a href="https://www.wikidata.org/wiki/Q135226435" target="_blank">Q135226435</a></td>
#       <td>Västerudd, Sandhamn</td>
#       <td>Point(18.896411 59.290883)</td>
#     </tr>
#     <tr>
#       <td>Q135443007</td>
#       <td><a href="https://www.wikidata.org/wiki/Q135443007" target="_blank">Q135443007</a></td>
#       <td>Brunströms bod i Berg</td>
#       <td>Point(18.885354386 59.406727545)</td>
#     </tr>
#     <tr>
#       <td>Q135152596</td>
#       <td><a href="https://www.wikidata.org/wiki/Q135152596" target="_blank">Q135152596</a></td>
#       <td>Sundby Gård gårdsbutik</td>
#       <td>Point(18.390091765 59.031817213)</td>
#     </tr>
#     <tr>
#       <td>Q106575390</td>
#       <td><a href="https://www.wikidata.org/wiki/Q106575390" target="_blank">Q106575390</a></td>
#       <td>Möja Bio</td>
#       <td>Point(18.887258 59.410937)</td>
#     </tr>
#     <tr>
#       <td>Q135153326</td>
#       <td><a href="https://www.wikidata.org/wiki/Q135153326" target="_blank">Q135153326</a></td>
#       <td>Gästbryggan vid Ornö Båtvarv, Brunnsviken</td>
#       <td>Point(18.373666666 59.036833333)</td>
#     </tr>
#     <tr>
#       <td>Q33108739</td>
#       <td><a href="https://www.wikidata.org/wiki/Q33108739" target="_blank">Q33108739</a></td>
#       <td>Ornö</td>
#       <td>Point(18.426471648 59.047595851)</td>
#     </tr>
#     <tr>
#       <td>Q115094918</td>
#       <td><a href="https://www.wikidata.org/wiki/Q115094918" target="_blank">Q115094918</a></td>
#       <td>Långvik yttre badplats</

# %%
import requests
import time
from tqdm.notebook import tqdm

OVERPASS_URL = "https://overpass-api.de/api/interpreter"

headers = {
    "User-Agent": "MagnusOSMTools/1.0 (salgo60@msn.com)"
}

osm_ref = []
osm_link = []

for qid in tqdm(df["QID"], total=len(df), desc="Kontrollerar OSM"):
    query = f"""
    [out:json][timeout:250];
    nwr["ref:stockholmarchipelagotrail"="{qid}"];
    out ids;
    """

    try:
        r = requests.post(OVERPASS_URL, data=query, headers=headers)
        r.raise_for_status()
        elements = r.json().get("elements", [])

        if elements:
            e = elements[0]
            osm_type = e["type"]  # node, way eller relation
            osm_id = e["id"]

            osm_ref.append("Ja")
            osm_link.append(
                f'<a href="https://www.openstreetmap.org/{osm_type}/{osm_id}" '
                f'target="_blank">{osm_type}/{osm_id}</a>'
            )
        else:
            osm_ref.append("Nej")
            osm_link.append("")

    except Exception as ex:
        osm_ref.append(f"Fel: {ex}")
        osm_link.append("")

    # Var snäll mot Overpass-servern
    time.sleep(40)

df["OSM_ref"] = osm_ref
df["OSM_länk"] = osm_link

from IPython.display import HTML
HTML(df.to_html(escape=False, index=False))
# Out:
# Kontrollerar OSM:   0%|          | 0/51 [00:00<?, ?it/s]

# %%
end_time = time.time()
duration = end_time - start_time

print(f"Fini§shed in {duration:.2f} seconds.")
