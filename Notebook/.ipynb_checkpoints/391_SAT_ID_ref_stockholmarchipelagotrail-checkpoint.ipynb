# %% [markdown]
# ## 391_SAT_ID_ref_stockholmarchipelagotrail
# * [#391](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/391)
# * denna Notebook [391_SAT_ID_ref_stockholmarchipelagotrail.ipynb](https://github.com/salgo60/Stockholm_Archipelago_Trail/tree/main/Notebook/391_SAT_ID_ref_stockholmarchipelagotrail.ipynb)
# * [ref:stockholmarchipelagotrail](https://wiki.openstreetmap.org/wiki/Sv:Key:ref:stockholmarchipelagotrail)
#
# ### Statistik
#
#
# | Tidpunkt | SAT OSM | OSM `unknown` | OSM med värde | SAT POI created date |
# |----------|----:|--------------:|--------------:|--------------:|
# | 2026-06-13 13:31 | 326 | 126 | 436 |
# | 2026-06-13 17:08 | 326 | 139 | 437 |
# | 2026-06-15 22:27 | 338 | 216 | 656 |
# | 2026-06-18 09:59 | 338 | 217 | 676 |
# | 2026-06-24 05:26 | 380 | 207 | 697 |
# | 2026-06-26 09:18 | 391 | 209 | 725 |
# | 2026-06-26 19:51 | 470 | 194 | 732 |
# | 2026-07-01 07:00 | 470 | 188 | 735 |
# | 2026-07-02 10:06 | 510 | 186 | 743 |
# | 2026-07-04 13:37 | 510 | 160 | 786 |
# | 2026-07-06 20:20 | 521 | 158 | 797 |
# | 2026-07-11 02:12 | 558 | 157 | 829 |
# | 2026-07-11 16:39 | 558 | 160 | 833 |
# | 2026-07-15 11:47 | 574 | 162 | 835 |
# | 2026-07-18 16:38 | 577 | 165 | 776 |
# | 2026-07-20 21:34 | 586 | 178 | 861 |
# | 2026-07-27 13:38 | 589 | 162 | 916 |
# | 2026-07-28 10:05 | 589 | 162 | 919 | 2026-07-27 08:07 |

# %%
import time
import datetime  
start_time = time.time()
start_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
print(f"Started: {start_str}")
# Out:
# Started: 2026-07-28 10:05

# %% [markdown]
# ### antal objekt OSM
# * antal unknow

# %%
import requests

OVERPASS_URL = "https://overpass.kumi.systems/api/interpreter"
OVERPASS_URL = "https://overpass-api.de/api/interpreter"
query = """
[out:json][timeout:120];

nwr["ref:stockholmarchipelagotrail"="unknown"];
out count;

nwr["ref:stockholmarchipelagotrail"]["ref:stockholmarchipelagotrail"!="unknown"];
out count;

nwr["ref:stockholmarchipelagotrail"];
out count;
"""

headers = {
    "User-Agent": "MagnusOSMTools/1.0 (https://github.com/salgo60 salgo60@msn.com)"
}

response = requests.post(
    OVERPASS_URL,
    data={"data": query},
    headers=headers,
    timeout=380,
)

response.raise_for_status()

results = response.json()["elements"]

OSM_unknown = int(results[0]["tags"]["total"])
OSM_with_SAT = int(results[1]["tags"]["total"])
OSM_total = int(results[2]["tags"]["total"])

print(f"Unknown:        {OSM_unknown}")
print(f"Known with SAT: {OSM_with_SAT}")
print(f"Total with SAT: {OSM_total}")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.3.0) or chardet (7.4.3)/charset_normalizer (3.4.1) doesn't match a supported version!
#   warnings.warn(
# Unknown:        162
# Known with SAT: 757
# Total with SAT: 919

# %% [markdown]
# ### Lista unknown

# %%
print(OVERPASS_URL)
#print(len(elements))
# Out:
# https://overpass-api.de/api/interpreter

# %%
print("Sleep 10")
time.sleep(10)
# Out:
# Sleep 10

# %%
import requests
import pandas as pd
from IPython.display import display


#OVERPASS_URL = "https://overpass-api.de/api/interpreter"
#OVERPASS_URL = "https://overpass.kumi.systems/api/interpreter"
query = """
[out:json][timeout:120];

nwr["ref:stockholmarchipelagotrail"="unknown"];
out tags center;
"""
query = """[out:json][timeout:120];
node["ref:stockholmarchipelagotrail"="unknown"];
out ids;
""" 

headers = {
    "User-Agent": "MagnusOSMTools SAT/1.0 (https://github.com/salgo60 salgo60@msn.com)"
}

response = requests.post(
    OVERPASS_URL,
    data={"data": query},
    headers=headers,
    timeout=300,
)

response.raise_for_status()
elements = response.json()["elements"]

rows = []

for el in elements:
    tags = el.get("tags", {})

    island = (
        tags.get("addr:island")
        or tags.get("island")
        or tags.get("place")
        or ""
    )

    rows.append({
        "Ö": island,
        "Namn": tags.get("name", ""),
        "Typ": el["type"],
        "id": el["id"],
        "OSM": f"https://www.openstreetmap.org/{el['type']}/{el['id']}",
    })

df = pd.DataFrame(rows)

df = (
    df.sort_values(["Ö", "Namn", "Typ"])
      .reset_index(drop=True)
)

display(
    df.style.format({
        "OSM": lambda url: f'<a href="{url}" target="_blank">Öppna</a>'
    })
)
# Out:
# Sleep 10
# <style type="text/css">
# </style>
# <table id="T_4e5c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e5c9_level0_col0" class="col_heading level0 col0" >Ö</th>
#       <th id="T_4e5c9_level0_col1" class="col_heading level0 col1" >Namn</th>
#       <th id="T_4e5c9_level0_col2" class="col_heading level0 col2" >Typ</th>
#       <th id="T_4e5c9_level0_col3" class="col_heading level0 col3" >id</th>
#       <th id="T_4e5c9_level0_col4" class="col_heading level0 col4" >OSM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e5c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e5c9_row0_col0" class="data row0 col0" ></td>
#       <td id="T_4e5c9_row0_col1" class="data row0 col1" ></td>
#       <td id="T_4e5c9_row0_col2" class="data row0 col2" >node</td>
#       <td id="T_4e5c9_row0_col3" class="data row0 col3" >800808700</td>
#       <td id="T_4e5c9_row0_col4" class="data row0 col4" ><a href="https://www.openstreetmap.org/node/800808700" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e5c9_row1_col0" class="data row1 col0" ></td>
#       <td id="T_4e5c9_row1_col1" class="data row1 col1" ></td>
#       <td id="T_4e5c9_row1_col2" class="data row1 col2" >node</td>
#       <td id="T_4e5c9_row1_col3" class="data row1 col3" >863394672</td>
#       <td id="T_4e5c9_row1_col4" class="data row1 col4" ><a href="https://www.openstreetmap.org/node/863394672" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e5c9_row2_col0" class="data row2 col0" ></td>
#       <td id="T_4e5c9_row2_col1" class="data row2 col1" ></td>
#       <td id="T_4e5c9_row2_col2" class="data row2 col2" >node</td>
#       <td id="T_4e5c9_row2_col3" class="data row2 col3" >863394760</td>
#       <td id="T_4e5c9_row2_col4" class="data row2 col4" ><a href="https://www.openstreetmap.org/node/863394760" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e5c9_row3_col0" class="data row3 col0" ></td>
#       <td id="T_4e5c9_row3_col1" class="data row3 col1" ></td>
#       <td id="T_4e5c9_row3_col2" class="data row3 col2" >node</td>
#       <td id="T_4e5c9_row3_col3" class="data row3 col3" >2285331215</td>
#       <td id="T_4e5c9_row3_col4" class="data row3 col4" ><a href="https://www.openstreetmap.org/node/2285331215" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4e5c9_row4_col0" class="data row4 col0" ></td>
#       <td id="T_4e5c9_row4_col1" class="data row4 col1" ></td>
#       <td id="T_4e5c9_row4_col2" class="data row4 col2" >node</td>
#       <td id="T_4e5c9_row4_col3" class="data row4 col3" >2544129249</td>
#       <td id="T_4e5c9_row4_col4" class="data row4 col4" ><a href="https://www.openstreetmap.org/node/2544129249" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4e5c9_row5_col0" class="data row5 col0" ></td>
#       <td id="T_4e5c9_row5_col1" class="data row5 col1" ></td>
#       <td id="T_4e5c9_row5_col2" class="data row5 col2" >node</td>
#       <td id="T_4e5c9_row5_col3" class="data row5 col3" >2550380437</td>
#       <td id="T_4e5c9_row5_col4" class="data row5 col4" ><a href="https://www.openstreetmap.org/node/2550380437" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4e5c9_row6_col0" class="data row6 col0" ></td>
#       <td id="T_4e5c9_row6_col1" class="data row6 col1" ></td>
#       <td id="T_4e5c9_row6_col2" class="data row6 col2" >node</td>
#       <td id="T_4e5c9_row6_col3" class="data row6 col3" >2942213742</td>
#       <td id="T_4e5c9_row6_col4" class="data row6 col4" ><a href="https://www.openstreetmap.org/node/2942213742" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4e5c9_row7_col0" class="data row7 col0" ></td>
#       <td id="T_4e5c9_row7_col1" class="data row7 col1" ></td>
#       <td id="T_4e5c9_row7_col2" class="data row7 col2" >node</td>
#       <td id="T_4e5c9_row7_col3" class="data row7 col3" >4239095072</td>
#       <td id="T_4e5c9_row7_col4" class="data row7 col4" ><a href="https://www.openstreetmap.org/node/4239095072" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4e5c9_row8_col0" class="data row8 col0" ></td>
#       <td id="T_4e5c9_row8_col1" class="data row8 col1" ></td>
#       <td id="T_4e5c9_row8_col2" class="data row8 col2" >node</td>
#       <td id="T_4e5c9_row8_col3" class="data row8 col3" >4900324409</td>
#       <td id="T_4e5c9_row8_col4" class="data row8 col4" ><a href="https://www.openstreetmap.org/node/4900324409" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4e5c9_row9_col0" class="data row9 col0" ></td>
#       <td id="T_4e5c9_row9_col1" class="data row9 col1" ></td>
#       <td id="T_4e5c9_row9_col2" class="data row9 col2" >node</td>
#       <td id="T_4e5c9_row9_col3" class="data row9 col3" >4930945229</td>
#       <td id="T_4e5c9_row9_col4" class="data row9 col4" ><a href="https://www.openstreetmap.org/node/4930945229" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4e5c9_row10_col0" class="data row10 col0" ></td>
#       <td id="T_4e5c9_row10_col1" class="data row10 col1" ></td>
#       <td id="T_4e5c9_row10_col2" class="data row10 col2" >node</td>
#       <td id="T_4e5c9_row10_col3" class="data row10 col3" >4936508702</td>
#       <td id="T_4e5c9_row10_col4" class="data row10 col4" ><a href="https://www.openstreetmap.org/node/4936508702" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4e5c9_row11_col0" class="data row11 col0" ></td>
#       <td id="T_4e5c9_row11_col1" class="data row11 col1" ></td>
#       <td id="T_4e5c9_row11_col2" class="data row11 col2" >node</td>
#       <td id="T_4e5c9_row11_col3" class="data row11 col3" >4964697340</td>
#       <td id="T_4e5c9_row11_col4" class="data row11 col4" ><a href="https://www.openstreetmap.org/node/4964697340" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4e5c9_row12_col0" class="data row12 col0" ></td>
#       <td id="T_4e5c9_row12_col1" class="data row12 col1" ></td>
#       <td id="T_4e5c9_row12_col2" class="data row12 col2" >node</td>
#       <td id="T_4e5c9_row12_col3" class="data row12 col3" >5745003236</td>
#       <td id="T_4e5c9_row12_col4" class="data row12 col4" ><a href="https://www.openstreetmap.org/node/5745003236" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4e5c9_row13_col0" class="data row13 col0" ></td>
#       <td id="T_4e5c9_row13_col1" class="data row13 col1" ></td>
#       <td id="T_4e5c9_row13_col2" class="data row13 col2" >node</td>
#       <td id="T_4e5c9_row13_col3" class="data row13 col3" >5749262789</td>
#       <td id="T_4e5c9_row13_col4" class="data row13 col4" ><a href="https://www.openstreetmap.org/node/5749262789" target="_blank">Öppna</a></td>
#     </tr>
#     <tr>
#       <th id="T_4e5c9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4e5c9_row14_col0" class="data row14 col0" ></td>
#       <td id="T_4e5c9_row14_col1" class="data row14 col1" ></td>
#       <td id="T_4e5c9_row14_col2" class="data row14 col2" >node</td>
#       <td id="T_4e5c9_row14_col3" class="data row14 col3" >5860556435</td>

# %%
print(OVERPASS_URL)
print(len(elements))
# Out:
# https://overpass-api.de/api/interpreter
# 108

# %% [markdown]
# ### Antal objekt SAT geojson fil

# %%
import requests

# Läs GeoJSON
url = "https://map.stockholmarchipelagotrail.com/data/geojson/pois.geojson"
geojson = requests.get(url).json()

# Metadata
metadata = geojson.get("metadata", {})

checksSAT = []

for feature in geojson["features"]:
    props = feature["properties"]

    sat_id = props["id"]

    # Hämta tidsstämplar
    updated_at = props.get("updatedAt")
    first_seen = props.get("firstSeen")
    last_seen = props.get("lastSeen")

    osm_ref = None
    for item in props.get("sameAs", []):
        if item.startswith("osm:"):
            osm_ref = item
            break

    if osm_ref is None:
        continue

    _, osm_type, osm_id = osm_ref.split(":")

    checksSAT.append({
        "type": osm_type,
        "id": osm_id,
        "expected_ref": sat_id,
        "updatedAt": updated_at,
        "lastSeen": last_seen,
        "firstSeen": first_seen,
    })
import datetime
all_SAT_nodes = len(checksSAT) 
print(f"Antal SAT objekt att kontrollera: {all_SAT_nodes}") 
generated_at = metadata.get("generatedAt")
formatted = datetime.datetime.strptime(
    generated_at,
    "%Y-%m-%dT%H:%M:%S.%fZ"
).strftime("%Y-%m-%d %H:%M")

print(f"GeoJSON generated at: {formatted}")
# Out:
# Antal SAT objekt att kontrollera: 589
# GeoJSON generated at: 2026-07-27 08:07

# %%
print(datetime)
# Out:
# <module 'datetime' from '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/datetime.py'>

# %%
checksSAT.sort(
    key=lambda x: x["updatedAt"] or "",
    reverse=True
) 
print(sorted(geojson["features"][0]["properties"].keys()))
# Out:
# ['address', 'category', 'description', 'firstSeen', 'id', 'image', 'internet_access', 'name', 'nameLocalized', 'osmChangeset', 'osmVersion', 'passBuyUrl', 'passSells', 'passStamps', 'phone', 'reliability', 'sameAs', 'section', 'source', 'updatedAt', 'website', 'wikidata']

# %%
from urllib.parse import quote
import pandas as pd
from IPython.display import HTML, display

df = pd.DataFrame(checksSAT)

# Senaste först
df = df.sort_values("updatedAt", ascending=False)

# Klickbar länk till kartan
df["expected_ref"] = df["expected_ref"].apply(
    lambda x: (
        f'<a href="https://map.stockholmarchipelagotrail.com/?{x}" '
        f'target="_blank">{x}</a>'
    )
)

# Ny kolumn: JSON-LD/API
df["jsonld"] = df["expected_ref"].str.extract(r'>([^<]+)<')[0].apply(
    lambda x: (
        f'<a href="https://map.stockholmarchipelagotrail.com/api/objects/{quote(x, safe="")}" '
        f'target="_blank">jsonld</a>'
    )
)

display(
    HTML(
        df[
            [
                "updatedAt",
                "lastSeen",
                "firstSeen",
                "expected_ref",
                "jsonld",
                "type",
                "id",
            ]
        ].to_html(escape=False, index=False)
    )
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>updatedAt</th>
#       <th>lastSeen</th>
#       <th>firstSeen</th>
#       <th>expected_ref</th>
#       <th>jsonld</th>
#       <th>type</th>
#       <th>id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:y2cyg" target="_blank">sat:poi:y2cyg</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Ay2cyg" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>268908517</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-26</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:k39nr" target="_blank">sat:poi:k39nr</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Ak39nr" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>227166926</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:4fge7" target="_blank">sat:poi:4fge7</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A4fge7" target="_blank">jsonld</a></td>
#       <td>relation</td>
#       <td>15033302</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-07-01</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:hvm2x" target="_blank">sat:poi:hvm2x</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Ahvm2x" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>1236446195</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:nf7y3" target="_blank">sat:poi:nf7y3</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Anf7y3" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>833809121</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-07-01</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:8n3kf" target="_blank">sat:poi:8n3kf</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A8n3kf" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>504184973</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-07-01</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:vzx7f" target="_blank">sat:poi:vzx7f</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Avzx7f" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>290833701</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:8wtn9" target="_blank">sat:poi:8wtn9</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A8wtn9" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>247542041</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:nhheb" target="_blank">sat:poi:nhheb</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Anhheb" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>802627515</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-07-01</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:t6xyk" target="_blank">sat:poi:t6xyk</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3At6xyk" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>227166923</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:zmh6w" target="_blank">sat:poi:zmh6w</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Azmh6w" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>5745003240</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:eg5ac" target="_blank">sat:poi:eg5ac</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Aeg5ac" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>4958820945</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-07-01</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:zqc9j" target="_blank">sat:poi:zqc9j</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Azqc9j" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>2943477507</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:mfg28" target="_blank">sat:poi:mfg28</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Amfg28" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>2495934893</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:t5tb5" target="_blank">sat:poi:t5tb5</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3At5tb5" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>802627527</td>
#     </tr>
#     <tr>
#       <td>2026-07-26</td>
#       <td>None</td>
#       <td>2026-06-25</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:59xam" target="_blank">sat:poi:59xam</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A59xam" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>13961598974</td>
#     </tr>
#     <tr>
#       <td>2026-07-25</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:6p6hb" target="_blank">sat:poi:6p6hb</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A6p6hb" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>4319184675</td>
#     </tr>
#     <tr>
#       <td>2026-07-24</td>
#       <td>None</td>
#       <td>2026-07-13</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:fzzma" target="_blank">sat:poi:fzzma</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Afzzma" target="_blank">jsonld</a></td>
#       <td>node</td>
#       <td>12925929671</td>
#     </tr>
#     <tr>
#       <td>2026-07-24</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:ts37b" target="_blank">sat:poi:ts37b</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Ats37b" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>1385588405</td>
#     </tr>
#     <tr>
#       <td>2026-07-24</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:kztar" target="_blank">sat:poi:kztar</a></td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Akztar" target="_blank">jsonld</a></td>
#       <td>way</td>
#       <td>229605231</td>
#     </tr>
#     <tr>
#       <td>2026-07-24</td>
#       <td>None</td>
#       <td>2026-06-10</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:fhn5g" target="_blank">sat:poi:fhn5g</a></td>

# %%
from urllib.parse import quote

df2 = pd.DataFrame(checksSAT)

# Skapa jsonld-kolumnen
df2["jsonld"] = df2["expected_ref"].apply(
    lambda x: f"https://map.stockholmarchipelagotrail.com/api/objects/{quote(x, safe='')}"
)

# Sortera efter firstSeen
df2 = df2.sort_values("firstSeen", ascending=False)

display(df2[
    [
        "firstSeen",
        "updatedAt",
        "lastSeen",
        "expected_ref",
        "jsonld",
        "type",
        "id",
    ]
])
# Out:
#       firstSeen   updatedAt lastSeen   expected_ref  \
# 48   2026-07-27  2026-07-22     None  sat:poi:ctepx
# 83   2026-07-27  2026-07-21     None  sat:poi:52fw8
# 114  2026-07-27  2026-07-20     None  sat:poi:nsc7t
# 112  2026-07-27  2026-07-20     None  sat:poi:g88w5
# 113  2026-07-27  2026-07-20     None  sat:poi:spg8j
# ..          ...         ...      ...            ...
# 329  2026-06-10  2026-06-30     None  sat:poi:gjaxf
# 328  2026-06-10  2026-06-30     None  sat:poi:ysez3
# 327  2026-06-10  2026-06-30     None  sat:poi:qgbc4
# 326  2026-06-10  2026-06-30     None  sat:poi:89hz7
# 0    2026-06-10  2026-07-26     None  sat:poi:y2cyg
#
#                                                 jsonld  type           id
# 48   https://map.stockholmarchipelagotrail.com/api/...  node  14038610020
# 83   https://map.stockholmarchipelagotrail.com/api/...  node  14031421382
# 114  https://map.stockholmarchipelagotrail.com/api/...   way   1541011648
# 112  https://map.stockholmarchipelagotrail.com/api/...   way   1424971792
# 113  https://map.stockholmarchipelagotrail.com/api/...   way   1540959335
# ..                                                 ...   ...          ...
# 329  https://map.stockholmarchipelagotrail.com/api/...   way    222170774
# 328  https://map.stockholmarchipelagotrail.com/api/...   way     64790110
# 327  https://map.stockholmarchipelagotrail.com/api/...  node  12958356256
# 326  https://map.stockholmarchipelagotrail.com/api/...  node   6722964356
# 0    https://map.stockholmarchipelagotrail.com/api/...  node    268908517
#
# [589 rows x 7 columns]

# %%
from urllib.parse import quote
from IPython.display import HTML

df = pd.DataFrame(checksSAT)

df["expected_ref"] = df["expected_ref"].apply(
    lambda x: f'<a href="https://map.stockholmarchipelagotrail.com/?{x}" target="_blank">{x}</a>'
)

df["jsonld"] = df["expected_ref"].str.extract(r'>([^<]+)<')[0].apply(
    lambda x: f'<a href="https://map.stockholmarchipelagotrail.com/api/objects/{quote(x, safe="")}" target="_blank">jsonld</a>'
)

df = df.sort_values("firstSeen", ascending=False)

HTML(df.to_html(escape=False, index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>type</th>
#       <th>id</th>
#       <th>expected_ref</th>
#       <th>updatedAt</th>
#       <th>lastSeen</th>
#       <th>firstSeen</th>
#       <th>jsonld</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>node</td>
#       <td>14038610020</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:ctepx" target="_blank">sat:poi:ctepx</a></td>
#       <td>2026-07-22</td>
#       <td>None</td>
#       <td>2026-07-27</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Actepx" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14031421382</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:52fw8" target="_blank">sat:poi:52fw8</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-27</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A52fw8" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>way</td>
#       <td>1541011648</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:nsc7t" target="_blank">sat:poi:nsc7t</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-27</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Ansc7t" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>way</td>
#       <td>1424971792</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:g88w5" target="_blank">sat:poi:g88w5</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-27</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Ag88w5" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>way</td>
#       <td>1540959335</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:spg8j" target="_blank">sat:poi:spg8j</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-27</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Aspg8j" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14023546865</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:5bvfw" target="_blank">sat:poi:5bvfw</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A5bvfw" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14022240647</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:w5jgg" target="_blank">sat:poi:w5jgg</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Aw5jgg" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14027227874</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:s8qkq" target="_blank">sat:poi:s8qkq</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3As8qkq" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14027227875</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:4h53m" target="_blank">sat:poi:4h53m</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A4h53m" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14027506532</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:pm382" target="_blank">sat:poi:pm382</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Apm382" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14026909991</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:gysy6" target="_blank">sat:poi:gysy6</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Agysy6" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14022546073</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:5kssn" target="_blank">sat:poi:5kssn</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A5kssn" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14022481830</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:kwvxw" target="_blank">sat:poi:kwvxw</a></td>
#       <td>2026-07-20</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Akwvxw" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14028200427</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:xvvxc" target="_blank">sat:poi:xvvxc</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Axvvxc" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14028221357</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:9x9zq" target="_blank">sat:poi:9x9zq</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3A9x9zq" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14028221358</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:x3rjc" target="_blank">sat:poi:x3rjc</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Ax3rjc" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>way</td>
#       <td>1540799482</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:qvqz3" target="_blank">sat:poi:qvqz3</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-20</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Aqvqz3" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>way</td>
#       <td>1539761038</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:vjccg" target="_blank">sat:poi:vjccg</a></td>
#       <td>2026-07-18</td>
#       <td>None</td>
#       <td>2026-07-17</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Avjccg" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>13190933132</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:bwsb2" target="_blank">sat:poi:bwsb2</a></td>
#       <td>2026-07-21</td>
#       <td>None</td>
#       <td>2026-07-17</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Abwsb2" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14017263426</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:nb7ca" target="_blank">sat:poi:nb7ca</a></td>
#       <td>2026-07-18</td>
#       <td>None</td>
#       <td>2026-07-16</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/api/objects/sat%3Apoi%3Anb7ca" target="_blank">jsonld</a></td>
#     </tr>
#     <tr>
#       <td>node</td>
#       <td>14014496535</td>
#       <td><a href="https://map.stockholmarchipelagotrail.com/?sat:poi:ptr6q" target="_blank">sat:poi:ptr6q</a></td>

# %%
import pandas as pd

df = pd.DataFrame(checksSAT)
df = df.sort_values("updatedAt", ascending=False)

display(df)
# Out:
#          type          id   expected_ref   updatedAt lastSeen   firstSeen
# 0        node   268908517  sat:poi:y2cyg  2026-07-26     None  2026-06-10
# 9         way   227166926  sat:poi:k39nr  2026-07-26     None  2026-06-26
# 15   relation    15033302  sat:poi:4fge7  2026-07-26     None  2026-06-10
# 14        way  1236446195  sat:poi:hvm2x  2026-07-26     None  2026-07-01
# 13        way   833809121  sat:poi:nf7y3  2026-07-26     None  2026-06-10
# ..        ...         ...            ...         ...      ...         ...
# 584       way   322935628  sat:poi:rxv5b  2025-05-22     None  2026-06-26
# 585       way   771056534  sat:poi:qgkkp  2023-08-30     None  2026-06-26
# 586       way   400255324  sat:poi:z2nrn  2021-07-26     None  2026-06-26
# 587       way   300450539  sat:poi:r88rc  2014-08-27     None  2026-06-26
# 588       way   300450541  sat:poi:5zvqw  2014-08-27     None  2026-06-26
#
# [589 rows x 6 columns]

# %% [markdown]
# ## Resultat sista körningen
# * antal noder [SAT geojson](https://map.stockholmarchipelagotrail.com/data/geojson/pois.geojson)
# * OSM ref_stockholmarchipelagotrail = unknown
#   * noder med ref_stockholmarchipelagotrail som ej finns kopplade till SAT = unknown
# * antal noder i OSM med [ref_stockholmarchipelagotrail](https://overpass-turbo.eu/s/2rzp) / [karta](https://overpass-turbo.eu/s/2rzr)
#
# Se även tags

# %%
print(f"| {start_str} | {all_SAT_nodes} | {OSM_unknown} | {OSM_total} | {formatted} |")  
#print(f"| {start_str} | {all_SAT_nodes} | {OSM_unknown_nodes} | {all_OSM_nodes} |")
# Out:
# | 2026-07-28 10:05 | 589 | 162 | 919 | 2026-07-27 08:07 |

# %% [markdown]
# * jämför objekt i SAT geojson med OSM

# %%
from IPython.display import HTML, display

osm_lookup = {e["expected_ref"]: e for e in checksSAT}

rows = []

for feature in geojson["features"]:
    props = feature["properties"]
    sat_id = props["id"]

    if sat_id in osm_lookup:
        status = "✅ ok"
        osm = osm_lookup[sat_id]

        osm_link = (
            f"<a href='https://www.openstreetmap.org/{osm['type']}/{osm['id']}' "
            f"target='_blank'>{osm['type']}/{osm['id']}</a>"
        )

        unknown = (
            "⚠️ unknown"
            if osm.get("osm_ref") == "unknown"
            else ""
        )
    else:
        status = "❌ false"
        osm_link = ""
        unknown = ""

    rows.append(
        f"""
        <tr>
            <td>{status}</td>
            <td>{unknown}</td>
            <td>{sat_id}</td>
            <td>{props.get('name', '')}</td>
            <td>{osm_link}</td>
        </tr>
        """
    )

html = f"""
<table border="1">
    <tr>
        <th>Status</th>
        <th>OSM ref=unknown</th>
        <th>SAT ID</th>
        <th>Namn</th>
        <th>OSM</th>
    </tr>
    {''.join(rows)}
</table>
"""

display(HTML(html))

# %%
for e in checksSAT:
    if "688nt" in str(e):
        print(e)

# %% [markdown]
# ### Sök ut wd och kolla om koppling osm finns
# * kolla om OSM har ref:stockholmarchipelagotrail
# * [SPARQL](https://w.wiki/R9Q2)

# %%
# saknar OSM 
import requests
import pandas as pd

query = """
SELECT DISTINCT
  # ?id
  # ?idLabel
  # ?geo
WHERE {
  # ?id wdt:P6104 wd:Q134294510 ;
      wdt:P625 ?geo .

  FILTER NOT EXISTS { ?id wdt:P11693 ?osmNode . }
  FILTER NOT EXISTS { ?id wdt:P10689 ?osmWay . }
  FILTER NOT EXISTS { ?id wdt:P402 ?osmRelation . }

  OPTIONAL { ?id wdt:P18 ?img . }

  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv,en,de,en" .
  }
}
"""

url = "https://query.wikidata.org/sparql"
headers = {
    "Accept": "application/sparql-results+json",
    "User-Agent": "MagnusOSMTools/1.0 salgo60@msn.com"
}

response = requests.get(
    url,
    params={"query": query},
    headers=headers
)
response.raise_for_status()

data = response.json()["results"]["bindings"]

rows = []
for row in data:
    rows.append({
        "QID": row["id"]["value"].split("/")[-1],
        "Wikidata": row["id"]["value"],
        "idLabel": row.get("idLabel", {}).get("value", ""),
        "Koordinater": row.get("geo", {}).get("value", ""),
    })

df = pd.DataFrame(rows)

df["Wikidata"] = df["QID"].apply(
    lambda q: f'<a href="https://www.wikidata.org/wiki/{q}" target="_blank">{q}</a>'
)

from IPython.display import HTML
print("Saknar OSM objekt")
HTML(df.to_html(escape=False, index=False))

# %%
import requests
import time
from tqdm.notebook import tqdm

OVERPASS_URL = "https://overpass-api.de/api/interpreter"

headers = {
    "User-Agent": "MagnusOSMTools/1.0 (salgo60@msn.com)"
}

osm_ref = []
osm_link = []

for qid in tqdm(df["QID"], total=len(df), desc="Kontrollerar OSM"):
    query = f"""
    [out:json][timeout:250];
    nwr["ref:stockholmarchipelagotrail"="{qid}"];
    out ids;
    """

    try:
        r = requests.post(OVERPASS_URL, data=query, headers=headers)
        r.raise_for_status()
        elements = r.json().get("elements", [])

        if elements:
            e = elements[0]
            osm_type = e["type"]  # node, way eller relation
            osm_id = e["id"]

            osm_ref.append("Ja")
            osm_link.append(
                f'<a href="https://www.openstreetmap.org/{osm_type}/{osm_id}" '
                f'target="_blank">{osm_type}/{osm_id}</a>'
            )
        else:
            osm_ref.append("Nej")
            osm_link.append("")

    except Exception as ex:
        osm_ref.append(f"Fel: {ex}")
        osm_link.append("")

    # Var snäll mot Overpass-servern
    time.sleep(40)

df["OSM_ref"] = osm_ref
df["OSM_länk"] = osm_link

from IPython.display import HTML
HTML(df.to_html(escape=False, index=False))

# %%
end_time = time.time()
duration = end_time - start_time
print(f"Started: {start_str}") 
print(f"Finished in {duration:.2f} seconds.")
