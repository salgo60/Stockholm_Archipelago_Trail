# %%
import time
import datetime  
start_time = time.time()
start_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
print(f"Started: {start_str}")
# Out:
# Started: 2026-07-19 10:23

# %%
import requests
import pandas as pd
from geopy.distance import geodesic
from datetime import datetime 
from google.transit import gtfs_realtime_pb2

# %%
import os
import requests

API_KEY = os.environ["GTFSSweden3"]

URL = (
    "https://opendata.samtrafiken.se/gtfs-rt/sweden/VehiclePositions.pb"
    f"?key={API_KEY}"
)
print(API_KEY ) 

headers = {
    "Authorization": f"Bearer {API_KEY}"
}

response = requests.get(URL, headers=headers)

print(response.status_code)
feed = gtfs_realtime_pb2.FeedMessage()
#feed.ParseFromString(response.content)

print(len(feed.entity)) 
rows = []

for entity in feed.entity:

    if not entity.HasField("vehicle"):
        continue

    vehicle = entity.vehicle

    rows.append({

        "vehicle_id": vehicle.vehicle.id,

        "trip_id":
            vehicle.trip.trip_id
            if vehicle.HasField("trip") else None,

        "latitude":
            vehicle.position.latitude,

        "longitude":
            vehicle.position.longitude,

        "bearing":
            vehicle.position.bearing
            if vehicle.position.HasField("bearing") else None,

        "speed":
            vehicle.position.speed
            if vehicle.position.HasField("speed") else None,

        "timestamp":
            vehicle.timestamp

    })

samtrafiken = pd.DataFrame(rows)
# Out:
# f2277323909847378fb5951b57fbce03
# 403
# 0

# %%
import requests

operator = "SL" 
API_KEY = os.environ["GTFSSweden3"]

url = "https://opendata.samtrafiken.se/gtfs-rt-sweden/sl/VehiclePositions.pb"

r = requests.get(url, params={"key": API_KEY})

print(r.status_code)
print(r.headers.get("Content-Type"))
print(r.content[:50])
# Out:
# 200
# application/octet-stream
# b'\n\r\n\x032.0\x10\x00\x18\xef\x92\xf2\xd2\x06\x12\\\n\x1151161784449391096"G\n\x15\n\x1114010000'

# %%
import requests
from google.transit import gtfs_realtime_pb2

feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(r.content)

print("Antal entities:", len(feed.entity))
# Out:
# Antal entities: 783

# %%
rows = []

for entity in feed.entity:
    if not entity.HasField("vehicle"):
        continue

    v = entity.vehicle

    rows.append({
        "vehicle_id": v.vehicle.id,
        "trip_id": v.trip.trip_id if v.HasField("trip") else "",
        "route_id": v.trip.route_id if v.HasField("trip") else "",
        "lat": v.position.latitude,
        "lon": v.position.longitude,
    })

import pandas as pd

df = pd.DataFrame(rows)

print(df.route_id.nunique())
print(df.route_id.sort_values().unique()) 
df
# Out:
# 6
# ['' '9011001001900000' '9011001055300000' '9011001056700000'
#  '9011001075300000' '9011001098200000']
#            vehicle_id            trip_id route_id        lat        lon
# 0    9031001004505116  14010000721140210           59.736507  18.686020
# 1    9031001001004825  14010000726583855           59.353184  18.096294
# 2    9031001003005037  14010000723743667           59.140541  18.391972
# 3    9031001001001540  14010000717643065           59.386185  18.105663
# 4    9031001003005052  14010000723735512           59.245693  18.230490
# ..                ...                ...      ...        ...        ...
# 778  9031001002500108  14010300728239979           59.267017  18.134008
# 779  9031001003004975  14010000708184334           59.185467  18.135635
# 780  9031001001007154  14010000724544394           59.344028  18.055571
# 781  9031001003005319  14010000694639239           59.315842  18.095182
# 782  9031001001500424  14010000716344859           59.244328  18.229485
#
# [783 rows x 5 columns]

# %%
import folium

# Centrera kartan över Stockholm
m = folium.Map(
    location=[59.33, 18.10],
    zoom_start=10,
    tiles="OpenStreetMap"
)

for _, row in df.iterrows():

    folium.CircleMarker(
        location=[row.lat, row.lon],
        radius=3,
        popup=f"Vehicle: {row.vehicle_id}",
        tooltip=row.vehicle_id,
        color="blue",
        fill=True,
        fill_opacity=0.8
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae8920e0268b8c75260917fad3b05933 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae8920e0268b8c75260917fad3b05933&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae8920e0268b8c75260917fad3b05933 = L.map(
#                 &quot;map_ae8920e0268b8c75260917fad3b05933&quot;,
#                 {
#                     center: [59.33, 18.1],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92f3d331ebbc59cb9ae596b128652447 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92f3d331ebbc59cb9ae596b128652447.addTo(map_ae8920e0268b8c75260917fad3b05933);
#
#
#             var circle_marker_051ca7d23fa92c14ab14f83e5b9722c9 = L.circleMarker(
#                 [59.736507415771484, 18.686019897460938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ae8920e0268b8c75260917fad3b05933);
#
#
#         var popup_ebb934aeac3e6c13d9f98a9d27df316a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4188e0ee476105bc7af92a78e9f6e2d5 = $(`&lt;div id=&quot;html_4188e0ee476105bc7af92a78e9f6e2d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle: 9031001004505116&lt;/div&gt;`)[0];
#                 popup_ebb934aeac3e6c13d9f98a9d27df316a.setContent(html_4188e0ee476105bc7af92a78e9f6e2d5);
#
#
#
#         circle_marker_051ca7d23fa92c14ab14f83e5b9722c9.bindPopup(popup_ebb934aeac3e6c13d9f98a9d27df316a)
#         ;
#
#
#
#
#             circle_marker_051ca7d23fa92c14ab14f83e5b9722c9.bindTooltip(
#                 `&lt;div&gt;
#                      9031001004505116
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6e31abbe00a260270ab7455e42ba2aaf = L.circleMarker(
#                 [59.35318374633789, 18.096294403076172],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ae8920e0268b8c75260917fad3b05933);
#
#
#         var popup_a15a3f1f0571d1472bfc3fcbea548ff5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3279825e47275bd617ef9e629082d697 = $(`&lt;div id=&quot;html_3279825e47275bd617ef9e629082d697&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle: 9031001001004825&lt;/div&gt;`)[0];
#                 popup_a15a3f1f0571d1472bfc3fcbea548ff5.setContent(html_3279825e47275bd617ef9e629082d697);
#
#
#
#         circle_marker_6e31abbe00a260270ab7455e42ba2aaf.bindPopup(popup_a15a3f1f0571d1472bfc3fcbea548ff5)
#         ;
#
#
#
#
#             circle_marker_6e31abbe00a260270ab7455e42ba2aaf.bindTooltip(
#                 `&lt;div&gt;
#                      9031001001004825
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_99ed702edc075d49a5f17f6bf6c13ca6 = L.circleMarker(
#                 [59.140541076660156, 18.391971588134766],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ae8920e0268b8c75260917fad3b05933);
#
#
#         var popup_95c2c7c2813a1e69296aadcda1188e52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %%
boats = df[
    (df.lon > 18.2) &
    (df.lat > 59.15)
]

# %%
boats
# Out:
#            vehicle_id            trip_id route_id        lat        lon
# 0    9031001004505116  14010000721140210           59.736507  18.686020
# 4    9031001003005052  14010000723735512           59.245693  18.230490
# 7    9031001003005330  14010000722216663           59.308849  18.273285
# 10   9031001004505128  14010000721157749           59.628506  18.971540
# 20   9031001003005324  14010000695321825           59.264561  18.432205
# ..                ...                ...      ...        ...        ...
# 746  9031001004505110  14010000721158149           60.100147  18.812777
# 767  9031001004516929  14010100717907079           59.473225  18.235397
# 775  9031001004505129  14010000721158332           59.760574  18.690809
# 776  9031001004505568  14010000721141403           59.634922  18.332029
# 782  9031001001500424  14010000716344859           59.244328  18.229485
#
# [111 rows x 5 columns]

# %%
rows = []

for entity in feed.entity:
    if not entity.HasField("vehicle"):
        continue

    v = entity.vehicle

    rows.append({
        "vehicle_id": v.vehicle.id,
        "trip_id": v.trip.trip_id if v.HasField("trip") else "",
        "route_id": v.trip.route_id if v.HasField("trip") else "",
        "lat": v.position.latitude,
        "lon": v.position.longitude,
    })

import pandas as pd

df = pd.DataFrame(rows)

print(df.route_id.nunique())
print(df.route_id.sort_values().unique()) 
df
boats = df[
    (df.lat >= 58.6) &
    (df.lat <= 59.9) &
    (df.lon >= 17.8) &
    (df.lon <= 19.4)
]
import folium

# Centrera kartan över Stockholm
m = folium.Map(
    location=[59.33, 18.10],
    zoom_start=10,
    tiles="OpenStreetMap"
)

for _, row in boats.iterrows():

    folium.CircleMarker(
        location=[row.lat, row.lon],
        radius=3,
        popup=f"Vehicle: {row.vehicle_id}",
        tooltip=row.vehicle_id,
        color="blue",
        fill=True,
        fill_opacity=0.8
    ).add_to(m)

m
# Out:
# 6
# ['' '9011001001900000' '9011001055300000' '9011001056700000'
#  '9011001075300000' '9011001098200000']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e881638357e6d922cda47ad2106dc1d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e881638357e6d922cda47ad2106dc1d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e881638357e6d922cda47ad2106dc1d4 = L.map(
#                 &quot;map_e881638357e6d922cda47ad2106dc1d4&quot;,
#                 {
#                     center: [59.33, 18.1],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f93f95e4939f865a43ac1f3e1c573ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f93f95e4939f865a43ac1f3e1c573ed.addTo(map_e881638357e6d922cda47ad2106dc1d4);
#
#
#             var circle_marker_16cfeba8186dd340e454b8ba8543b032 = L.circleMarker(
#                 [59.736507415771484, 18.686019897460938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e881638357e6d922cda47ad2106dc1d4);
#
#
#         var popup_d01228c8e99eed8953316fa5677ccefd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cf0eb3c3e2eb2fcd3e1f66906892e80 = $(`&lt;div id=&quot;html_8cf0eb3c3e2eb2fcd3e1f66906892e80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle: 9031001004505116&lt;/div&gt;`)[0];
#                 popup_d01228c8e99eed8953316fa5677ccefd.setContent(html_8cf0eb3c3e2eb2fcd3e1f66906892e80);
#
#
#
#         circle_marker_16cfeba8186dd340e454b8ba8543b032.bindPopup(popup_d01228c8e99eed8953316fa5677ccefd)
#         ;
#
#
#
#
#             circle_marker_16cfeba8186dd340e454b8ba8543b032.bindTooltip(
#                 `&lt;div&gt;
#                      9031001004505116
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_be3bad30c6a85d40b6ef4dfbb271f2be = L.circleMarker(
#                 [59.35318374633789, 18.096294403076172],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e881638357e6d922cda47ad2106dc1d4);
#
#
#         var popup_30f57ea20f7bbd09116ed6d543bec0fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_214c740c16e4164187bda01bd373d027 = $(`&lt;div id=&quot;html_214c740c16e4164187bda01bd373d027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle: 9031001001004825&lt;/div&gt;`)[0];
#                 popup_30f57ea20f7bbd09116ed6d543bec0fc.setContent(html_214c740c16e4164187bda01bd373d027);
#
#
#
#         circle_marker_be3bad30c6a85d40b6ef4dfbb271f2be.bindPopup(popup_30f57ea20f7bbd09116ed6d543bec0fc)
#         ;
#
#
#
#
#             circle_marker_be3bad30c6a85d40b6ef4dfbb271f2be.bindTooltip(
#                 `&lt;div&gt;
#                      9031001001004825
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_c642863deefd08da4ff3e192d2b896b5 = L.circleMarker(
#                 [59.140541076660156, 18.391971588134766],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e881638357e6d922cda47ad2106dc1d4);
#
#
#         var popup_1eafe4bd59546d5eb0c44658039c81be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %%
## Nära Ornö   
near_orno = df[
    (df.lat.between(59.13, 59.18)) &
    (df.lon.between(18.38, 18.48))
]

near_orno
# Out:
#          vehicle_id            trip_id route_id        lat        lon
# 2  9031001003005037  14010000723743667           59.140541  18.391972

# %%
with ZipFile("sweden_api.zip") as z:
    trips = pd.read_csv(z.open("trips.txt"))
    routes = pd.read_csv(z.open("routes.txt"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 with ZipFile("sweden_api.zip") as z:
#       2     trips = pd.read_csv(z.open("trips.txt"))
#       3     routes = pd.read_csv(z.open("routes.txt"))
#
# NameError: name 'ZipFile' is not defined

# %%
trip = trips[trips.trip_id == "14010000723744632"]
trip

# %%
routes.columns

# %%
ferry_routes = routes[routes.route_type == 4]["route_id"]

ferries = df[df.route_id.isin(ferry_routes)]

# %%
ferries

# %%
trip = trips[trips.trip_id == "14010000723744632"]
trip

# %%
trips.dtypes

# %%
trip = trips[trips.trip_id == 14010000723744632]

# %%
trips["trip_id"] = trips["trip_id"].astype(str)
df["trip_id"] = df["trip_id"].astype(str)

trip = trips[trips.trip_id == df.iloc[37]["trip_id"]]

# %%
print("Realtime trip_id:", df.iloc[37]["trip_id"])
print("Finns i trips.txt:", (trips["trip_id"].astype(str) == str(df.iloc[37]["trip_id"])).any())

# %%
trip = trips[trips.trip_id.astype(str) == "14010000723744632"]

print(trip)

# %%
trip.T

# %%
route_id = trip.iloc[0]["route_id"]

print("Route ID:", route_id)

# %%
route = routes[routes.route_id == route_id]

route

# %%
route.T

# %%
routes["route_type"].value_counts().sort_index()

# %%
ferries = routes[routes["route_type"] == 700]

ferries[[
    "route_short_name",
    "route_long_name",
    "agency_id",
    "route_id"
]].sort_values("route_short_name")

# %%
df = (
    df
    .merge(
        trips[["trip_id", "route_id"]],
        on="trip_id",
        how="left"
    )
    .merge(
        routes[[
            "route_id",
            "route_short_name",
            "route_type",
            "agency_id"
        ]],
        on="route_id",
        how="left"
    )
)

# %%
print(df.columns.tolist())
print(routes.columns.tolist())

# %%
print(routes.head())

# %%
print(routes.dtypes)

# %%
boats = df.merge(
    routes[["route_id", "route_short_name", "route_type", "agency_id"]],
    on="route_id",
    how="left"
)

boats[boats.route_type == 700]

# %%
from zipfile import ZipFile
import pandas as pd

with ZipFile("sweden_api.zip") as z:
    agencies = pd.read_csv(z.open("agency.txt"))

agencies.head()

# %%
with ZipFile("sweden_api.zip") as z:
    agencies = pd.read_csv(
        z.open("agency.txt"),
        dtype=str
    )

    routes = pd.read_csv(
        z.open("routes.txt"),
        dtype=str
    )

    trips = pd.read_csv(
        z.open("trips.txt"),
        dtype=str
    )
boats = (
    df[
        ["vehicle_id", "trip_id", "route_id", "lat", "lon"]
    ]
    .drop_duplicates()
    .merge(
        routes[
            ["route_id", "agency_id", "route_short_name", "route_type"]
        ],
        on="route_id",
        how="left"
    )
    .merge(
        agencies[
            ["agency_id", "agency_name"]
        ],
        on="agency_id",
        how="left"
    )
)

# %%
print(boats["agency_id"].unique()[:10])
print(agencies["agency_id"].unique()[:10])

# %%
boats.to_csv("boats.csv")

# %%
end_time = time.time()
duration = end_time - start_time
print(f"Started: {start_str}") 
print(f"Finished in {duration:.2f} seconds.")
