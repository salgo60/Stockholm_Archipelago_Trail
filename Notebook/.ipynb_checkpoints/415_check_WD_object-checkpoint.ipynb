# %% [markdown]
# ## 415_check_WD_object
# * [#415](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/415)
# * denna Notebook [415_check_WD_object](https://github.com/salgo60/Stockholm_Archipelago_Trail/tree/main/Notebook/415_check_WD_object.ipynb)

# %%
import time
import datetime  
start_time = time.time()
start_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
print(f"Started: {start_str}")
# Out:
# Started: 2026-07-02 21:34

# %%
import requests

url = "https://map.stockholmarchipelagotrail.com/data/geojson/poi-concordance.json"
data = requests.get(url).json()

wikidata_ids = [
    k.replace("wikidata:", "")
    for k in data["satIdOf"].keys()
    if k.startswith("wikidata:")
]

print(f"{len(wikidata_ids)} Wikidata-objekt")
print(wikidata_ids[:10])
# Out:
# 289 Wikidata-objekt
# ['Q10397095', 'Q10417837', 'Q10417838', 'Q10478848', 'Q10553968', 'Q10593490', 'Q10605049', 'Q10611874', 'Q10657821', 'Q10661170']

# %%
osm_ids = [
    k.replace("osm:", "")
    for k in data["satIdOf"].keys()
    if k.startswith("osm:")
]

print(f"{len(osm_ids)} OSM-objekt")
print(osm_ids[:10])
# Out:
# 551 OSM-objekt
# ['node:10049761782', 'node:10049770242', 'node:1032978690', 'node:1033001787', 'node:10658261600', 'node:10796713818', 'node:10948911479', 'node:11066973234', 'node:11075643778', 'node:11079164849']

# %%
# Issue #415
# SAT Wikidata QA checker
#
# Checks all Wikidata references in poi-concordance.json
#
# Reports:
#   - Redirected Wikidata objects (merged)
#   - Deleted Wikidata objects
#   - Related SAT object
#   - Related OSM objects
#
# Output:
#   output/issue_415_wikidata_quality_report_YYYYMMDD.json
#   output/issue_415_wikidata_issues_YYYYMMDD.csv
#   output/issue_415_wikidata_issues_YYYYMMDD.html
#
# Notebook:
#   Displays clickable table with:
#     Wikidata
#     Redirect target
#     SAT API link
#     OSM links

import json
import time
from pathlib import Path
from datetime import datetime

import pandas as pd
import requests
from IPython.display import HTML, display

ISSUE = 415

CONCORDANCE_URL = (
    "https://map.stockholmarchipelagotrail.com/data/geojson/poi-concordance.json"
)

# --------------------------------------------------
# Setup
# --------------------------------------------------

today = datetime.now().strftime("%Y%m%d")

output_dir = Path("output")
output_dir.mkdir(exist_ok=True)

json_file = (
    output_dir /
    f"issue_{ISSUE}_wikidata_quality_report_{today}.json"
)

csv_file = (
    output_dir /
    f"issue_{ISSUE}_wikidata_issues_{today}.csv"
)

html_file = (
    output_dir /
    f"issue_{ISSUE}_wikidata_issues_{today}.html"
)

print("Loading concordance...")

concordance = requests.get(CONCORDANCE_URL).json()

sat_of = concordance["satIdOf"]

# --------------------------------------------------
# Build indexes
# --------------------------------------------------

wikidata_to_sat = {}
sat_to_osm = {}

for key, sat_id in sat_of.items():

    if key.startswith("wikidata:"):
        qid = key.replace("wikidata:", "")
        wikidata_to_sat[qid] = sat_id

    elif key.startswith("osm:"):
        sat_to_osm.setdefault(
            sat_id,
            []
        ).append(key)

print(
    f"Found {len(wikidata_to_sat)} Wikidata objects"
)

# --------------------------------------------------
# Check Wikidata
# --------------------------------------------------

alive = []
redirects = []
deleted = []
errors = []

for idx, qid in enumerate(
    sorted(wikidata_to_sat.keys()),
    start=1
):

    print(
        f"{idx}/{len(wikidata_to_sat)} {qid}",
        end="\r"
    )

    sat_id = wikidata_to_sat[qid]

    try:

        url = (
            f"https://www.wikidata.org/wiki/"
            f"Special:EntityData/{qid}.json"
        )

        r = requests.get(
            url,
            timeout=30,
            headers={
                "User-Agent":
                "Stockholm Archipelago Trail QA"
            }
        )

        osm_objects = sat_to_osm.get(
            sat_id,
            []
        )

        if r.status_code == 404:

            deleted.append({
                "status": "deleted",
                "qid": qid,
                "target": "",
                "sat_id": sat_id,
                "osm": osm_objects
            })

            continue

        if r.status_code != 200:

            errors.append({
                "qid": qid,
                "status_code": r.status_code
            })

            continue

        entities = r.json()["entities"]

        returned_qid = next(
            iter(entities.keys())
        )

        if returned_qid != qid:

            redirects.append({
                "status": "redirect",
                "qid": qid,
                "target": returned_qid,
                "sat_id": sat_id,
                "osm": osm_objects
            })

        else:
            alive.append(qid)

    except Exception as e:

        errors.append({
            "qid": qid,
            "error": str(e)
        })

    time.sleep(0.1)

print()
print("Done")

# --------------------------------------------------
# Create dataframe
# --------------------------------------------------

rows = []

for item in redirects + deleted:

    osm_urls = []

    for osm in item["osm"]:

        _, osm_type, osm_id = osm.split(":")

        osm_urls.append(
            f"https://www.openstreetmap.org/"
            f"{osm_type}/{osm_id}"
        )

    rows.append({
        "Status": item["status"],
        "Wikidata": item["qid"],
        "Target": item["target"],
        "SAT": item["sat_id"],
        "OSM Count": len(osm_urls),
        "OSM Links": "\n".join(osm_urls)
    })

df = pd.DataFrame(rows)

# --------------------------------------------------
# Save CSV
# --------------------------------------------------

df.to_csv(
    csv_file,
    index=False
)

# --------------------------------------------------
# Save JSON
# --------------------------------------------------

report = {
    "alive": len(alive),
    "redirects": redirects,
    "deleted": deleted,
    "errors": errors,
}

with open(
    json_file,
    "w",
    encoding="utf-8"
) as f:

    json.dump(
        report,
        f,
        indent=2,
        ensure_ascii=False
    )

# --------------------------------------------------
# HTML helpers
# --------------------------------------------------

def wd_link(qid):

    if not qid:
        return ""

    return (
        f'<a href="https://www.wikidata.org/wiki/{qid}" '
        f'target="_blank">{qid}</a>'
    )

def sat_link(sat_id):

    if not sat_id:
        return ""

    url = (
        "https://map.stockholmarchipelagotrail.com/api/objects/"
        f"{sat_id}"
    )

    return (
        f'<a href="{url}" target="_blank">'
        f'{sat_id}'
        f'</a>'
    )

def osm_links(text):

    if not text:
        return ""

    html = []

    for url in text.split("\n"):

        parts = url.split("/")

        html.append(
            f'<a href="{url}" target="_blank">'
            f'{parts[-2]}/{parts[-1]}'
            f'</a>'
        )

    return "<br>".join(html)

# --------------------------------------------------
# Notebook table
# --------------------------------------------------

if len(df):

    html_df = df.copy()

    html_df["Wikidata"] = (
        html_df["Wikidata"]
        .apply(wd_link)
    )

    html_df["Target"] = (
        html_df["Target"]
        .apply(wd_link)
    )

    html_df["SAT"] = (
        html_df["SAT"]
        .apply(sat_link)
    )

    html_df["OSM Links"] = (
        html_df["OSM Links"]
        .apply(osm_links)
    )

    table = html_df.to_html(
        escape=False,
        index=False,
        classes="issues"
    )
    latest_html = (
        output_dir /
        "415_check_WD_object_latest.html"
    )
    
    dated_html = (
        output_dir /
        f"415_check_WD_object_{today}.html"
    )
    
    html = f"""
    <!DOCTYPE html>
    
    <html>
    
    <head>
    
    <meta charset="utf-8">
    
    <title>Issue #415</title>
    
    <style>
    
    body {{
    
        font-family: Arial;
        margin:40px;
    }}
    
    table.issues {{
    
        border-collapse:collapse;
        width:100%;
    }}
    
    table.issues th,
    table.issues td {{
    
        border:1px solid #ccc;
        padding:6px;
    }}
    
    table.issues th {{
    
        background:#eeeeee;
    }}
    
    .summary td:first-child {{
    
        font-weight:bold;
    }}
    
    </style>
    
    </head>
    
    <body>
    
    <h1>Stockholm Archipelago Trail</h1>
    
    <h2>QA report</h2>
    
    <p>
    
    Issue:
    <a href="https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/415">
    #415
    </a>
    
    </p>
    
    <p>
    
    Generated:
    {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}
    
    </p>
    
    <h2>Summary</h2>
    
    <table class="summary">
    
    <tr><td>Alive Wikidata</td><td>{len(alive)}</td></tr>
    
    <tr><td>Redirects</td><td>{len(redirects)}</td></tr>
    
    <tr><td>Deleted Wikidata</td><td>{len(deleted)}</td></tr>
    
    <tr><td>Errors Wikidata</td><td>{len(errors)}</td></tr>
    
    <tr><td>Alive OSM</td><td>{len(osm_alive)}</td></tr>
    
    <tr><td>Deleted OSM</td><td>{len(osm_deleted)}</td></tr>
    
    <tr><td>OSM ref mismatch</td><td>{len(osm_ref_mismatch)}</td></tr>
    
    <tr><td>OSM errors</td><td>{len(osm_errors)}</td></tr>
    
    </table>
    
    <h2>QA checks</h2>
    
    <ul>
    
    <li>✔ SAT → Wikidata</li>
    
    <li>✔ Wikidata object exists</li>
    
    <li>✔ SAT → OSM</li>
    
    <li>✔ OSM object exists</li>
    
    <li>✔ OSM backlink</li>
    
    <li>⬜ Wikidata backlink</li>
    
    <li>⬜ OSM wikidata=* matches SAT</li>
    
    <li>⬜ Duplicate SAT ids</li>
    
    <li>⬜ Duplicate Wikidata ids</li>
    
    <li>⬜ Duplicate OSM ids</li>
    
    </ul>
    <h2>Wikidata issues</h2>
    
    {table}
    
    <hr>
    
    <h2>OSM backlink issues</h2>
    
    <p>
    
    These OSM objects exist but
    <code>ref:stockholmarchipelagotrail</code>
    does not match the SAT identifier stored in
    <code>poi-concordance.json</code>.
    
    </p>
    
    {osm_table}
    
    <hr>
    
    <h2>Lessons learned</h2>
    
    <ul>
    
    <li>
    A SAT POI may legitimately reference multiple OSM objects.
    For example a beach may consist of both a
    <code>natural=beach</code>
    way and a
    <code>leisure=swimming_area</code>
    node.
    </li>
    
    <li>
    The QA therefore validates that each OSM object points back
    to the correct SAT id rather than enforcing a 1:1
    SAT→OSM relationship.
    </li>
    
    </ul>
    
    <hr>
    
    <h2>Future QA</h2>
    
    <ul>
    
    <li>✔ SAT → Wikidata exists</li>
    
    <li>✔ Wikidata item exists</li>
    
    <li>✔ SAT → OSM exists</li>
    
    <li>✔ OSM object exists</li>
    
    <li>✔ OSM → SAT backlink</li>
    
    <li>⬜ Wikidata → SAT backlink</li>
    
    <li>⬜ OSM wikidata=* matches SAT Wikidata</li>
    
    <li>⬜ Duplicate SAT ids</li>
    
    <li>⬜ Duplicate Wikidata ids</li>
    
    <li>⬜ Duplicate OSM ids</li>
    
    <li>⬜ Check that all SAT identifiers are unique</li>
    
    <li>⬜ GitHub Action publishes latest report</li>
    
    </ul>    
    <h2>Issues</h2>
    
    {table}
    
    </body>
    
    </html>
    """
    html_file.write_text(
        html,
        encoding="utf-8"
    )
    
    dated_html.write_text(
        html,
        encoding="utf-8"
    )
    
    latest_html.write_text(
        html,
        encoding="utf-8"
    )
    
    display(
        HTML(html)
    )
# --------------------------------------------------
# Summary
# --------------------------------------------------

print()
print("Summary")
print("--------------------------------")
print("Alive     :", len(alive))
print("Redirects :", len(redirects))
print("Deleted   :", len(deleted))
print("Errors    :", len(errors))

print()
print("Files")
print("--------------------------------")
print(json_file)
print(csv_file)
print(html_file)
# Out:
# Loading concordance...
# Found 289 Wikidata objects
# 289/289 Q842877974
# Done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 421
#     331 latest_html = (
#     332     output_dir /
#     333     "415_check_WD_object_latest.html"
#     334 )
#     336 dated_html = (
#     337     output_dir /
#     338     f"415_check_WD_object_{today}.html"
#     339 )
#     341 html = f"""
#     342 <!DOCTYPE html>
#     343
#     344 <html>
#     345
#     346 <head>
#     347
#     348 <meta charset="utf-8">
#     349
#     350 <title>Issue #415</title>
#     351
#     352 <style>
#     353
#     354 body {{
#     355
#     356     font-family: Arial;
#     357     margin:40px;
#     358 }}
#     359
#     360 table.issues {{
#     361
#     362     border-collapse:collapse;
#     363     width:100%;
#     364 }}
#     365
#     366 table.issues th,
# ...

# %%
page = f"""
<!DOCTYPE html>

<html>

<head>

<meta charset="utf-8">

<title>Issue #415 QA report</title>

<style>

body {{

    font-family: Arial, sans-serif;
    margin:40px;
}}

table.issues {{

    border-collapse: collapse;
    width:100%;
}}

table.issues th,
table.issues td {{

    border:1px solid #ccc;
    padding:6px;
}}

table.issues th {{

    background:#efefef;
}}

.summary td:first-child {{

    font-weight:bold;
}}

code {{

    background:#f0f0f0;
}}

</style>

</head>

<body>

<h1>Stockholm Archipelago Trail QA</h1>

<p>

Issue:

<a href="https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/415">

#415

</a>

</p>

<p>

Generated:

{datetime.now().strftime("%Y-%m-%d %H:%M:%S")}

</p>

<h2>Summary</h2>

<table class="summary">

<tr><td>Alive Wikidata</td><td>{len(alive)}</td></tr>

<tr><td>Redirects</td><td>{len(redirects)}</td></tr>

<tr><td>Deleted Wikidata</td><td>{len(deleted)}</td></tr>

<tr><td>Wikidata errors</td><td>{len(errors)}</td></tr>

<tr><td>Alive OSM</td><td>{len(osm_alive)}</td></tr>

<tr><td>Deleted OSM</td><td>{len(osm_deleted)}</td></tr>

<tr><td>OSM ref mismatches</td><td>{len(osm_ref_mismatch)}</td></tr>

<tr><td>OSM API errors</td><td>{len(osm_errors)}</td></tr>

</table>

<h2>QA checklist</h2>

<ul>

<li>✔ SAT → Wikidata</li>

<li>✔ Wikidata object exists</li>

<li>✔ SAT → OSM</li>

<li>✔ OSM object exists</li>

<li>✔ OSM backlink</li>

<li>⬜ Wikidata backlink</li>

<li>⬜ OSM wikidata=* matches SAT</li>

<li>⬜ Duplicate SAT ids</li>

<li>⬜ Duplicate OSM ids</li>

<li>⬜ Duplicate Wikidata ids</li>

</ul>

<h2>Issues</h2>

{table}

</body>

</html>
"""

# %% [markdown]
# ## Check OSM

# %%
from tqdm.auto import tqdm
import requests
import time

# --------------------------------------------------
# Check OSM
# --------------------------------------------------

osm_alive = []
osm_deleted = []
osm_errors = []
osm_ref_mismatch = []

osm_has_ref = 0
osm_missing_ref = 0

session = requests.Session()
session.headers.update(
    {
        "User-Agent": "Stockholm Archipelago Trail QA (salgo60@msn.com)"
    }
)

total = sum(len(v) for v in sat_to_osm.values())

with tqdm(total=total, desc="Checking OSM") as pbar:

    for sat_id, osm_objects in sat_to_osm.items():

        for osm in osm_objects:

            _, osm_type, osm_id = osm.split(":")

            url = (
                f"https://api.openstreetmap.org/api/0.6/"
                f"{osm_type}/{osm_id}.json"
            )

            try:

                r = session.get(url, timeout=30)

                if r.status_code == 404:

                    osm_deleted.append(
                        {
                            "osm": osm,
                            "sat_id": sat_id,
                        }
                    )
                    pbar.update(1)
                    continue

                if r.status_code != 200:

                    osm_errors.append(
                        {
                            "osm": osm,
                            "status_code": r.status_code,
                        }
                    )
                    pbar.update(1)
                    continue

                obj = r.json()["elements"][0]
                tags = obj.get("tags", {})

                ref = tags.get("ref:stockholmarchipelagotrail")

                if ref is None:
                    osm_missing_ref += 1
                else:
                    osm_has_ref += 1

                    if ref != sat_id:
                        osm_ref_mismatch.append(
                            {
                                "osm": osm,
                                "sat_id": sat_id,
                                "found": ref,
                            }
                        )

                osm_alive.append(osm)

            except Exception as e:

                osm_errors.append(
                    {
                        "osm": osm,
                        "error": str(e),
                    }
                )

            pbar.update(1)

            # Var snäll mot OSM API
            time.sleep(0.1)

print()
print("OSM")
print("--------------------------------")
print("Alive        :", len(osm_alive))
print("Deleted      :", len(osm_deleted))
print("Has ref      :", osm_has_ref)
print("Missing ref  :", osm_missing_ref)
print("Ref mismatch :", len(osm_ref_mismatch))
print("Errors       :", len(osm_errors))

# %%
report["osm"] = {
    "alive": len(osm_alive),
    "deleted": osm_deleted,
    "ref_mismatch": osm_ref_mismatch,
    "errors": osm_errors,
} 

print()
print("OSM")
print("--------------------------------")
print("Alive        :", len(osm_alive))
print("Deleted      :", len(osm_deleted))
print("Ref mismatch :", len(osm_ref_mismatch))
print("Errors       :", len(osm_errors))

# %% [markdown]
# ## Rapport

# %%
from urllib.parse import quote

def sat_link(sat_id):

    if not sat_id:
        return ""

    map_url = (
        "https://map.stockholmarchipelagetrail.com/?id="
        + quote(sat_id)
    )

    api_url = (
        "https://map.stockholmarchipelagetrail.com/api/objects/"
        + quote(sat_id)
    )

    return (
        f'<a href="{map_url}" target="_blank">{sat_id}</a>'
        f' (<a href="{api_url}" target="_blank">API</a>)'
    )
def sat_api_link(sat_id):
    return (
        f'<a href="https://map.stockholmarchipelagetrail.com/api/objects/{quote(sat_id)}" '
        f'target="_blank">API</a>'
    )


def wd_link(qid):
    if not qid:
        return ""

    return (
        f'<a href="https://www.wikidata.org/wiki/{qid}" '
        f'target="_blank">{escape(qid)}</a>'
    )


def osm_links(text):

    if not text:
        return ""

    links = []

    for url in text.split("\n"):

        if not url:
            continue

        if url.startswith("https://"):

            parts = url.split("/")

            label = parts[-2] + "/" + parts[-1]

            links.append(
                f'<a href="{url}" target="_blank">{label}</a>'
            )

    return "<br>".join(links)

# %%
from pathlib import Path
from datetime import datetime
from html import escape

output = Path("output")
output.mkdir(exist_ok=True)

stamp = datetime.now().strftime("%Y%m%d")
generated = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

html_timestamp = output / f"415_check_WD_object_{stamp}.html"
html_latest = output / "415_check_WD_object_latest.html"


def html_table(rows, headers):

    if not rows:
        return "<p><em>No issues found.</em></p>"

    html = [
        "<table>",
        "<thead><tr>",
    ]

    for h in headers:
        html.append(f"<th>{escape(h)}</th>")

    html.append("</tr></thead><tbody>")

    for row in rows:
        html.append("<tr>")
        for c in row:
            html.append(f"<td>{escape(str(c))}</td>")
        html.append("</tr>")

    html.append("</tbody></table>")

    return "\n".join(html)

wd_rows = [
    [
        sat_link(x["sat_id"]),
        sat_api_link(x["sat_id"]),
        wd_link(x["wikidata"]),
        escape(x.get("reason", ""))
    ]
    for x in wd_missing_backlink
]

osm_rows = [
    [
        sat_link(x["sat_id"]),
        sat_api_link(x["sat_id"]),
        osm_link(x["osm"]),
        escape(str(x["found"]))
    ]
    for x in osm_ref_mismatch
]

error_rows = [
    [
        x.get("osm"),
        x.get("status_code", ""),
        x.get("error", "")
    ]
    for x in osm_errors
]

status = "🟢 PASS"

if wd_rows or osm_rows or osm_errors:
    status = "🟡 WARN"

if osm_deleted:
    status = "🔴 FAIL"

html = f"""
<!DOCTYPE html>
<html>

<head>

<meta charset="utf-8">

<title>SAT QA report</title>

<style>

body {{

    font-family: Arial, sans-serif;
    margin:40px;
}}

table {{

    border-collapse: collapse;
    width:100%;
}}

th,td {{

    border:1px solid #ccc;
    padding:6px;
}}

th {{

    background:#efefef;
}}

h2 {{

    margin-top:40px;
}}

.summary td:first-child {{

    font-weight:bold;
}}

code {{

    background:#eee;
    padding:2px;
}}

</style>

</head>

<body>

<h1>Stockholm Archipelago Trail</h1>

<h2>QA report – Issue #415</h2>

<p><b>Status:</b> {status}</p>

<p>

Generated: {generated}<br>

Notebook: <code>415_check_WD_object.ipynb</code>

</p>

<h2>Summary</h2>

<table class="summary">

<tr><td>OSM objects</td><td>{len(osm_alive)}</td></tr>

<tr><td>Deleted OSM objects</td><td>{len(osm_deleted)}</td></tr>

<tr><td>OSM ref mismatches</td><td>{len(osm_ref_mismatch)}</td></tr>

<tr><td>OSM API errors</td><td>{len(osm_errors)}</td></tr>

<tr><td>Wikidata backlink issues</td><td>{len(wd_rows)}</td></tr>

</table>


<h2>TODO</h2>

<ul>

<li>Verify every SAT → Wikidata mapping.</li>

<li>Verify every Wikidata object points back to the SAT identifier.</li>

<li>Verify every SAT → OSM mapping.</li>

<li>Verify every OSM object has the correct <code>ref:stockholmarchipelagotrail</code>.</li>

<li>Verify OSM <code>wikidata=*</code> matches the SAT concordance.</li>

<li>Detect duplicate SAT ids.</li>

<li>Detect duplicate Wikidata ids.</li>

<li>Detect duplicate OSM ids.</li>

</ul>

<h2>Wikidata backlink issues</h2>

{html_table(
    wd_rows,
    [
        "SAT id",
        "Wikidata",
        "Problem"
    ]
)}

<h2>OSM backlink issues</h2>

{html_table(
    osm_rows,
    [
        "SAT id",
        "OSM object",
        "ref:stockholmarchipelagotrail"
    ]
)}

<h2>OSM API errors</h2>

{html_table(
    error_rows,
    [
        "OSM object",
        "HTTP",
        "Error"
    ]
)}

</body>

</html>
"""

html_timestamp.write_text(html, encoding="utf-8")
html_latest.write_text(html, encoding="utf-8")

print(html_timestamp)
print(html_latest)

# %%
end_time = time.time()
duration = end_time - start_time

print(f"Finished in {duration:.2f} seconds.")
