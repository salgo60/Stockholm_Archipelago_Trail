# %% [markdown]
# ## Test Postpass
# * [#389](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/389)
# * Denna notebook [389_postpass.ipynb](https://github.com/salgo60/Stockholm_Archipelago_Trail/tree/main/Notebook/389_postpass.ipynb)

# %%
import time
import datetime  
start_time = time.time()https://github.com/salgo60/Stockholm_Archipelago_Trail/tree/main/Notebook/389_postpass.ipynb
start_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
print(f"Started: {start_str}")
# Out:
# Started: 2026-06-09 17:56

# %%
import requests

query = """
SELECT osm_id, tags, geom
FROM postpass_pointlinepolygon
WHERE tags ? 'ref:stockholmarchipelagotrail'
"""

r = requests.post(
    "https://postpass.geofabrik.de/api/0.2/interpreter",
    data={"data": query}
)

print(r.status_code)
#print(r.text)
# Out:
# 200

# %%
import json
print(json.dumps(r.json(), indent=2, ensure_ascii=False))
# Out:
# {
#   "postpass_properties": {
#     "generator": "Postpass API 0.2",
#     "timestamp": "2026-06-09T15:50:30Z"
#   },
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           18.5579106,
#           59.4118287
#         ]
#       },
#       "properties": {
#         "osm_id": 863423239,
#         "tags": {
#           "fee": "no",
#           "name": "Misse",
#           "note": "Vatten stängs av på Grinda i oktober enligt Skärgårdsstiftelsen",
#           "image": "https://upload.wikimedia.org/wikipedia/commons/2/2a/SAT_Grinda_20250825_vandring_dokumentera_05.jpg",
#           "access": "yes",
#           "bottle": "yes",
#           "indoor": "yes",
#           "source": "survey",
#           "unisex": "yes",
#           "amenity": "toilets",
#           "note:en": "Water will be turned off at Grinda in October",
#           "fountain": "water_tap",
# ...

# %% [markdown]
# ## ref:grillplatser.nu

# %%
import requests

query = """
SELECT osm_id, tags, geom
FROM postpass_pointlinepolygon
WHERE tags ? 'ref:grillplatser.nu'
"""

r = requests.post(
    "https://postpass.geofabrik.de/api/0.2/interpreter",
    data={"data": query}
)

#print(r.status_code)
import json
print(json.dumps(r.json(), indent=2, ensure_ascii=False))
# Out:
# {
#   "postpass_properties": {
#     "generator": "Postpass API 0.2",
#     "timestamp": "2026-06-09T16:04:45Z"
#   },
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           18.5748343,
#           59.4063316
#         ]
#       },
#       "properties": {
#         "osm_id": 863394672,
#         "tags": {
#           "image": "https://upload.wikimedia.org/wikipedia/commons/f/f0/Grinda%2C_Klubbudden_Barbecue_area.jpg",
#           "amenity": "bbq",
#           "website": "https://grillplatser.nu/Grillplats/Visa/Grinda-Klubbudden",
#           "wikidata": "Q121714588",
#           "fireplace": "yes",
#           "wheelchair": "no",
#           "image:license": "CC0 1.0",
#           "ref:grillplatser.nu": "Grinda-Klubbudden"
#         }
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
# ...

# %%
import json
print(json.dumps(r.json(), indent=2, ensure_ascii=False))
# Out:
# {
#   "postpass_properties": {
#     "generator": "Postpass API 0.2",
#     "timestamp": "2026-06-09T16:04:45Z"
#   },
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           18.5748343,
#           59.4063316
#         ]
#       },
#       "properties": {
#         "osm_id": 863394672,
#         "tags": {
#           "image": "https://upload.wikimedia.org/wikipedia/commons/f/f0/Grinda%2C_Klubbudden_Barbecue_area.jpg",
#           "amenity": "bbq",
#           "website": "https://grillplatser.nu/Grillplats/Visa/Grinda-Klubbudden",
#           "wikidata": "Q121714588",
#           "fireplace": "yes",
#           "wheelchair": "no",
#           "image:license": "CC0 1.0",
#           "ref:grillplatser.nu": "Grinda-Klubbudden"
#         }
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
# ...

# %%
end_time = time.time()
duration = end_time - start_time

print(f"Finished in {duration:.2f} seconds.")
# Out:
# Finished in 0.28 seconds.
