# %% [markdown]
# ### 203_sanity_check_WD_OSM
#
# * Issue #203
# * This notebook 203_sanity_check_WD_OSM.ipynb

# %%
import requests
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

# -------------------------------
# 1. Get reserves from OSM
# -------------------------------
overpass_url = "https://overpass-api.de/api/interpreter"
query = """
[out:json][timeout:180];
rel(54391)->.stockholm_lan;
.stockholm_lan map_to_area -> .area_stockholm;

(
  node["leisure"="nature_reserve"](area.area_stockholm);
  way["leisure"="nature_reserve"](area.area_stockholm);
  rel["leisure"="nature_reserve"](area.area_stockholm);

  node["boundary"="protected_area"]["protect_class"](area.area_stockholm);
  way["boundary"="protected_area"]["protect_class"](area.area_stockholm);
  rel["boundary"="protected_area"]["protect_class"](area.area_stockholm);
);

out body;
>;
out skel qt;
"""

resp = requests.get(overpass_url, params={'data': query})
data = resp.json()

osm_reserves = []
for el in data.get("elements", []):
    if "tags" in el:
        tags = el["tags"]
        osm_reserves.append({
            "osm_id": f"{el['type']}/{el['id']}",
            "name": tags.get("name"),
            "ref:NVRID": tags.get("ref:NVRID"),
            "wikidata": tags.get("wikidata"),
            "website_osm": tags.get("website"),
        })

df_osm = pd.DataFrame(osm_reserves).drop_duplicates(subset=["osm_id"]).reset_index(drop=True)

print(f"Found {len(df_osm)} reserves in OSM Stockholm län")
display(df_osm.head())


# -------------------------------
# 2. Get reserves from Wikidata
# -------------------------------
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
SELECT ?item ?itemLabel ?NVRID ?geojson ?osmRel ?osmWay ?website WHERE {
  # ?item wdt:P31 wd:Q179049;            # instance of nature reserve
        wdt:P131* wd:Q104231.          # located in Stockholm County

  OPTIONAL { ?item wdt:P856 ?website. }
  OPTIONAL { ?item wdt:P3896 ?geojson. }
  OPTIONAL { ?item wdt:P402 ?osmRel. }
  OPTIONAL { ?item wdt:P10689 ?osmWay. }
  OPTIONAL { ?item wdt:P1281 ?NVRID. } # NVR ID
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
""")
sparql.setReturnFormat(JSON)

results = sparql.query().convert()

wd_reserves = []
for r in results["results"]["bindings"]:
    wd_reserves.append({
        "wikidata": r["item"]["value"].split("/")[-1],
        "label": r.get("itemLabel", {}).get("value"),
        "NVRID": r.get("NVRID", {}).get("value"),
        "geojson": r.get("geojson", {}).get("value"),
        "osmRel": r.get("osmRel", {}).get("value"),
        "osmWay": r.get("osmWay", {}).get("value"),
        "website_wd": r.get("website", {}).get("value")
    })

df_wd = pd.DataFrame(wd_reserves).drop_duplicates(subset=["wikidata"]).reset_index(drop=True)

print(f"Found {len(df_wd)} reserves in Wikidata (Stockholm län)")
display(df_wd.head())


# -------------------------------
# 3. Merge OSM ↔ Wikidata
# -------------------------------
df_merged = df_osm.merge(df_wd, on="wikidata", how="outer", suffixes=("_osm", "_wd"))

# -------------------------------
# 4. Sanity checks
# -------------------------------
# Missing Wikidata in OSM
missing_wd = df_merged[df_merged["wikidata"].isna() | df_merged["wikidata"].eq("")]
print("Reserves missing Wikidata in OSM:", len(missing_wd))

# Missing NVRID
missing_nvrid = df_merged[df_merged["NVRID"].isna() & df_merged["ref:NVRID"].isna()]
print("Reserves missing NVRID:", len(missing_nvrid))

# Website comparison
df_merged["website_match"] = df_merged.apply(
    lambda row: row["website_osm"] == row["website_wd"] if pd.notna(row["website_osm"]) and pd.notna(row["website_wd"]) else None,
    axis=1
)

mismatched_websites = df_merged[df_merged["website_match"] == False]

print("Reserves with mismatched websites:", len(mismatched_websites))

# -------------------------------
# 5. Display merged table
# -------------------------------
display(df_merged.head(30))
# Out:
# Found 393 reserves in OSM Stockholm län
#             osm_id                          name ref:NVRID   wikidata  \
# 0  node/6293895037  Dyviklövängars naturreservat      None       None
# 1     way/56660225                       Mödomen      None       None
# 2     way/56666596                  Fågelgrundet      None       None
# 3    way/103223526       Svalgarns naturreservat   2000166  Q30162772
# 4    way/103223545                   Talbyskogen      None  Q10690208
#
#                                          website_osm
# 0                                               None
# 1                                               None
# 2                                               None
# 3  https://www.upplands-bro.se/uppleva-och-gora/n...
# 4                                               None
# Found 374 reserves in Wikidata (Stockholm län)
#     wikidata                           label NVRID  \
# 0  Q29580026  Häverö prästängs naturreservat  None
# 1  Q30157780                            Oxön  None
# 2  Q30157868                      Gränskäret  None
# 3  Q30158128              Lidö naturreservat  None
# 4  Q30158284                        Mornäsan  None
#
#                                              geojson   osmRel     osmWay  \
# 0  http://commons.wikimedia.org/data/main/Data:/S...     None  103228133
# 1  http://commons.wikimedia.org/data/main/Data:/S...     None       None
# 2  http://commons.wikimedia.org/data/main/Data:/S...     None  103225936
# 3  http://commons.wikimedia.org/data/main/Data:/S...  1463761       None
# 4  http://commons.wikimedia.org/data/main/Data:/S...     None  103226788
#
#                                           website_wd
# 0  https://www.lansstyrelsen.se/stockholm/besoksm...
# 1                                               None
# 2                                               None
# 3  https://www.lansstyrelsen.se/stockholm/besoksm...
# 4                                               None
# Reserves missing Wikidata in OSM: 33
# Reserves missing NVRID: 208
# Reserves with mismatched websites: 17
#                osm_id                                               name  \
# 0     node/6293895037                       Dyviklövängars naturreservat
# 1        way/56660225                                            Mödomen
# 2        way/56666596                                       Fågelgrundet
# 3       way/163794719                                               None
# 4       way/353421146                                        Biotopskydd
# 5       way/447777489                                               None
# 6       way/531344162                        Mölnviks biotopskyddsområde
# 7       way/531344167                     Farstaborgs biotopskyddsområde
# 8       way/577604971                                        Biotopskydd
# 9       way/671858677                                               None
# 10      way/810325614                                               None
# 11      way/813054513                                               None
# 12      way/956060945                                  Fågelskyddsområde
# 13     way/1154068359                    Kursöskogen södra naturreservat
# 14     way/1154068368                   Mjölnarkärrskogens naturreservat
# 15     way/1154068387                               Färsna naturreservat
# 16     way/1337590798                                          Drevviken
# 17     way/1337590799                                          Drevviken
# 18     way/1337590800                                          Drevviken
# 19     way/1421656799                                               None
# 20   relation/1463775                                          Fårholmen
# 21   relation/1463792                                            Nåttarö
# 22   relation/7639571                       Ebbalunds biotopskyddsområde
# 23   relation/7639773                      Farstadals biotopskyddsområde
# 24   relation/8124667                                Biotopskydd 2003:96
# 25  relation/13929199                                          Fårholmen
# 26  relation/15596302                         Mälarskogens naturreservat
# 27  relation/15821511  Fågelskyddsområdet Vallboskär-Skrakholmen-Ersh...
# 28  relation/16033881                              Svärdsö naturreservat
# 29  relation/18267240                                         Uddaberget
#
#    ref:NVRID wikidata                                        website_osm  \
# 0       None     None                                               None
# 1       None     None                                               None
# 2       None     None                                               None
# 3       None     None                                               None
# 4       None     None                                               None
# 5       None     None                                               None
# 6       None     None                                               None
# 7       None     None                                               None
# 8       None     None                                               None
# 9       None     None                                               None
# 10      None     None                                               None
# 11      None     None                                               None
# 12      None     None                                               None
# 13   2056263     None                                               None
# 14   2056664     None  https://www.lansstyrelsen.se/stockholm/besoksm...
# 15   2052889     None  https://www.norrtalje.se/info/bo-och-miljo/nat...
# 16      None     None                                               None
# 17      None     None                                               None
# 18      None     None                                               None
# 19      None     None                                               None
# 20      None     None                                               None
# 21      None     None  https://www.lansstyrelsen.se/stockholm/besoksm...
# 22      None     None                                               None
# 23      None     None                                               None
# 24      None     None                                               None
# 25      None     None                                               None
# 26   2056266     None                                               None
# 27      None     None  https://www.lansstyrelsen.se/download/18.4e041...
# 28      None     None                                               None
# 29      None     None                                               None
#
#    label NVRID geojson osmRel osmWay website_wd website_match
# 0    NaN   NaN     NaN    NaN    NaN        NaN          None
# 1    NaN   NaN     NaN    NaN    NaN        NaN          None
# 2    NaN   NaN     NaN    NaN    NaN        NaN          None
# 3    NaN   NaN     NaN    NaN    NaN        NaN          None
# 4    NaN   NaN     NaN    NaN    NaN        NaN          None
# 5    NaN   NaN     NaN    NaN    NaN        NaN          None
# 6    NaN   NaN     NaN    NaN    NaN        NaN          None
# 7    NaN   NaN     NaN    NaN    NaN        NaN          None
# 8    NaN   NaN     NaN    NaN    NaN        NaN          None
# 9    NaN   NaN     NaN    NaN    NaN        NaN          None
# 10   NaN   NaN     NaN    NaN    NaN        NaN          None
# 11   NaN   NaN     NaN    NaN    NaN        NaN          None
# 12   NaN   NaN     NaN    NaN    NaN        NaN          None
# 13   NaN   NaN     NaN    NaN    NaN        NaN          None
# 14   NaN   NaN     NaN    NaN    NaN        NaN          None
# 15   NaN   NaN     NaN    NaN    NaN        NaN          None
# 16   NaN   NaN     NaN    NaN    NaN        NaN          None
# 17   NaN   NaN     NaN    NaN    NaN        NaN          None
# 18   NaN   NaN     NaN    NaN    NaN        NaN          None
# 19   NaN   NaN     NaN    NaN    NaN        NaN          None
# 20   NaN   NaN     NaN    NaN    NaN        NaN          None
# 21   NaN   NaN     NaN    NaN    NaN        NaN          None
# 22   NaN   NaN     NaN    NaN    NaN        NaN          None
# 23   NaN   NaN     NaN    NaN    NaN        NaN          None
# 24   NaN   NaN     NaN    NaN    NaN        NaN          None
# 25   NaN   NaN     NaN    NaN    NaN        NaN          None
# 26   NaN   NaN     NaN    NaN    NaN        NaN          None
# 27   NaN   NaN     NaN    NaN    NaN        NaN          None
# 28   NaN   NaN     NaN    NaN    NaN        NaN          None
# 29   NaN   NaN     NaN    NaN    NaN        NaN          None

# %% [markdown]
# ### What is needed to be cleaned

# %%
# -------------------------------
# 6. Flag geometry coverage
# -------------------------------
def geometry_status(row):
    if pd.notna(row["geojson"]) or pd.notna(row["osmRel"]) or pd.notna(row["osmWay"]):
        return "✅ Wikidata links to geometry"
    elif str(row["osm_id"]).startswith("way/") or str(row["osm_id"]).startswith("relation/"):
        return "✅ Geometry in OSM"
    else:
        return "⚠️ Missing geometry"

df_merged["geometry_status"] = df_merged.apply(geometry_status, axis=1)

# -------------------------------
# 7. Create TODO list
# -------------------------------
todos = []

for _, row in df_merged.iterrows():
    issues = []
    if pd.isna(row["wikidata"]):
        issues.append("Add Wikidata")
    if pd.isna(row["NVRID"]) and pd.isna(row["ref:NVRID"]):
        issues.append("Add NVRID")
    if row["website_match"] is False:
        issues.append("Fix website mismatch")
    if row["geometry_status"].startswith("⚠️"):
        issues.append("Add geometry")

    if issues:
        todos.append({
            "name": row.get("name") or row.get("label"),
            "osm_link": f"https://www.openstreetmap.org/{row['osm_id']}" if pd.notna(row["osm_id"]) else None,
            "wikidata_link": f"https://www.wikidata.org/wiki/{row['wikidata']}" if pd.notna(row["wikidata"]) else None,
            "issues": ", ".join(issues)
        })

df_todo = pd.DataFrame(todos)

display(df_todo.head(30))
print(f"Total TODOs: {len(df_todo)}")
# Out:
#                                                  name  \
# 0                        Dyviklövängars naturreservat
# 1                                             Mödomen
# 2                                        Fågelgrundet
# 3                                                 NaN
# 4                                         Biotopskydd
# 5                                                 NaN
# 6                         Mölnviks biotopskyddsområde
# 7                      Farstaborgs biotopskyddsområde
# 8                                         Biotopskydd
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                  Fågelskyddsområde
# 13                    Kursöskogen södra naturreservat
# 14                   Mjölnarkärrskogens naturreservat
# 15                               Färsna naturreservat
# 16                                          Drevviken
# 17                                          Drevviken
# 18                                          Drevviken
# 19                                                NaN
# 20                                          Fårholmen
# 21                                            Nåttarö
# 22                       Ebbalunds biotopskyddsområde
# 23                      Farstadals biotopskyddsområde
# 24                                Biotopskydd 2003:96
# 25                                          Fårholmen
# 26                         Mälarskogens naturreservat
# 27  Fågelskyddsområdet Vallboskär-Skrakholmen-Ersh...
# 28                              Svärdsö naturreservat
# 29                                         Uddaberget
#
#                                            osm_link wikidata_link  \
# 0     https://www.openstreetmap.org/node/6293895037          None
# 1        https://www.openstreetmap.org/way/56660225          None
# 2        https://www.openstreetmap.org/way/56666596          None
# 3       https://www.openstreetmap.org/way/163794719          None
# 4       https://www.openstreetmap.org/way/353421146          None
# 5       https://www.openstreetmap.org/way/447777489          None
# 6       https://www.openstreetmap.org/way/531344162          None
# 7       https://www.openstreetmap.org/way/531344167          None
# 8       https://www.openstreetmap.org/way/577604971          None
# 9       https://www.openstreetmap.org/way/671858677          None
# 10      https://www.openstreetmap.org/way/810325614          None
# 11      https://www.openstreetmap.org/way/813054513          None
# 12      https://www.openstreetmap.org/way/956060945          None
# 13     https://www.openstreetmap.org/way/1154068359          None
# 14     https://www.openstreetmap.org/way/1154068368          None
# 15     https://www.openstreetmap.org/way/1154068387          None
# 16     https://www.openstreetmap.org/way/1337590798          None
# 17     https://www.openstreetmap.org/way/1337590799          None
# 18     https://www.openstreetmap.org/way/1337590800          None
# 19     https://www.openstreetmap.org/way/1421656799          None
# 20   https://www.openstreetmap.org/relation/1463775          None
# 21   https://www.openstreetmap.org/relation/1463792          None
# 22   https://www.openstreetmap.org/relation/7639571          None
# 23   https://www.openstreetmap.org/relation/7639773          None
# 24   https://www.openstreetmap.org/relation/8124667          None
# 25  https://www.openstreetmap.org/relation/13929199          None
# 26  https://www.openstreetmap.org/relation/15596302          None
# 27  https://www.openstreetmap.org/relation/15821511          None
# 28  https://www.openstreetmap.org/relation/16033881          None
# 29  https://www.openstreetmap.org/relation/18267240          None
#
#                                    issues
# 0   Add Wikidata, Add NVRID, Add geometry
# 1                 Add Wikidata, Add NVRID
# 2                 Add Wikidata, Add NVRID
# 3                 Add Wikidata, Add NVRID
# 4                 Add Wikidata, Add NVRID
# 5                 Add Wikidata, Add NVRID
# 6                 Add Wikidata, Add NVRID
# 7                 Add Wikidata, Add NVRID
# 8                 Add Wikidata, Add NVRID
# 9                 Add Wikidata, Add NVRID
# 10                Add Wikidata, Add NVRID
# 11                Add Wikidata, Add NVRID
# 12                Add Wikidata, Add NVRID
# 13                           Add Wikidata
# 14                           Add Wikidata
# 15                           Add Wikidata
# 16                Add Wikidata, Add NVRID
# 17                Add Wikidata, Add NVRID
# 18                Add Wikidata, Add NVRID
# 19                Add Wikidata, Add NVRID
# 20                Add Wikidata, Add NVRID
# 21                Add Wikidata, Add NVRID
# 22                Add Wikidata, Add NVRID
# 23                Add Wikidata, Add NVRID
# 24                Add Wikidata, Add NVRID
# 25                Add Wikidata, Add NVRID
# 26                           Add Wikidata
# 27                Add Wikidata, Add NVRID
# 28                Add Wikidata, Add NVRID
# 29                Add Wikidata, Add NVRID
# Total TODOs: 227

# %%
# Convert TODO DataFrame into Markdown table

def df_to_markdown(df):
    lines = []
    # Header
    lines.append("| Name | OSM Link | Wikidata Link | Issues |")
    lines.append("|------|----------|---------------|--------|")
    
    for _, row in df.iterrows():
        name = row["name"] or ""
        
        # OSM link
        if pd.notna(row["osm_link"]):
            osm_link = f"[OSM]({row['osm_link']})"
        else:
            osm_link = "*(missing)*"
        
        # Wikidata link
        if pd.notna(row["wikidata_link"]):
            qid = row["wikidata_link"].split("/")[-1]
            wd_link = f"[{qid}]({row['wikidata_link']})"
        else:
            wd_link = "*(missing)*"
        
        issues = row["issues"] or ""
        
        lines.append(f"| {name} | {osm_link} | {wd_link} | {issues} |")
    
    return "\n".join(lines)

markdown_table = df_to_markdown(df_todo)
print(markdown_table)
# Out:
# | Name | OSM Link | Wikidata Link | Issues |
# |------|----------|---------------|--------|
# | Dyviklövängars naturreservat | [OSM](https://www.openstreetmap.org/node/6293895037) | *(missing)* | Add Wikidata, Add NVRID, Add geometry |
# | Mödomen | [OSM](https://www.openstreetmap.org/way/56660225) | *(missing)* | Add Wikidata, Add NVRID |
# | Fågelgrundet | [OSM](https://www.openstreetmap.org/way/56666596) | *(missing)* | Add Wikidata, Add NVRID |
# | nan | [OSM](https://www.openstreetmap.org/way/163794719) | *(missing)* | Add Wikidata, Add NVRID |
# | Biotopskydd | [OSM](https://www.openstreetmap.org/way/353421146) | *(missing)* | Add Wikidata, Add NVRID |
# | nan | [OSM](https://www.openstreetmap.org/way/447777489) | *(missing)* | Add Wikidata, Add NVRID |
# | Mölnviks biotopskyddsområde | [OSM](https://www.openstreetmap.org/way/531344162) | *(missing)* | Add Wikidata, Add NVRID |
# | Farstaborgs biotopskyddsområde | [OSM](https://www.openstreetmap.org/way/531344167) | *(missing)* | Add Wikidata, Add NVRID |
# | Biotopskydd | [OSM](https://www.openstreetmap.org/way/577604971) | *(missing)* | Add Wikidata, Add NVRID |
# | nan | [OSM](https://www.openstreetmap.org/way/671858677) | *(missing)* | Add Wikidata, Add NVRID |
# | nan | [OSM](https://www.openstreetmap.org/way/810325614) | *(missing)* | Add Wikidata, Add NVRID |
# | nan | [OSM](https://www.openstreetmap.org/way/813054513) | *(missing)* | Add Wikidata, Add NVRID |
# | Fågelskyddsområde | [OSM](https://www.openstreetmap.org/way/956060945) | *(missing)* | Add Wikidata, Add NVRID |
# | Kursöskogen södra naturreservat | [OSM](https://www.openstreetmap.org/way/1154068359) | *(missing)* | Add Wikidata |
# | Mjölnarkärrskogens naturreservat | [OSM](https://www.openstreetmap.org/way/1154068368) | *(missing)* | Add Wikidata |
# | Färsna naturreservat | [OSM](https://www.openstreetmap.org/way/1154068387) | *(missing)* | Add Wikidata |
# | Drevviken | [OSM](https://www.openstreetmap.org/way/1337590798) | *(missing)* | Add Wikidata, Add NVRID |
# | Drevviken | [OSM](https://www.openstreetmap.org/way/1337590799) | *(missing)* | Add Wikidata, Add NVRID |
# | Drevviken | [OSM](https://www.openstreetmap.org/way/1337590800) | *(missing)* | Add Wikidata, Add NVRID |
# | nan | [OSM](https://www.openstreetmap.org/way/1421656799) | *(missing)* | Add Wikidata, Add NVRID |
# | Fårholmen | [OSM](https://www.openstreetmap.org/relation/1463775) | *(missing)* | Add Wikidata, Add NVRID |
# | Nåttarö | [OSM](https://www.openstreetmap.org/relation/1463792) | *(missing)* | Add Wikidata, Add NVRID |
# | Ebbalunds biotopskyddsområde | [OSM](https://www.openstreetmap.org/relation/7639571) | *(missing)* | Add Wikidata, Add NVRID |
# | Farstadals biotopskyddsområde | [OSM](https://www.openstreetmap.org/relation/7639773) | *(missing)* | Add Wikidata, Add NVRID |
# | Biotopskydd 2003:96 | [OSM](https://www.openstreetmap.org/relation/8124667) | *(missing)* | Add Wikidata, Add NVRID |
# | Fårholmen | [OSM](https://www.openstreetmap.org/relation/13929199) | *(missing)* | Add Wikidata, Add NVRID |
# | Mälarskogens naturreservat | [OSM](https://www.openstreetmap.org/relation/15596302) | *(missing)* | Add Wikidata |
# | Fågelskyddsområdet Vallboskär-Skrakholmen-Ersholmen, Haninge kommun | [OSM](https://www.openstreetmap.org/relation/15821511) | *(missing)* | Add Wikidata, Add NVRID |
# | Svärdsö naturreservat | [OSM](https://www.openstreetmap.org/relation/16033881) | *(missing)* | Add Wikidata, Add NVRID |
# | Uddaberget | [OSM](https://www.openstreetmap.org/relation/18267240) | *(missing)* | Add Wikidata, Add NVRID |
# | Gribby naturreservat | [OSM](https://www.openstreetmap.org/relation/18273318) | *(missing)* | Add Wikidata |
# | Sticklinge Naturreservat | [OSM](https://www.openstreetmap.org/relation/18290186) | *(missing)* | Add Wikidata, Add NVRID |
# | Drevviken | [OSM](https://www.openstreetmap.org/relation/18328655) | *(missing)* | Add Wikidata, Add NVRID |
# | Talbyskogen | [OSM](https://www.openstreetmap.org/way/103223545) | [Q10690208](https://www.wikidata.org/wiki/Q10690208) | Add NVRID |
# | Oxnäset | [OSM](https://www.openstreetmap.org/way/103223586) | [Q30162674](https://www.wikidata.org/wiki/Q30162674) | Add NVRID |
# | Svenska Björn | [OSM](https://www.openstreetmap.org/way/103223783) | [Q10684954](https://www.wikidata.org/wiki/Q10684954) | Add NVRID |
# | Lindholmen | [OSM](https://www.openstreetmap.org/way/103223790) | [Q30162565](https://www.wikidata.org/wiki/Q30162565) | Add NVRID |
# | Kappsta | [OSM](https://www.openstreetmap.org/way/103223875) | [Q10543482](https://www.wikidata.org/wiki/Q10543482) | Add NVRID |
# | Storskär | [OSM](https://www.openstreetmap.org/way/103224006) | [Q30183496](https://www.wikidata.org/wiki/Q30183496) | Add NVRID |
# | Stora Alsjöns naturreservat | [OSM](https://www.openstreetmap.org/way/103224034) | [Q10680961](https://www.wikidata.org/wiki/Q10680961) | Fix website mismatch |
# | Rönninge by-Skavlöten | [OSM](https://www.openstreetmap.org/way/103224118) | [Q18332369](https://www.wikidata.org/wiki/Q18332369) | Add NVRID |
# | Lettholmen | [OSM](https://www.openstreetmap.org/way/103224154) | [Q30170346](https://www.wikidata.org/wiki/Q30170346) | Add NVRID |
# | Stavsudda-Krokholmen | [OSM](https://www.openstreetmap.org/way/103224263) | [Q30161862](https://www.wikidata.org/wiki/Q30161862) | Add NVRID |
# | Furusundsfjärden | [OSM](https://www.openstreetmap.org/way/103224343) | [Q30205045](https://www.wikidata.org/wiki/Q30205045) | Add NVRID |
# | Borgskogen | [OSM](https://www.openstreetmap.org/way/103224974) | [Q30158476](https://www.wikidata.org/wiki/Q30158476) | Add NVRID |
# | Stångskär | [OSM](https://www.openstreetmap.org/way/103225003) | [Q30175524](https://www.wikidata.org/wiki/Q30175524) | Add NVRID |
# | Gymmerholmen | [OSM](https://www.openstreetmap.org/way/103225642) | [Q30172747](https://www.wikidata.org/wiki/Q30172747) | Add NVRID |
# | Södra Stavsudda | [OSM](https://www.openstreetmap.org/way/103225795) | [Q30161366](https://www.wikidata.org/wiki/Q30161366) | Add NVRID |
# | Södergarn | [OSM](https://www.openstreetmap.org/way/103225808) | [Q10688520](https://www.wikidata.org/wiki/Q10688520) | Add NVRID |
# | Björinge | [OSM](https://www.openstreetmap.org/way/103225890) | [Q30160668](https://www.wikidata.org/wiki/Q30160668) | Add NVRID |
# | Gränskärets naturreservat | [OSM](https://www.openstreetmap.org/way/103225936) | [Q30157868](https://www.wikidata.org/wiki/Q30157868) | Add NVRID |
# | Parkudden i Lövsta | [OSM](https://www.openstreetmap.org/way/103225996) | [Q10620470](https://www.wikidata.org/wiki/Q10620470) | Add NVRID |
# | Grottberget | [OSM](https://www.openstreetmap.org/way/103226054) | [Q10509025](https://www.wikidata.org/wiki/Q10509025) | Add NVRID |
# | Ekholmen | [OSM](https://www.openstreetmap.org/way/103226188) | [Q18288878](https://www.wikidata.org/wiki/Q18288878) | Add NVRID |
# | Åvinge | [OSM](https://www.openstreetmap.org/way/103226271) | [Q16912291](https://www.wikidata.org/wiki/Q16912291) | Add NVRID |
# | Norrholmen | [OSM](https://www.openstreetmap.org/way/103226306) | [Q30207766](https://www.wikidata.org/wiki/Q30207766) | Add NVRID |
# | Broängarna | [OSM](https://www.openstreetmap.org/way/103226440) | [Q30184184](https://www.wikidata.org/wiki/Q30184184) | Add NVRID |
# | Vigelsjö | [OSM](https://www.openstreetmap.org/way/103226533) | [Q10715185](https://www.wikidata.org/wiki/Q10715185) | Add NVRID |
# | Långgrundet | [OSM](https://www.openstreetmap.org/way/103226598) | [Q10572595](https://www.wikidata.org/wiki/Q10572595) | Add NVRID |
# | Svenska Högarna | [OSM](https://www.openstreetmap.org/way/103226666) | [Q5238909](https://www.wikidata.org/wiki/Q5238909) | Add NVRID |
# | Stora Träsket | [OSM](https://www.openstreetmap.org/way/103226748) | [Q16912359](https://www.wikidata.org/wiki/Q16912359) | Add NVRID |
# | Tattby | [OSM](https://www.openstreetmap.org/way/103226828) | [Q25292306](https://www.wikidata.org/wiki/Q25292306) | Add NVRID |
# | Jägarskogen | [OSM](https://www.openstreetmap.org/way/103226889) | [Q30160077](https://www.wikidata.org/wiki/Q30160077) | Add NVRID |
# | Hällsboskogen | [OSM](https://www.openstreetmap.org/way/103227189) | [Q30160809](https://www.wikidata.org/wiki/Q30160809) | Add NVRID |
# | Norra Malma | [OSM](https://www.openstreetmap.org/way/103227357) | [Q30202073](https://www.wikidata.org/wiki/Q30202073) | Add NVRID |
# | Stora Vindåsen | [OSM](https://www.openstreetmap.org/way/103227397) | [Q10681161](https://www.wikidata.org/wiki/Q10681161) | Add NVRID |
# | Rönnskärs udde | [OSM](https://www.openstreetmap.org/way/103227484) | [Q30173769](https://www.wikidata.org/wiki/Q30173769) | Add NVRID |
# | Öbacken-Bränninge | [OSM](https://www.openstreetmap.org/way/103227770) | [Q10727059](https://www.wikidata.org/wiki/Q10727059) | Add NVRID |
# | Stavsudda-Tjägö | [OSM](https://www.openstreetmap.org/way/103227976) | [Q30167181](https://www.wikidata.org/wiki/Q30167181) | Add NVRID |
# | Lännaskogen | [OSM](https://www.openstreetmap.org/way/103228091) | [Q10571920](https://www.wikidata.org/wiki/Q10571920) | Add NVRID |
# | Fäviksgrundet | [OSM](https://www.openstreetmap.org/way/103228295) | [Q30174979](https://www.wikidata.org/wiki/Q30174979) | Add NVRID |
# | Skötkobbarna | [OSM](https://www.openstreetmap.org/way/103228380) | [Q30164733](https://www.wikidata.org/wiki/Q30164733) | Add NVRID |
# | Stensholmen | [OSM](https://www.openstreetmap.org/way/103228399) | [Q30167075](https://www.wikidata.org/wiki/Q30167075) | Add NVRID |
# | Ekebysjön | [OSM](https://www.openstreetmap.org/way/103228530) | [Q30164842](https://www.wikidata.org/wiki/Q30164842) | Add NVRID |
# | Gåsholmen | [OSM](https://www.openstreetmap.org/way/103228583) | [Q30199720](https://www.wikidata.org/wiki/Q30199720) | Add NVRID |
# | Öja-Landsort | [OSM](https://www.openstreetmap.org/way/103228585) | [Q108159298](https://www.wikidata.org/wiki/Q108159298) | Add NVRID |
# | Skansholmen | [OSM](https://www.openstreetmap.org/way/103228602) | [Q30158245](https://www.wikidata.org/wiki/Q30158245) | Add NVRID |
# | Hörningsnäs | [OSM](https://www.openstreetmap.org/way/103228609) | [Q10532621](https://www.wikidata.org/wiki/Q10532621) | Add NVRID |
# | Storö | [OSM](https://www.openstreetmap.org/way/103228650) | [Q29579991](https://www.wikidata.org/wiki/Q29579991) | Add NVRID |
# | Lina | [OSM](https://www.openstreetmap.org/way/103249491) | [Q10562401](https://www.wikidata.org/wiki/Q10562401) | Add NVRID |
# | Munkholmen | [OSM](https://www.openstreetmap.org/way/103249540) | [Q30160144](https://www.wikidata.org/wiki/Q30160144) | Add NVRID |
# | Askarehage | [OSM](https://www.openstreetmap.org/way/103249546) | [Q30159126](https://www.wikidata.org/wiki/Q30159126) | Add NVRID |
# | Sätraskogens naturreservat | [OSM](https://www.openstreetmap.org/way/103249558) | [Q10688197](https://www.wikidata.org/wiki/Q10688197) | Add NVRID |
# | Näsudden | [OSM](https://www.openstreetmap.org/way/103249601) | [Q30161686](https://www.wikidata.org/wiki/Q30161686) | Add NVRID |
# | Gömsta ängs naturreservat | [OSM](https://www.openstreetmap.org/way/209686481) | [Q10512650](https://www.wikidata.org/wiki/Q10512650) | Add NVRID |
# | Skeviks Grotta | [OSM](https://www.openstreetmap.org/way/364823651) | [Q10670113](https://www.wikidata.org/wiki/Q10670113) | Add NVRID |
# | Moraåns dalgång | [OSM](https://www.openstreetmap.org/way/396431799) | [Q30177152](https://www.wikidata.org/wiki/Q30177152) | Add NVRID |
# | Skogstorps naturreservat | [OSM](https://www.openstreetmap.org/way/1284729094) | [Q30169842](https://www.wikidata.org/wiki/Q30169842) | Fix website mismatch |
# | Vackstaskogens naturreservat | [OSM](https://www.openstreetmap.org/way/1284729095) | [Q30178564](https://www.wikidata.org/wiki/Q30178564) | Fix website mismatch |
# | Norra skogen | [OSM](https://www.openstreetmap.org/way/1331536835) | [Q133794691](https://www.wikidata.org/wiki/Q133794691) | Add NVRID |
# | Abborrträsks naturreservat | [OSM](https://www.openstreetmap.org/relation/1381602) | [Q10397880](https://www.wikidata.org/wiki/Q10397880) | Fix website mismatch |
# | Tranvik | [OSM](https://www.openstreetmap.org/relation/1463744) | [Q30177066](https://www.wikidata.org/wiki/Q30177066) | Add NVRID |
# | Ådö-Lagnö | [OSM](https://www.openstreetmap.org/relation/1463745) | [Q30160531](https://www.wikidata.org/wiki/Q30160531) | Add NVRID |
# | Gålö | [OSM](https://www.openstreetmap.org/relation/1463746) | [Q10512483](https://www.wikidata.org/wiki/Q10512483) | Add NVRID |
# | Skogsö | [OSM](https://www.openstreetmap.org/relation/1463747) | [Q3562577](https://www.wikidata.org/wiki/Q3562577) | Add NVRID |
# | Utö | [OSM](https://www.openstreetmap.org/relation/1463748) | [Q2301512](https://www.wikidata.org/wiki/Q2301512) | Add NVRID |
# | Velamsund | [OSM](https://www.openstreetmap.org/relation/1463751) | [Q23929994](https://www.wikidata.org/wiki/Q23929994) | Add NVRID |
# | Häringe-Hammersta | [OSM](https://www.openstreetmap.org/relation/1463754) | [Q10531642](https://www.wikidata.org/wiki/Q10531642) | Add NVRID |
# | Sundby naturreservat | [OSM](https://www.openstreetmap.org/relation/1463756) | [Q10683750](https://www.wikidata.org/wiki/Q10683750) | Add NVRID |
# | Bornsjön | [OSM](https://www.openstreetmap.org/relation/1463757) | [Q10433291](https://www.wikidata.org/wiki/Q10433291) | Add NVRID |
# | Gömmaren | [OSM](https://www.openstreetmap.org/relation/1463764) | [Q5626593](https://www.wikidata.org/wiki/Q5626593) | Add NVRID |
# | Grimsta naturreservat | [OSM](https://www.openstreetmap.org/relation/1463766) | [Q16928120](https://www.wikidata.org/wiki/Q16928120) | Add NVRID |
# | Ålö-Rånö naturreservat | [OSM](https://www.openstreetmap.org/relation/1463767) | [Q30164971](https://www.wikidata.org/wiki/Q30164971) | Add NVRID |
# | Yttereneby naturreservat | [OSM](https://www.openstreetmap.org/relation/1463768) | [Q10723827](https://www.wikidata.org/wiki/Q10723827) | Add NVRID |
# | Norra Björkfjärden | [OSM](https://www.openstreetmap.org/relation/1463770) | [Q56254846](https://www.wikidata.org/wiki/Q56254846) | Add NVRID |
# | Rävsta | [OSM](https://www.openstreetmap.org/relation/1463771) | [Q30159458](https://www.wikidata.org/wiki/Q30159458) | Add NVRID |
# | Jungfruskär | [OSM](https://www.openstreetmap.org/relation/1463774) | [Q10541386](https://www.wikidata.org/wiki/Q10541386) | Add NVRID |
# | Långängen-Elfvik | [OSM](https://www.openstreetmap.org/relation/1463776) | [Q10572706](https://www.wikidata.org/wiki/Q10572706) | Add NVRID |
# | Nämdö | [OSM](https://www.openstreetmap.org/relation/1463777) | [Q10605047](https://www.wikidata.org/wiki/Q10605047) | Add NVRID |
# | Björksättrahalvön | [OSM](https://www.openstreetmap.org/relation/1463778) | [Q10430621](https://www.wikidata.org/wiki/Q10430621) | Add NVRID |
# | Huvudskärs naturreservat | [OSM](https://www.openstreetmap.org/relation/1463779) | [Q5951207](https://www.wikidata.org/wiki/Q5951207) | Add NVRID |
# | Äpplarö | [OSM](https://www.openstreetmap.org/relation/1463780) | [Q30171561](https://www.wikidata.org/wiki/Q30171561) | Add NVRID |
# | Paradisets naturreservat | [OSM](https://www.openstreetmap.org/relation/1463782) | [Q10617534](https://www.wikidata.org/wiki/Q10617534) | Fix website mismatch |
# | Örens naturreservat | [OSM](https://www.openstreetmap.org/relation/1463783) | [Q19979180](https://www.wikidata.org/wiki/Q19979180) | Fix website mismatch |
# | Stora Nassa | [OSM](https://www.openstreetmap.org/relation/1463785) | [Q10681079](https://www.wikidata.org/wiki/Q10681079) | Add NVRID, Fix website mismatch |
# | Björnö | [OSM](https://www.openstreetmap.org/relation/1463786) | [Q26196467](https://www.wikidata.org/wiki/Q26196467) | Add NVRID |
# | Fjärdlångs naturreservat | [OSM](https://www.openstreetmap.org/relation/1463788) | [Q1422492](https://www.wikidata.org/wiki/Q1422492) | Add NVRID, Fix website mismatch |
# | Orlångens naturreservat | [OSM](https://www.openstreetmap.org/relation/1463797) | [Q10611591](https://www.wikidata.org/wiki/Q10611591) | Add NVRID |
# | Flaten | [OSM](https://www.openstreetmap.org/relation/1463799) | [Q10496362](https://www.wikidata.org/wiki/Q10496362) | Add NVRID |
# | Slessbergets naturreservat | [OSM](https://www.openstreetmap.org/relation/1463801) | [Q10671555](https://www.wikidata.org/wiki/Q10671555) | Fix website mismatch |
# | Hallonstenarnas naturreservat | [OSM](https://www.openstreetmap.org/relation/1463802) | [Q30180517](https://www.wikidata.org/wiki/Q30180517) | Add NVRID |
# | Tornbergets naturreservat | [OSM](https://www.openstreetmap.org/relation/1464356) | [Q10700136](https://www.wikidata.org/wiki/Q10700136) | Add NVRID |
# | Långviksträsk | [OSM](https://www.openstreetmap.org/relation/1464358) | [Q24197187](https://www.wikidata.org/wiki/Q24197187) | Add NVRID |
# | Sköndalsskogen | [OSM](https://www.openstreetmap.org/relation/1464359) | [Q30160125](https://www.wikidata.org/wiki/Q30160125) | Add NVRID |
# | Ösbyträsks naturreservat | [OSM](https://www.openstreetmap.org/relation/1464360) | [Q21281541](https://www.wikidata.org/wiki/Q21281541) | Add NVRID |
# | Steningedalen | [OSM](https://www.openstreetmap.org/relation/1464362) | [Q30170229](https://www.wikidata.org/wiki/Q30170229) | Add NVRID |
# | Alby naturreservat | [OSM](https://www.openstreetmap.org/relation/2651046) | [Q10404424](https://www.wikidata.org/wiki/Q10404424) | Add NVRID |
# | Eriksö naturreservat | [OSM](https://www.openstreetmap.org/relation/2749565) | [Q10487760](https://www.wikidata.org/wiki/Q10487760) | Fix website mismatch |
# | Kålsö naturreservat | [OSM](https://www.openstreetmap.org/relation/2749566) | [Q10552025](https://www.wikidata.org/wiki/Q10552025) | Fix website mismatch |
# | Ensta ö | [OSM](https://www.openstreetmap.org/relation/3820225) | [Q16912292](https://www.wikidata.org/wiki/Q16912292) | Add NVRID |
# | Vinterskogen | [OSM](https://www.openstreetmap.org/relation/3820244) | [Q10715845](https://www.wikidata.org/wiki/Q10715845) | Add NVRID |
# | Korpbergets naturreservat | [OSM](https://www.openstreetmap.org/relation/3830003) | [Q10548129](https://www.wikidata.org/wiki/Q10548129) | Fix website mismatch |
# | Ekoberget | [OSM](https://www.openstreetmap.org/relation/5748169) | [Q10480665](https://www.wikidata.org/wiki/Q10480665) | Add NVRID |
# | Långsjöns naturreservat | [OSM](https://www.openstreetmap.org/relation/5925720) | [Q18292085](https://www.wikidata.org/wiki/Q18292085) | Add NVRID |
# | Kyrksjölöten | [OSM](https://www.openstreetmap.org/relation/6010059) | [Q10551536](https://www.wikidata.org/wiki/Q10551536) | Add NVRID |
# | Tollare naturreservat | [OSM](https://www.openstreetmap.org/relation/6376975) | [Q25269455](https://www.wikidata.org/wiki/Q25269455) | Add NVRID |
# | Nyckelviken | [OSM](https://www.openstreetmap.org/relation/6378765) | [Q10604417](https://www.wikidata.org/wiki/Q10604417) | Add NVRID |
# | Nackareservatet | [OSM](https://www.openstreetmap.org/relation/8466908) | [Q30199475](https://www.wikidata.org/wiki/Q30199475) | Add NVRID |
# | Lovö naturreservat | [OSM](https://www.openstreetmap.org/relation/8467810) | [Q2625471](https://www.wikidata.org/wiki/Q2625471) | Add NVRID |
# | Södra Törnskogens naturreservat | [OSM](https://www.openstreetmap.org/relation/8494866) | [Q30174497](https://www.wikidata.org/wiki/Q30174497) | Add NVRID, Fix website mismatch |
# | Fifång | [OSM](https://www.openstreetmap.org/relation/8521592) | [Q18289763](https://www.wikidata.org/wiki/Q18289763) | Add NVRID |
# | Kullö | [OSM](https://www.openstreetmap.org/relation/8537591) | [Q30206095](https://www.wikidata.org/wiki/Q30206095) | Add NVRID |
# | Öarna i Stora Värtan | [OSM](https://www.openstreetmap.org/relation/8537631) | [Q30170445](https://www.wikidata.org/wiki/Q30170445) | Add NVRID |
# | Bogesundslandet | [OSM](https://www.openstreetmap.org/relation/8537632) | [Q30181662](https://www.wikidata.org/wiki/Q30181662) | Add NVRID |
# | Gärdesudden | [OSM](https://www.openstreetmap.org/relation/9344353) | [Q10512354](https://www.wikidata.org/wiki/Q10512354) | Add NVRID |
# | Huvudholmen | [OSM](https://www.openstreetmap.org/relation/9348944) | [Q28485678](https://www.wikidata.org/wiki/Q28485678) | Add NVRID |
# | Mörtö-Bunsö | [OSM](https://www.openstreetmap.org/relation/9348947) | [Q10593699](https://www.wikidata.org/wiki/Q10593699) | Add NVRID |
# | Boskapsön | [OSM](https://www.openstreetmap.org/relation/9367179) | [Q10433446](https://www.wikidata.org/wiki/Q10433446) | Add NVRID |
# | Rosenlundsskogen | [OSM](https://www.openstreetmap.org/relation/9367812) | [Q19721299](https://www.wikidata.org/wiki/Q19721299) | Add NVRID |
# | Aspdalssjön | [OSM](https://www.openstreetmap.org/relation/9769162) | [Q30161455](https://www.wikidata.org/wiki/Q30161455) | Add NVRID |
# | Rågsveds naturreservat | [OSM](https://www.openstreetmap.org/relation/10424979) | [Q57270510](https://www.wikidata.org/wiki/Q57270510) | Add NVRID |
# | Rösjöskogen | [OSM](https://www.openstreetmap.org/relation/10519502) | [Q30172755](https://www.wikidata.org/wiki/Q30172755) | Add NVRID |
# | Norra Igelbäcken | [OSM](https://www.openstreetmap.org/relation/10520741) | [Q55693494](https://www.wikidata.org/wiki/Q55693494) | Add NVRID |
# | Vidinge naturreservat | [OSM](https://www.openstreetmap.org/relation/10626043) | [Q10715120](https://www.wikidata.org/wiki/Q10715120) | Add NVRID |
# | Vickelsjön | [OSM](https://www.openstreetmap.org/relation/10626044) | [Q30169361](https://www.wikidata.org/wiki/Q30169361) | Add NVRID |
# | Stora Sunnkobben | [OSM](https://www.openstreetmap.org/relation/10626045) | [Q30172916](https://www.wikidata.org/wiki/Q30172916) | Add NVRID |
# | Norrpada | [OSM](https://www.openstreetmap.org/relation/10626047) | [Q10602924](https://www.wikidata.org/wiki/Q10602924) | Add NVRID |
# | Kudoxa | [OSM](https://www.openstreetmap.org/relation/10626049) | [Q10549793](https://www.wikidata.org/wiki/Q10549793) | Add NVRID |
# | Hallskäret | [OSM](https://www.openstreetmap.org/relation/10626052) | [Q30197151](https://www.wikidata.org/wiki/Q30197151) | Add NVRID |
# | Vidingsöra | [OSM](https://www.openstreetmap.org/relation/10626054) | [Q10715125](https://www.wikidata.org/wiki/Q10715125) | Add NVRID |
# | Lilla Husarn | [OSM](https://www.openstreetmap.org/relation/10626305) | [Q10561728](https://www.wikidata.org/wiki/Q10561728) | Add NVRID |
# | Svartkobben | [OSM](https://www.openstreetmap.org/relation/10626310) | [Q30158121](https://www.wikidata.org/wiki/Q30158121) | Add NVRID |
# | Skogsskär-Vindalsö | [OSM](https://www.openstreetmap.org/relation/10626311) | [Q30166889](https://www.wikidata.org/wiki/Q30166889) | Add NVRID |
# | Hästholmen | [OSM](https://www.openstreetmap.org/relation/10626313) | [Q30159080](https://www.wikidata.org/wiki/Q30159080) | Add NVRID |
# | Grönskär | [OSM](https://www.openstreetmap.org/relation/10626314) | [Q30161336](https://www.wikidata.org/wiki/Q30161336) | Add NVRID |
# | Dävelsöfjärden | [OSM](https://www.openstreetmap.org/relation/10626315) | [Q30158226](https://www.wikidata.org/wiki/Q30158226) | Add NVRID |
# | Vindalsö | [OSM](https://www.openstreetmap.org/relation/10626316) | [Q10715681](https://www.wikidata.org/wiki/Q10715681) | Add NVRID |
# | Angödrommen | [OSM](https://www.openstreetmap.org/relation/10626317) | [Q30162836](https://www.wikidata.org/wiki/Q30162836) | Add NVRID |
# | Stor-Kunnan | [OSM](https://www.openstreetmap.org/relation/10626318) | [Q30163326](https://www.wikidata.org/wiki/Q30163326) | Add NVRID |
# | Kålgårdsöns naturreservat | [OSM](https://www.openstreetmap.org/relation/10626459) | [Q30162906](https://www.wikidata.org/wiki/Q30162906) | Add NVRID |
# | Halsfambaken | [OSM](https://www.openstreetmap.org/relation/10626460) | [Q30169901](https://www.wikidata.org/wiki/Q30169901) | Add NVRID |
# | Gälnan | [OSM](https://www.openstreetmap.org/relation/10626461) | [Q30183563](https://www.wikidata.org/wiki/Q30183563) | Add NVRID |
# | Rudan | [OSM](https://www.openstreetmap.org/relation/10626565) | [Q10657592](https://www.wikidata.org/wiki/Q10657592) | Add NVRID |
# | Stora och Lilla Sandböte | [OSM](https://www.openstreetmap.org/relation/10626566) | [Q10681160](https://www.wikidata.org/wiki/Q10681160) | Add NVRID |
# | Bårsjöns naturreservat | [OSM](https://www.openstreetmap.org/relation/10626682) | [Q10438614](https://www.wikidata.org/wiki/Q10438614) | Fix website mismatch |
# | Frölunda | [OSM](https://www.openstreetmap.org/relation/10626956) | [Q30176496](https://www.wikidata.org/wiki/Q30176496) | Add NVRID |
# | Broknapparna | [OSM](https://www.openstreetmap.org/relation/10626957) | [Q30158406](https://www.wikidata.org/wiki/Q30158406) | Add NVRID |
# | Eldgarnsö | [OSM](https://www.openstreetmap.org/relation/10626958) | [Q10481121](https://www.wikidata.org/wiki/Q10481121) | Add NVRID |
# | Djurgård | [OSM](https://www.openstreetmap.org/relation/10626959) | [Q30165719](https://www.wikidata.org/wiki/Q30165719) | Add NVRID |
# | Sättra gård | [OSM](https://www.openstreetmap.org/relation/10627072) | [Q10688215](https://www.wikidata.org/wiki/Q10688215) | Add NVRID |
# | Lejondal | [OSM](https://www.openstreetmap.org/relation/10627074) | [Q30160742](https://www.wikidata.org/wiki/Q30160742) | Add NVRID |
# | Molnsättra | [OSM](https://www.openstreetmap.org/relation/10627920) | [Q29184800](https://www.wikidata.org/wiki/Q29184800) | Add NVRID |
# | Östra Järvafältet | [OSM](https://www.openstreetmap.org/relation/10627921) | [Q30158554](https://www.wikidata.org/wiki/Q30158554) | Add NVRID |
# | Västra Järvafältet | [OSM](https://www.openstreetmap.org/relation/10627922) | [Q30204726](https://www.wikidata.org/wiki/Q30204726) | Add NVRID |
# | Hansta | [OSM](https://www.openstreetmap.org/relation/10627923) | [Q18290510](https://www.wikidata.org/wiki/Q18290510) | Add NVRID |
# | Norra Törnskogens naturreservat | [OSM](https://www.openstreetmap.org/relation/10627924) | [Q30178285](https://www.wikidata.org/wiki/Q30178285) | Add NVRID |
# | Tegelhagsskogen | [OSM](https://www.openstreetmap.org/relation/10630961) | [Q30201771](https://www.wikidata.org/wiki/Q30201771) | Add NVRID |
# | Igelbäcken i Sundbyberg | [OSM](https://www.openstreetmap.org/relation/10630962) | [Q30170922](https://www.wikidata.org/wiki/Q30170922) | Add NVRID |
# | Igelbäckens naturreservat | [OSM](https://www.openstreetmap.org/relation/10630963) | [Q30162337](https://www.wikidata.org/wiki/Q30162337) | Add NVRID |
# | Trångsundsskogen | [OSM](https://www.openstreetmap.org/relation/10631201) | [Q10705665](https://www.wikidata.org/wiki/Q10705665) | Add NVRID |
# | Älta mosse-Strålsjön | [OSM](https://www.openstreetmap.org/relation/10631203) | [Q25292173](https://www.wikidata.org/wiki/Q25292173) | Add NVRID |
# | Strålsjön-Erstavik | [OSM](https://www.openstreetmap.org/relation/10631204) | [Q25292148](https://www.wikidata.org/wiki/Q25292148) | Add NVRID |
# | Nackareservatet i Stockholm | [OSM](https://www.openstreetmap.org/relation/10631205) | [Q30177527](https://www.wikidata.org/wiki/Q30177527) | Add NVRID |
# | Lida | [OSM](https://www.openstreetmap.org/relation/10631429) | [Q30158356](https://www.wikidata.org/wiki/Q30158356) | Add NVRID |
# | Garnudden | [OSM](https://www.openstreetmap.org/relation/10631430) | [Q18290091](https://www.wikidata.org/wiki/Q18290091) | Add NVRID |
# | Älvsjöskogen | [OSM](https://www.openstreetmap.org/relation/10631431) | [Q10725781](https://www.wikidata.org/wiki/Q10725781) | Add NVRID |
# | Flemingsbergsskogen | [OSM](https://www.openstreetmap.org/relation/10631432) | [Q5458610](https://www.wikidata.org/wiki/Q5458610) | Add NVRID |
# | Gladöskogen | [OSM](https://www.openstreetmap.org/relation/10631433) | [Q10505222](https://www.wikidata.org/wiki/Q10505222) | Add NVRID |
# | Vånsholmen | [OSM](https://www.openstreetmap.org/relation/10992515) | [Q30158217](https://www.wikidata.org/wiki/Q30158217) | Add NVRID |
# | Hamnskogen-Eriksberg | [OSM](https://www.openstreetmap.org/relation/11901220) | [Q30160722](https://www.wikidata.org/wiki/Q30160722) | Add NVRID |
# | Bullerskär | [OSM](https://www.openstreetmap.org/relation/12865306) | [Q30160705](https://www.wikidata.org/wiki/Q30160705) | Add NVRID |
# | Lötsjön-Golfängarnas naturreservat | [OSM](https://www.openstreetmap.org/relation/13011639) | [Q55693514](https://www.wikidata.org/wiki/Q55693514) | Add NVRID |
# | Råstasjöns naturreservat | [OSM](https://www.openstreetmap.org/relation/13011640) | [Q55693512](https://www.wikidata.org/wiki/Q55693512) | Fix website mismatch |
# | Judarskogen | [OSM](https://www.openstreetmap.org/relation/14437333) | [Q10541053](https://www.wikidata.org/wiki/Q10541053) | Add NVRID |
# | Korshamn | [OSM](https://www.openstreetmap.org/relation/15425988) | [Q30208639](https://www.wikidata.org/wiki/Q30208639) | Add NVRID |
# | Trollsjöns naturreservat | [OSM](https://www.openstreetmap.org/relation/16033876) | [Q30162135](https://www.wikidata.org/wiki/Q30162135) | Add NVRID |
# | Hamnskärs naturreservat | [OSM](https://www.openstreetmap.org/relation/18247369) | [Q89399237](https://www.wikidata.org/wiki/Q89399237) | Fix website mismatch |
# | Björkby-Kyrkvikens naturreservat | [OSM](https://www.openstreetmap.org/relation/18254668) | [Q30161744](https://www.wikidata.org/wiki/Q30161744) | Fix website mismatch |
# | nan | *(missing)* | [Q30163211](https://www.wikidata.org/wiki/Q30163211) | Add NVRID |
# | nan | *(missing)* | [Q30170945](https://www.wikidata.org/wiki/Q30170945) | Add NVRID |
# | nan | *(missing)* | [Q30158607](https://www.wikidata.org/wiki/Q30158607) | Add NVRID |
# | nan | *(missing)* | [Q134587569](https://www.wikidata.org/wiki/Q134587569) | Add NVRID |
# | nan | *(missing)* | [Q124467604](https://www.wikidata.org/wiki/Q124467604) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q10541993](https://www.wikidata.org/wiki/Q10541993) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q29580016](https://www.wikidata.org/wiki/Q29580016) | Add NVRID |
# | nan | *(missing)* | [Q29580017](https://www.wikidata.org/wiki/Q29580017) | Add NVRID |
# | nan | *(missing)* | [Q30160624](https://www.wikidata.org/wiki/Q30160624) | Add NVRID |
# | nan | *(missing)* | [Q124474431](https://www.wikidata.org/wiki/Q124474431) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q124474524](https://www.wikidata.org/wiki/Q124474524) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q124660839](https://www.wikidata.org/wiki/Q124660839) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q133794690](https://www.wikidata.org/wiki/Q133794690) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q133794775](https://www.wikidata.org/wiki/Q133794775) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q6957282](https://www.wikidata.org/wiki/Q6957282) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q10593514](https://www.wikidata.org/wiki/Q10593514) | Add NVRID |
# | nan | *(missing)* | [Q26256700](https://www.wikidata.org/wiki/Q26256700) | Add NVRID |
# | nan | *(missing)* | [Q133794720](https://www.wikidata.org/wiki/Q133794720) | Add NVRID, Add geometry |
# | nan | *(missing)* | [Q124660694](https://www.wikidata.org/wiki/Q124660694) | Add NVRID, Add geometry |

# %%
# !pip install rapidfuzz
# Out:
# Requirement already satisfied: rapidfuzz in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.14.1)

# %%
import requests
import xml.etree.ElementTree as ET
import geopandas as gpd
import os

feed_url = "https://geodata.naturvardsverket.se/atom/inspire/ps/SE_ProtectedSitesN2K_serviceFeed.xml"

resp = requests.get(feed_url)
root = ET.fromstring(resp.content)

ns = {"atom": "http://www.w3.org/2005/Atom"}
entries = root.findall("atom:entry", ns)

download_links = []
for e in entries:
    link = e.find("atom:link", ns).attrib.get("href")
    title = e.find("atom:title", ns).text
    download_links.append((title, link))

print("Found dataset links:")
for title, link in download_links:
    print(f"- {title}: {link}")

# Pick one link manually for now
title, link = download_links[0]
print("Downloading:", title, link)

resp = requests.get(link)

# Save to file with proper extension
fname = os.path.basename(link.split("?")[0])
with open(fname, "wb") as f:
    f.write(resp.content)

print("Saved as:", fname)

# Try reading directly
try:
    gdf = gpd.read_file(fname)
    print("Loaded directly into GeoDataFrame")
except Exception as e:
    print("Direct load failed:", e)
# Out:
# Found dataset links:
# - Nedladdningstjänst för data som ingår i INSPIRE bilaga 1, Natura 2000, Art- och habitatdirektivet (SCI): https://www.geodata.se/geodataportalen/srv/eng/csw-inspire?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=945e918f-8426-4155-8fd6-3f780a85dd8f&outputSchema=csw:IsoRecord
# - Nedladdningstjänst för data som ingår i INSPIRE bilaga 1, Natura 2000, Fågeldirektivet (SPA): https://www.geodata.se/geodataportalen/srv/eng/csw-inspire?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=a80bf3d7-e70c-42d1-9b8d-8148e53e011d&outputSchema=csw:IsoRecord
# Downloading: Nedladdningstjänst för data som ingår i INSPIRE bilaga 1, Natura 2000, Art- och habitatdirektivet (SCI) https://www.geodata.se/geodataportalen/srv/eng/csw-inspire?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=945e918f-8426-4155-8fd6-3f780a85dd8f&outputSchema=csw:IsoRecord
# Saved as: csw-inspire
# Direct load failed: index 0 is out of bounds for axis 0 with size 0

# %%
from rapidfuzz import process, fuzz

def normalize_name(name):
    if not isinstance(name, str):
        return ""
    name = name.lower()
    name = name.replace("naturreservat", "").replace("nr", "")
    name = name.strip()
    return name

# Normalize names
df_osm["name_norm"] = df_osm["name"].apply(normalize_name)
df_wd["label_norm"] = df_wd["label"].apply(normalize_name)
df_sn["name_norm"] = df_sn["NAMN"].apply(normalize_name)

# Try fuzzy match OSM → Wikidata
matches = []
for idx, row in df_osm.iterrows():
    name = row["name_norm"]
    match, score, _ = process.extractOne(name, df_wd["label_norm"], scorer=fuzz.ratio)
    if score > 80:  # threshold
        wd_row = df_wd[df_wd["label_norm"] == match].iloc[0]
        matches.append({
            "osm_id": row["osm_id"],
            "osm_name": row["name"],
            "wikidata": wd_row["wikidata"],
            "wd_label": wd_row["label"],
            "score": score
        })

df_matches = pd.DataFrame(matches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 14
#      12 df_osm["name_norm"] = df_osm["name"].apply(normalize_name)
#      13 df_wd["label_norm"] = df_wd["label"].apply(normalize_name)
# ---> 14 df_sn["name_norm"] = df_sn["NAMN"].apply(normalize_name)
#      16 # Try fuzzy match OSM → Wikidata
#      17 matches = []
#
# NameError: name 'df_sn' is not defined

# %%
import requests
import xml.etree.ElementTree as ET
import geopandas as gpd
import os

def get_atom_entries(feed_url):
    """Parse an ATOM feed and return (title, link) tuples."""
    resp = requests.get(feed_url)
    root = ET.fromstring(resp.content)
    ns = {"atom": "http://www.w3.org/2005/Atom"}
    entries = root.findall("atom:entry", ns)
    return [(e.find("atom:title", ns).text, e.find("atom:link", ns).attrib.get("href")) for e in entries]

def get_metadata_links(meta_url):
    """Parse CSW metadata record and extract dataset URLs."""
    resp = requests.get(meta_url)
    root = ET.fromstring(resp.content)
    urls = []
    for elem in root.iter():
        if elem.text and "http" in elem.text:
            urls.append(elem.text.strip())
    return urls

def download_dataset(url, outdir="data"):
    """Download dataset file and return path."""
    os.makedirs(outdir, exist_ok=True)
    fname = os.path.join(outdir, os.path.basename(url.split("?")[0]))
    r = requests.get(url)
    with open(fname, "wb") as f:
        f.write(r.content)
    return fname

# --- Step 1: ATOM feed for ProtectedSites
feed_url = "https://geodata.naturvardsverket.se/atom/inspire/ps/SE_ProtectedSitesN2K_serviceFeed.xml"
entries = get_atom_entries(feed_url)

print("ATOM entries found:")
for title, link in entries:
    print("-", title, link)

# --- Step 2: Pick one entry and follow to metadata
title, meta_url = entries[0]
print("\nFollowing metadata link:", meta_url)
dataset_links = get_metadata_links(meta_url)

print("Dataset links found in metadata:")
for dl in dataset_links:
    print("-", dl)

# --- Step 3: Pick first dataset link and download
if dataset_links:
    dataset_url = [u for u in dataset_links if u.endswith((".zip", ".gml", ".gpkg"))][0]
    fname = download_dataset(dataset_url)
    print("\nDownloaded dataset:", fname)

    # --- Step 4: Try reading with GeoPandas
    try:
        gdf = gpd.read_file(fname)
        print("Loaded dataset into GeoDataFrame with", len(gdf), "features")
        print(gdf.head())
    except Exception as e:
        print("Could not load with GeoPandas:", e)
# Out:
# ATOM entries found:
# - Nedladdningstjänst för data som ingår i INSPIRE bilaga 1, Natura 2000, Art- och habitatdirektivet (SCI) https://www.geodata.se/geodataportalen/srv/eng/csw-inspire?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=945e918f-8426-4155-8fd6-3f780a85dd8f&outputSchema=csw:IsoRecord
# - Nedladdningstjänst för data som ingår i INSPIRE bilaga 1, Natura 2000, Fågeldirektivet (SPA) https://www.geodata.se/geodataportalen/srv/eng/csw-inspire?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=a80bf3d7-e70c-42d1-9b8d-8148e53e011d&outputSchema=csw:IsoRecord
#
# Following metadata link: https://www.geodata.se/geodataportalen/srv/eng/csw-inspire?request=GetRecordById&service=CSW&version=2.0.2&elementSetName=full&id=945e918f-8426-4155-8fd6-3f780a85dd8f&outputSchema=csw:IsoRecord
# Dataset links found in metadata:
# - http://www.opengis.net/def/crs/EPSG/0/3006
# - Creative commons  CC0 1.0 Universiell
#
# DU HAR TILLSTÅND ATT:
# Personen som associerat ett verk med detta dokument har dedikerat verket till public domain
# genom att avsäga sig sina rättigheter till verket i hela världen enligt upphovsrättslagstiftningen,
# inklusive alla relaterade och närstående rättigheter, så lågt lagen tillåter.
#
# Du får kopiera, modifiera, distribuera och framföra verket,
# även i kommersiellt syfte,
# utan att fråga om lov. Se Annan information nedan.
#
# Kortfattad beskrivning: https://creativecommons.org/publicdomain/zero/1.0/deed.sv
# Full licenstext: https://creativecommons.org/publicdomain/zero/1.0/legalcode.sv
# - https://www.naturvardsverket.se/amnesomraden/skyddad-natur/olika-former-av-naturskydd/natura-2000-omraden/
# - https://geodata.naturvardsverket.se/inspire/ps-n2k/ows?
# - https://geodata.naturvardsverket.se/nedladdning/naturvardsregistret/SCI_Rikstackande.zip
# - https://geodata.naturvardsverket.se/atom/inspire/ps/SE_ProtectedSitesN2K_serviceFeed.xml
# - https://geodata.naturvardsverket.se/inspire/ps-n2k/wfs?
# - https://www.naturvardsverket.se/amnesomraden/skyddad-natur/olika-former-av-naturskydd/natura-2000-omraden/
# - https://geodata.naturvardsverket.se/inspire/ps-n2k/ows?
# - https://geodata.naturvardsverket.se/nedladdning/naturvardsregistret/SCI_Rikstackande.zip
# - https://geodata.naturvardsverket.se/atom/inspire/ps/SE_ProtectedSitesN2K_serviceFeed.xml
# - https://geodata.naturvardsverket.se/inspire/ps-n2k/wfs?
#
# Downloaded dataset: data/SCI_Rikstackande.zip
# Could not load with GeoPandas: '/vsizip/data/SCI_Rikstackande.zip' not recognized as being in a supported file format.; It might help to specify the correct driver explicitly by prefixing the file path with '<DRIVER>:', e.g. 'CSV:path'.

# %%
import zipfile, os, geopandas as gpd

zip_path = "data/SCI_Rikstackande.zip"
extract_dir = "data/SCI_Rikstackande"

# Unzip
with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_dir)

# Find .shp file inside
shp_files = [f for f in os.listdir(extract_dir) if f.endswith(".shp")]
print("Shapefiles found:", shp_files)

# Load the first shapefile
if shp_files:
    shp_path = os.path.join(extract_dir, shp_files[0])
    gdf = gpd.read_file(shp_path)
    print("Loaded", len(gdf), "features")
    print(gdf.head())
# Out:
# Shapefiles found: []

# %%
import zipfile

with zipfile.ZipFile("data/SCI_Rikstackande.zip") as z:
    print(z.namelist())
# Out:
# ['SCI_alvar_AC_lan/', 'SCI_alvar_BD_lan/', 'SCI_ej_alvar_rikstackande/', 'SCI_alvar_AC_lan/SCI_alvar_AC_lan.cpg', 'SCI_alvar_AC_lan/SCI_alvar_AC_lan.dbf', 'SCI_alvar_AC_lan/SCI_alvar_AC_lan.prj', 'SCI_alvar_AC_lan/SCI_alvar_AC_lan.shp', 'SCI_alvar_AC_lan/SCI_alvar_AC_lan.shx', 'SCI_alvar_BD_lan/SCI_alvar_BD_lan.cpg', 'SCI_alvar_BD_lan/SCI_alvar_BD_lan.dbf', 'SCI_alvar_BD_lan/SCI_alvar_BD_lan.prj', 'SCI_alvar_BD_lan/SCI_alvar_BD_lan.shp', 'SCI_alvar_BD_lan/SCI_alvar_BD_lan.shx', 'SCI_ej_alvar_rikstackande/SCI_ej_alvar_rikstackande.cpg', 'SCI_ej_alvar_rikstackande/SCI_ej_alvar_rikstackande.dbf', 'SCI_ej_alvar_rikstackande/SCI_ej_alvar_rikstackande.prj', 'SCI_ej_alvar_rikstackande/SCI_ej_alvar_rikstackande.shp', 'SCI_ej_alvar_rikstackande/SCI_ej_alvar_rikstackande.shx']

# %%
import geopandas as gpd
import zipfile, os

zip_path = "data/SCI_Rikstackande.zip"
extract_dir = "data/SCI_Rikstackande"

# Extract
with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_dir)

# Find shapefiles recursively
shp_files = []
for root, dirs, files in os.walk(extract_dir):
    for f in files:
        if f.endswith(".shp"):
            shp_files.append(os.path.join(root, f))

print("Shapefiles found:", shp_files)

# Load one shapefile
gdf = gpd.read_file(shp_files[0])
print("Loaded", len(gdf), "features from", shp_files[0])
print(gdf.head())
# Out:
# Shapefiles found: ['data/SCI_Rikstackande/SCI_ej_alvar_rikstackande/SCI_ej_alvar_rikstackande.shp', 'data/SCI_Rikstackande/SCI_alvar_BD_lan/SCI_alvar_BD_lan.shp', 'data/SCI_Rikstackande/SCI_alvar_AC_lan/SCI_alvar_AC_lan.shp']
# Loaded 4016 features from data/SCI_Rikstackande/SCI_ej_alvar_rikstackande/SCI_ej_alvar_rikstackande.shp
#                NAMN                                            BEVPLAN  \
# 0        Abborravan  https://geodata.naturvardsverket.se/handlingar...
# 1  Abborrtjärnsberg  https://geodata.naturvardsverket.se/handlingar...
# 2       Abborrträsk  https://geodata.naturvardsverket.se/handlingar...
# 3          Abborrås  https://geodata.naturvardsverket.se/handlingar...
# 4            Abisko  https://geodata.naturvardsverket.se/handlingar...
#
#    SITE_CODE OMRADESTYP                            UPPLAMNARE     KOMMUN  \
# 0  SE0810361        SCI     Länsstyrelsen i Västerbottens län   Lycksele
# 1  SE0610084        SCI         Länsstyrelsen i Värmlands län     Torsby
# 2  SE0820455        SCI       Länsstyrelsen i Norrbottens län  Gällivare
# 3  SE0530205        SCI  Länsstyrelsen i Västra Götalands län      Borås
# 4  SE0820261        SCI       Länsstyrelsen i Norrbottens län     Kiruna
#
#                     LAN SCI_FORSL SCI_DATUM SAC_DATUM SPA_DATUM  AREA_HA  \
# 0     Västerbottens län    199801    200501    201103      None     12.9
# 1         Värmlands län    199701    200501    201103      None     14.9
# 2       Norrbottens län    200106    200501    201103      None      4.7
# 3  Västra Götalands län    200404    200501    201103      None      4.0
# 4       Norrbottens län    199512    200312    200912      None   7720.5
#
#                                             KVALITET  \
# 0  The site is a river lagoon with rich vegetatio...
# 1  Site has very high quality as one of eight rel...
# 2  The site represents a species-rich grassland w...
# 3  Ett vähävdat område med rödlistade arter som ä...
# 4  Abisko comprises a pronounced zonation of nord...
#
#                                             KARAKTAR  \
# 0  Historically Abboravan is a rest from an old r...
# 1  Abborrtjärnsberg is a very isolated Finnish se...
# 2  Parts of the site are grazed by sheep. Other p...
# 3  En mycket vacker och välhävdad björkhage. Mark...
# 4  The National park of Abisko, consisting a U-sh...
#
#                                                ARTER  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  Dvärgpärlemorfjäril, Fjällsilversmygare  , Hög...
#
#                                           NATURTYPER  OBJECTID  SHAPE_AREA  \
# 0                                         3130, 6450    762631         NaN
# 1                                         6520, 7140    764153         NaN
# 2                                         6410, 6520    761982         NaN
# 3                                               4030    763201         NaN
# 4  3140, 3220, 4060, 4080, 6150, 6170, 6430, 7140...    764634         NaN
#
#    SHAPE_LEN                                           geometry
# 0        NaN  POLYGON Z ((683562.092 7193543.706 0, 683586.1...
# 1        NaN  POLYGON Z ((369410.769 6703301.724 0, 369347.5...
# 2        NaN  POLYGON Z ((732125.277 7451002.02 0, 732155.53...
# 3        NaN  POLYGON Z ((373072.349 6381283.123 0, 373070.9...
# 4        NaN  POLYGON Z ((653700.169 7579791.52 0, 653704.10...

# %% [markdown]
# ### 🔧 Python Code to Download + Load Stockholm län Naturreservat

# %%
import requests, zipfile, os, geopandas as gpd

# --- Download ---
url = "https://geodata.naturvardsverket.se/nedladdning/naturvardsregistret/NR.zip"
zip_path = "NR.zip"
extract_dir = "data/NR"

if not os.path.exists(zip_path):
    print("Downloading Naturreservat dataset...")
    r = requests.get(url)
    with open(zip_path, "wb") as f:
        f.write(r.content)

# --- Unzip ---
with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_dir)

# --- Find .shp ---
shp_files = []
for root, dirs, files in os.walk(extract_dir):
    for f in files:
        if f.endswith(".shp"):
            shp_files.append(os.path.join(root, f))

print("Shapefiles found:", shp_files)

# --- Load into GeoPandas ---
gdf = gpd.read_file(shp_files[0])

print(gdf.columns)         # See available fields
print(gdf["LAN"].unique()) # Inspect unique values for county
print(gdf.head())

print("Total Naturreservat in Stockholm län:", len(gdf_stockholm))
print(gdf_stockholm[["NVRID", "NAMN", "KOMMUN"]].head())
# Out:
# Shapefiles found: ['data/NR/NR/NR_polygon.shp']
# Index(['NVRID', 'NAMN', 'SKYDDSTYP', 'BESLSTATUS', 'URSBESLDAT', 'IKRAFTDATF',
#        'URSGALLDAT', 'SENGALLDAT', 'TILLSYNSMH', 'PROVNMHDIS', 'PROVNMHTIL',
#        'LAN', 'KOMMUN', 'IUCNKAT', 'FORVALTARE', 'AREA_HA', 'LAND_HA',
#        'VATTEN_HA', 'SKOG_HA', 'GEOSTATUS', 'DIARIENR', 'LAGRUM', 'BESLMYND',
#        'geometry'],
#       dtype='object')
# ['Östergötlands Län' 'Värmlands Län' 'Blekinge Län' 'Västerbottens Län'
#  'Gotlands Län' 'Uppsala Län' 'Norrbottens Län' 'Dalarnas Län'
#  'Stockholms Län' 'Jämtlands Län' 'Västra Götalands Län'
#  'Västernorrlands Län' 'Jönköpings Län' 'Gävleborgs Län' 'Skåne Län'
#  'Västmanlands Län' 'Hallands Län' 'Kronobergs Län' 'Örebro Län'
#  'Kalmar Län' 'Södermanlands Län']
#      NVRID            NAMN      SKYDDSTYP BESLSTATUS URSBESLDAT IKRAFTDATF  \
# 0  2032070  Styra kalkkärr  Naturreservat   Gällande 2012-12-06        NaT
# 1  2002137  Högbergsfältet  Naturreservat   Gällande 1979-11-19        NaT
# 2  2001440    Bärsjöskogen  Naturreservat   Gällande 1994-04-21        NaT
# 3  2000061       Stilleryd  Naturreservat   Gällande 1967-08-01        NaT
# 4  2001581  Degerforsheden  Naturreservat   Gällande 1997-01-27        NaT
#
#   URSGALLDAT SENGALLDAT TILLSYNSMH PROVNMHDIS  ...  \
# 0 2013-01-05 2013-01-05       None       None  ...
# 1 1979-11-19 2009-03-09       None       None  ...
# 2 1994-06-15 2009-02-28       None       None  ...
# 3 1967-08-01 2012-09-14       None       None  ...
# 4 1997-03-10 1997-03-10       None       None  ...
#
#                           FORVALTARE AREA_HA LAND_HA VATTEN_HA SKOG_HA  \
# 0  Länsstyrelsen i Östergötlands län    3.94    3.89      0.00    0.46
# 1      Länsstyrelsen i Värmlands län   63.84   51.13     12.79   37.95
# 2                 Norrköpings kommun   44.11   31.73     12.29   27.62
# 3       Länsstyrelsen i Blekinge län   82.95   25.15     57.81    7.06
# 4  Länsstyrelsen i Västerbottens län  136.41  132.76      3.63  109.06
#
#                       GEOSTATUS       DIARIENR           LAGRUM      BESLMYND  \
# 0                 Ospecificerad    511-3884-12      Miljöbalken  Länsstyrelse
# 1                 Ospecificerad   511-13715-05      Miljöbalken  Länsstyrelse
# 2  Justerad mot fastighetskarta           None             None        Kommun
# 3                 Ospecificerad  511-2307-2010      Miljöbalken  Länsstyrelse
# 4  Justerad mot fastighetskarta   231-10447/96  Naturvårdslagen  Länsstyrelse
#
#                                             geometry
# 0  POLYGON ((505215.423 6478848.401, 505269.55 64...
# 1  POLYGON ((460204.76 6623826.766, 460236.166 66...
# 2  POLYGON ((571503.915 6507576.002, 571646.562 6...
# 3  POLYGON ((487108.296 6223569.74, 487009.463 62...
# 4  POLYGON ((797207.783 7236063.491, 797212.731 7...
#
# [5 rows x 24 columns]
# Total Naturreservat in Stockholm län: 0
# Empty DataFrame
# Columns: [NVRID, NAMN, KOMMUN]
# Index: []

# %%
gdf_stockholm = gdf[gdf["LAN"].str.lower().str.contains("stockholm")]

print("Naturreservat in Stockholm län:", len(gdf_stockholm))
print(gdf_stockholm[["NVRID", "NAMN", "KOMMUN"]].head())
# Out:
# Naturreservat in Stockholm län: 376
#       NVRID                 NAMN      KOMMUN
# 11  2000008           Yttereneby  Södertälje
# 29  2061101       Telegrafberget      Tyresö
# 33  2001109             Vindalsö      Värmdö
# 38  2005573  Flemingsbergsskogen    Huddinge
# 55  2005594             Mornäsan   Norrtälje

# %% [markdown]
# ### Merge code

# %% [markdown]
# Step 1. Setup helpers

# %%
import pandas as pd
import geopandas as gpd
from SPARQLWrapper import SPARQLWrapper, JSON
import requests
import unicodedata
from rapidfuzz import process, fuzz

# Helper: normalize names for fuzzy matching
def normalize_name(name):
    if not isinstance(name, str):
        return ""
    name = unicodedata.normalize("NFKD", name).encode("ascii", "ignore").decode("utf-8")
    name = name.lower()
    name = name.replace("naturreservat", "").replace("nr", "").strip()
    return name

# %% [markdown]
# 🔧 Step 2. Load NVR (Naturvårdsverket)

# %%
gdf_nvr = gpd.read_file("data/NR/NR/NR_polygon.shp")

# Filter Stockholm län
gdf_nvr = gdf_nvr[gdf_nvr["LAN"] == "Stockholms Län"]

# Keep relevant columns
df_nvr = gdf_nvr[["NVRID", "NAMN", "KOMMUN"]].copy()
df_nvr["name_norm"] = df_nvr["NAMN"].apply(normalize_name)

print("NVR reserves in Stockholm:", len(df_nvr))
# Out:
# NVR reserves in Stockholm: 376

# %% [markdown]
# 🔧 Step 3. Load OSM (Overpass API)

# %%
import requests

overpass_url = "https://overpass-api.de/api/interpreter"
query = """
[out:json][timeout:90];
relation(54391)->.area;  // Stockholm län
(
  node(area.area)["leisure"="nature_reserve"];
  way(area.area)["leisure"="nature_reserve"];
  relation(area.area)["leisure"="nature_reserve"];
);
out tags center;
"""

resp = requests.get(overpass_url, params={"data": query})

# Debug response
print("HTTP status:", resp.status_code)
print("First 200 chars:\n", resp.text[:200])

if resp.status_code == 200 and resp.headers.get("Content-Type", "").startswith("application/json"):
    data = resp.json()
    elements = data["elements"]
    print("Got elements:", len(elements))
else:
    raise RuntimeError("Overpass returned non-JSON response, try again or use another endpoint.")
# Out:
# HTTP status: 200
# First 200 chars:
#  {
#   "version": 0.6,
#   "generator": "Overpass API 0.7.62.8 e802775f",
#   "osm3s": {
#     "timestamp_osm_base": "2025-09-29T14:04:15Z",
#     "timestamp_areas_base": "2025-09-29T10:04:35Z",
#     "copyright":
# Got elements: 0

# %% [markdown]
# 🔧 Step 4. Load Wikidata (SPARQL)

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)
sparql.setQuery("""
SELECT ?item ?itemLabel ?NVRID ?website ?osmRel ?osmWay WHERE {
  # ?item wdt:P31 wd:Q179049;
        wdt:P131* wd:Q104231;
        wdt:P1281 ?NVRID.
  OPTIONAL { ?item wdt:P856 ?website. }
  OPTIONAL { ?item wdt:P402 ?osmRel. }
  OPTIONAL { ?item wdt:P10689 ?osmWay. }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
""")

results = sparql.query().convert()

records = []
for r in results["results"]["bindings"]:
    rec = {
        "qid": r["item"]["value"].split("/")[-1],
        "label": r.get("itemLabel", {}).get("value"),
        "NVRID": r["NVRID"]["value"],
        "website": r.get("website", {}).get("value"),
        "osmRel": r.get("osmRel", {}).get("value"),
        "osmWay": r.get("osmWay", {}).get("value"),
    }
    rec["name_norm"] = normalize_name(rec["label"])
    records.append(rec)

df_wd = pd.DataFrame(records)
print("Wikidata reserves:", len(df_wd))
# Out:
# Wikidata reserves: 0

# %% [markdown]
# 🔧 Step 6. Export TODO table

# %%
def make_osm_link(osm_id):
    if pd.isna(osm_id): return "*(missing)*"
    t, i = osm_id.split("/")
    return f"[OSM {t} {i}](https://www.openstreetmap.org/{t}/{i})"

def make_wd_link(qid):
    if pd.isna(qid): return "*(missing)*"
    return f"[{qid}](https://www.wikidata.org/wiki/{qid})"

rows = []
for _, row in df_master.iterrows():
    issues = []
    if row["flag_osm"]: issues.append("Missing in OSM")
    if row["flag_wd"]: issues.append("Missing in Wikidata")
    if row["flag_site_mismatch"]: issues.append("Website mismatch")

    rows.append({
        "Name": row["NAMN"],
        "NVRID": row["NVRID"],
        "OSM": make_osm_link(row.get("osm_id")),
        "Wikidata": make_wd_link(row.get("qid")),
        "Issues": ", ".join(issues) if issues else "✅"
    })

df_todo = pd.DataFrame(rows)
print(df_todo.head())

# Save to Markdown
with open("TODO_reserves.md", "w") as f:
    f.write(df_todo.to_markdown(index=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 11
#       8     return f"[{qid}](https://www.wikidata.org/wiki/{qid})"
#      10 rows = []
# ---> 11 for _, row in df_master.iterrows():
#      12     issues = []
#      13     if row["flag_osm"]: issues.append("Missing in OSM")
#
# NameError: name 'df_master' is not defined

# %% [markdown]
# 🔧 Step 7. Add fuzzy matching for OSM ↔ NVR

# %%
from rapidfuzz import process, fuzz

# Only OSM reserves without NVRID
df_osm_nomatch = df_osm[df_osm["ref_NVRID"].isna()].copy()

matches = []
for idx, row in df_osm_nomatch.iterrows():
    if not row["name_norm"]:
        continue
    match = process.extractOne(
        row["name_norm"], 
        df_nvr["name_norm"], 
        scorer=fuzz.ratio
    )
    if match and match[1] >= 85:  # threshold
        # get NVR record
        nvr_row = df_nvr[df_nvr["name_norm"] == match[0]].iloc[0]
        matches.append({
            "osm_id": row["osm_id"],
            "osm_name": row["name"],
            "NVRID": nvr_row["NVRID"],
            "nvr_name": nvr_row["NAMN"],
            "score": match[1]
        })

df_osm_fuzzy = pd.DataFrame(matches)
print("Fuzzy matches found:", len(df_osm_fuzzy))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ref_NVRID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 4
#       1 from rapidfuzz import process, fuzz
#       3 # Only OSM reserves without NVRID
# ----> 4 df_osm_nomatch = df_osm[df_osm["ref_NVRID"].isna()].copy()
#       6 matches = []
#       7 for idx, row in df_osm_nomatch.iterrows():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'ref_NVRID'

# %% [markdown]
# ## New try

# %%
# export_OSM_leisure_nature_reserve.geojson

# %%
import os

cwd = os.getcwd()
print("Current working directory:", cwd)
# Out:
# Current working directory: /Users/salgo/Documents/GitHub/Stockholm_Archipelago_Trail/notebook

# %%
import geopandas as gpd

gdf_osm = gpd.read_file("export_OSM_leisure_nature_reserve.geojson")

# Extract tags we care about
records = []
for _, row in gdf_osm.iterrows():
    tags = row.get("tags", {})
    rec = {
        "osm_id": f"{row['osm_type']}/{row['osm_id']}" if "osm_id" in row else None,
        "name": tags.get("name"),
        "ref_NVRID": tags.get("ref:NVRID"),
        "wikidata": tags.get("wikidata"),
        "website": tags.get("website"),
    }
    records.append(rec)

import pandas as pd
df_osm = pd.DataFrame(records)

print("Loaded OSM reserves:", len(df_osm))
print(df_osm.head())
# Out:
# Loaded OSM reserves: 558
#   osm_id  name ref_NVRID wikidata website
# 0   None  None      None     None    None
# 1   None  None      None     None    None
# 2   None  None      None     None    None
# 3   None  None      None     None    None
# 4   None  None      None     None    None

# %%
import geopandas as gpd

gdf_osm = gpd.read_file("export_OSM_leisure_nature_reserve.geojson")
print(gdf_osm.columns)
print(gdf_osm.head(2))
# Out:
# Index(['id', '@id', 'LAN', 'NVRID', 'access', 'addr:city', 'addr:postcode',
#        'alt_name', 'boundary', 'comment', 'communication:amateur_radio:pota',
#        'description', 'description:en', 'dog', 'fixme', 'governance_type',
#        'historic', 'image', 'image:license', 'ist:area_ha', 'ist:land_ha',
#        'ist:tillkomst', 'ist:vatten_ha', 'landuse', 'leaf_cycle', 'leaf_type',
#        'leisure', 'lst:anmärkning', 'lst:area_ha', 'lst:metodbeskrivning',
#        'lst:ref', 'lst:reviderad', 'lst:tillkomst', 'lst:url', 'lst_area_h',
#        'lst_ref', 'name', 'name:en', 'natural', 'note', 'official_name',
#        'old_name', 'old_ref:DIARIENR', 'old_ref:NVRID', 'old_ref:lst',
#        'openfire', 'opening_hours', 'operator', 'operator:type',
#        'operator:wikidata', 'place', 'protect_class', 'protection_title',
#        'ref:DIARIENR', 'ref:NVRID', 'ref:OBJECTID', 'ref:lst', 'related_law',
#        'short_name', 'site_status', 'source', 'start_date', 'type', 'url',
#        'website', 'wikidata', 'wikimedia_commons', 'wikipedia', '@geometry',
#        'geometry'],
#       dtype='object')
#                  id               @id   LAN NVRID access addr:city  \
# 0  relation/1381602  relation/1381602  None  None   None      None
# 1  relation/1460258  relation/1460258  None  None   None      None
#
#   addr:postcode alt_name        boundary comment  ...            source  \
# 0          None     None  protected_area    None  ...  Naturvårdsverket
# 1          None     None  protected_area    None  ...  Naturvårdsverket
#
#    start_date      type   url  \
# 0  2007-03-08  boundary  None
# 1  1971-12-01  boundary  None
#
#                                              website   wikidata  \
# 0  https://www.nacka.se/boende-miljo/natur-och-pa...  Q10397880
# 1                  https://nynasslott.se/reservatet/  Q10604865
#
#   wikimedia_commons wikipedia @geometry                   geometry
# 0              None      None    center  POINT (18.28852 59.33091)
# 1              None      None    center  POINT (17.38532 58.82348)
#
# [2 rows x 70 columns]

# %%
records = []
for _, row in gdf_osm.iterrows():
    rec = {
        "osm_id": row.get("id"),
        "name": row.get("name"),
        "ref_NVRID": row.get("ref:NVRID"),
        "wikidata": row.get("wikidata"),
        "website": row.get("website"),
    }
    records.append(rec)

df_osm = pd.DataFrame(records)
print("Loaded OSM reserves:", len(df_osm))
print(df_osm.head())
# Out:
# Loaded OSM reserves: 558
#              osm_id                        name ref_NVRID   wikidata  \
# 0  relation/1381602  Abborrträsks naturreservat   2013015  Q10397880
# 1  relation/1460258         Nynäs naturreservat   2001921  Q10604865
# 2  relation/1460259                       Persö      None  Q30165688
# 3  relation/1460260                      Ringsö      None  Q30171026
# 4  relation/1460261                  Marvikarna      None   Q3361676
#
#                                              website
# 0  https://www.nacka.se/boende-miljo/natur-och-pa...
# 1                  https://nynasslott.se/reservatet/
# 2                                               None
# 3                                               None
# 4                                               None
