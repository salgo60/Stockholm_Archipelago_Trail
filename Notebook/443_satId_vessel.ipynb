# %% [markdown]
# ### satId på fartyg
# * [#443](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/443)
# * denna Notebook [443_satId_vessel.ipynb](https://github.com/salgo60/Stockholm_Archipelago_Trail/tree/main/Notebook/443_satId_vessel.ipynb)

# %%
import time

from datetime import datetime

now = datetime.now()
timestampStart = datetime.now()

print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-07-10 22:51:09

# %%
import requests

# URL till JSON-filen
url = "https://map.stockholmarchipelagotrail.com/data/vessels-identity.json"

# Ersätt med rätt property när den finns
PROPERTY = "P14545"

# Hämta JSON
response = requests.get(url)
response.raise_for_status()
data = response.json()

# Skapa QuickStatements
lines = []

for obj in data.values():
    wikidata = obj.get("wikidata")
    satid = obj.get("satId")

    if wikidata and satid:
        lines.append(f'{wikidata}\t{PROPERTY}\t"{satid}"')

# Spara fil
output_file = "vessels_quickstatements.txt"

with open(output_file, "w", encoding="utf-8") as f:
    f.write("\n".join(lines))

print(f"Skrev {len(lines)} QuickStatements till {output_file}")

# Visa 100 första raderna
for line in lines:
    print(line)
# Out:
# Skrev 18 QuickStatements till vessels_quickstatements.txt
# Q10573162	P14545	"sat:vessel:3kjzv"
# Q10573052	P14545	"sat:vessel:4agqh"
# Q10684595	P14545	"sat:vessel:4x39x"
# Q134550614	P14545	"sat:vessel:5dh3f"
# Q10573151	P14545	"sat:vessel:5xrhm"
# Q10573203	P14545	"sat:vessel:7awvt"
# Q10659318	P14545	"sat:vessel:7bj23"
# Q64548778	P14545	"sat:vessel:aws8m"
# Q63384746	P14545	"sat:vessel:e99jw"
# Q10667918	P14545	"sat:vessel:gg8gw"
# Q20205108	P14545	"sat:vessel:jgnhb"
# Q31895770	P14545	"sat:vessel:rgcmv"
# Q10573200	P14545	"sat:vessel:sgwt5"
# Q10659340	P14545	"sat:vessel:tsvh9"
# Q10573127	P14545	"sat:vessel:vn92p"
# Q10573144	P14545	"sat:vessel:wmf8m"
# Q31885478	P14545	"sat:vessel:x4hte"
# Q64362244	P14545	"sat:vessel:zzm4n"

# %%
nowend = datetime.now()
timestamp = nowend.timestamp()


print("Start:", timestampStart.strftime("%Y-%m-%d %H:%M:%S")) 
print("End:", nowend.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-07-10 22:51:09
# End: 2026-07-10 22:51:12
