# %% [markdown]
# ## Export natureserves to geojson
#
# * testing [umap](https://umap.openstreetmap.fr/en/map/boende-vindskydd-nordsydlinjen-och-stockholm-archi_1257552?share#9/59.3052/18.5161)
#
# see if we can add Naturereserves

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?item ?itemLabel ?_image ?coord ?www ?article ?OSMr ?OSMw ?OSM WHERE {
  # ?item wdt:P6104 wd:Q134294510; wdt:P625 ?coord.
  # ?item wdt:P31 wd:Q179049.  
  # ?item wdt:P856 ?www.
  OPTIONAL { ?item wdt:P402 ?OSMr. }
  OPTIONAL { ?item wdt:P11693 ?OSMw. }
  
  BIND( URI(CONCAT("https://www.openstreetmap.org/way/",?OSMw)) AS ?OSM)
  BIND( URI(CONCAT("https://www.openstreetmap.org/relation/",?OSMr)) AS ?OSM)

  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "sv, en" . 
  }
    OPTIONAL { 
   # ?article schema:about ?item ;
             schema:inLanguage "sv" ;
             schema:name ?name ;
             schema:isPartOf [ wikibase:wikiGroup "wikipedia" ] .
  }
OPTIONAL { ?item wdt:P18 ?_image. }
} order by ?objectLabel
"""


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


results = get_results(endpoint_url, query)

for result in results["results"]["bindings"]:
    print(result)
# Out:
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1422492'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/Fj%C3%A4rdl%C3%A5ngs_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/fjardlang.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.573401117 59.018765892)'}, 'OSMr': {'type': 'literal', 'value': '1463788'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463788'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/Fjardlang%20P9230090%20%2852103910%29.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Fjärdlångs naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2301512'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/Ut%C3%B6_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/uto.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.312222222 58.986944444)'}, 'OSMr': {'type': 'literal', 'value': '1463748'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463748'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/Ut%C3%B6%20gruvor%20Nyk%C3%B6pingsgruvan%20September%202012%2002.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Utö naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10605047'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/N%C3%A4md%C3%B6_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/namdo.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.642675439 59.177536289)'}, 'OSMr': {'type': 'literal', 'value': '1463777'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463777'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/SAT%20N%C3%A4md%C3%B6%20b3.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Nämdö naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30158128'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/Lid%C3%B6_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/lido.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(19.080419 59.784268)'}, 'OSMr': {'type': 'literal', 'value': '1463761'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463761'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/Lid%C3%B6.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Lidö naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30161368'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/Finnhamns_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/finnhamn.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.84400489 59.474933564)'}, 'OSMr': {'type': 'literal', 'value': '1463800'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463800'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/Finnhamn%20July%202015.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Finnhamns naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30162906'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/K%C3%A5lg%C3%A5rds%C3%B6ns_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/kalgardson.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.798240011 59.474223038)'}, 'OSMr': {'type': 'literal', 'value': '10626459'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/10626459'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/SAT%20Ingmars%C3%B6%20B%C3%A5tluffarleden%20%286%29.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Kålgårdsöns naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30164971'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/%C3%85l%C3%B6-R%C3%A5n%C3%B6_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/alo-rano.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.1886 58.92966)'}, 'OSMr': {'type': 'literal', 'value': '1463767'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463767'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/%C3%85l%C3%B6.JPG'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Ålö-Rånö naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30165452'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/Arholma-Id%C3%B6_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/arholma-ido.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(19.135512106 59.818524173)'}, 'OSMr': {'type': 'literal', 'value': '1463750'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463750'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/100703%20Farmors%20hus%20p%C3%A5%20Id%C3%B6.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Arholma-Idö naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q30167695'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/Grinda_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/grinda.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.554258 59.411864)'}, 'OSMr': {'type': 'literal', 'value': '1463789'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463789'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/Grinda%20-%20April%202018.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Grinda naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q108159298'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/%C3%96ja-Landsorts_naturv%C3%A5rdsomr%C3%A5de'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/oja-landsort.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(17.86325 58.757611111)'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/SAT%20Landsort%2016.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Öja-Landsort Naturvårdsområde'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q133794691'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/Norra_skogens_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/om-oss/om-lansstyrelsen-stockholm/lanets-forfattningssamling/forfattningar-2024/forfattningssamling-2024/2024-11-27-01fs-202441.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.45602 59.08943)'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/SAT%20Orn%C3%B6%202025%20maj%20%2810%29.jpg'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Norra skogens naturreservat'}}
# {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q134587569'}, 'article': {'type': 'uri', 'value': 'https://sv.wikipedia.org/wiki/N%C3%A5ttar%C3%B6_naturreservat'}, 'www': {'type': 'uri', 'value': 'https://www.lansstyrelsen.se/stockholm/besoksmal/naturreservat/nattaro.html'}, 'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(18.118719831 58.873033344)'}, 'OSMr': {'type': 'literal', 'value': '1463792'}, 'OSM': {'type': 'uri', 'value': 'https://www.openstreetmap.org/relation/1463792'}, '_image': {'type': 'uri', 'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/%C3%96stra%20N%C3%A5ttar%C3%B6%20juli%202009.png'}, 'itemLabel': {'xml:lang': 'sv', 'type': 'literal', 'value': 'Nåttarö naturreservat'}}

# %%
import sys
import requests
import json
from SPARQLWrapper import SPARQLWrapper, JSON

# --- Step 1: SPARQL Query ---

endpoint_url = "https://query.wikidata.org/sparql"
query = """
SELECT ?item ?itemLabel ?OSMr ?OSMw WHERE {
  # ?item wdt:P6104 wd:Q134294510;  # Stockholm Archipelago Trail
        wdt:P625 ?coord;
        wdt:P31 wd:Q179049.       # nature reserve
  OPTIONAL { ?item wdt:P402 ?OSMr. }    # OSM relation
  OPTIONAL { ?item wdt:P11693 ?OSMw. }  # OSM way
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
"""

def get_results(endpoint_url, query):
    user_agent = "YourCustomAppName/1.0 (contact@example.com)"
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

results = get_results(endpoint_url, query)

# --- Step 2: Extract OSM IDs ---
osm_ids = []
labels = {}

for r in results["results"]["bindings"]:
    label = r.get("itemLabel", {}).get("value")
    if "OSMr" in r:
        rel_id = r["OSMr"]["value"]
        osm_ids.append(f"relation({rel_id})")
        labels[f"relation/{rel_id}"] = label
    elif "OSMw" in r:
        way_id = r["OSMw"]["value"]
        osm_ids.append(f"way({way_id})")
        labels[f"way/{way_id}"] = label

if not osm_ids:
    print("No OSM IDs found.")
    sys.exit(1)

# --- Step 3: Query Overpass API ---
overpass_query = f"""
[out:json][timeout:25];
(
  {';'.join(osm_ids)};
);
out body;
>;
out skel qt;
"""

response = requests.get("https://overpass-api.de/api/interpreter", params={'data': overpass_query})
overpass_data = response.json()

# --- Step 4: Convert OSM JSON → GeoJSON ---

# Option A: use osmtogeojson (requires Node.js)
# Option B: manual conversion (simplified below)

# Here, we just dump the Overpass output — you can use https://tyrasd.github.io/osmtogeojson/ to convert it
with open("raw_overpass_output.json", "w", encoding="utf-8") as f:
    json.dump(overpass_data, f, indent=2)

print("✅ Overpass JSON saved. You can now convert to GeoJSON using osmtogeojson.")

# Optional: use https://overpass-turbo.eu/ → paste query → Export GeoJSON
# Out:
# ✅ Overpass JSON saved. You can now convert to GeoJSON using osmtogeojson.

# %%
result

# %%
import sys
import requests
import json
from collections import defaultdict
from SPARQLWrapper import SPARQLWrapper, JSON
from geojson import Feature, FeatureCollection, Point, Polygon, LineString

# --- Step 1: Fetch Wikidata items with OSM relation/way IDs ---

def get_results(endpoint_url, query):
    user_agent = "GeoJSONGenerator/1.0 (your@email.com)"
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

endpoint_url = "https://query.wikidata.org/sparql"
query = """
SELECT ?item ?itemLabel ?OSMr ?OSMw ?wwwN WHERE {
  # ?item wdt:P6104 wd:Q134294510;
        wdt:P625 ?coord;
        wdt:P31 wd:Q179049.
  OPTIONAL { ?item wdt:P856 ?wwwN . }
  OPTIONAL { ?item wdt:P402 ?OSMr. }
  OPTIONAL { ?item wdt:P11693 ?OSMw. }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
"""

results = get_results(endpoint_url, query)

osm_ids = []
labels = {}
wd_qids = {}

for r in results["results"]["bindings"]:
    label = r.get("itemLabel", {}).get("value", "Unnamed")
    qid = r["item"]["value"].split("/")[-1]

    if "OSMr" in r:
        rel_id = r["OSMr"]["value"]
        osm_ids.append(f"relation({rel_id})")
        labels[f"relation/{rel_id}"] = label
        wd_qids[f"relation/{rel_id}"] = qid
    elif "OSMw" in r:
        way_id = r["OSMw"]["value"]
        osm_ids.append(f"way({way_id})")
        labels[f"way/{way_id}"] = label
        wd_qids[f"way/{way_id}"] = qid

if not osm_ids:
    print("No OSM IDs found.")
    sys.exit(1)

# --- Step 2: Query Overpass API ---

overpass_query = f"""
[out:json][timeout:25];
(
  {';'.join(osm_ids)};
);
out body;
>;
out skel qt;
"""

response = requests.get("https://overpass-api.de/api/interpreter", params={'data': overpass_query})
osm_data = response.json()

# --- Step 3: Convert to GeoJSON ---

# Build node dictionary
nodes = {}
for el in osm_data['elements']:
    if el['type'] == 'node':
        nodes[el['id']] = [el['lon'], el['lat']]

features = []

# Build features from ways and relations
for el in osm_data['elements']:
    if el['type'] == 'way':
        coords = []
        for node_id in el['nodes']:
            if node_id in nodes:
                coords.append(nodes[node_id])
        geometry = None
        if coords and coords[0] == coords[-1]:  # closed ring
            geometry = Polygon([coords])
        else:
            geometry = LineString(coords)
        ref = f"way/{el['id']}"
        features.append(Feature(
            geometry=geometry,
            properties={
                "name": labels.get(ref, "Unnamed"),
                "wikidata": wd_qids.get(ref, None),
                "osm_id": ref
            }
        ))

    elif el['type'] == 'relation' and 'members' in el:
        # Simplified support for multipolygon relations
        outer_rings = []
        for member in el['members']:
            if member['type'] == 'way' and member['role'] == 'outer':
                way = next((w for w in osm_data['elements'] if w['type'] == 'way' and w['id'] == member['ref']), None)
                if way:
                    coords = [nodes[nid] for nid in way['nodes'] if nid in nodes]
                    if coords[0] == coords[-1]:  # closed
                        outer_rings.append(coords)
        if outer_rings:
            ref = f"relation/{el['id']}"
            features.append(Feature(
                geometry=Polygon(outer_rings),
                properties={
                    "name": labels.get(ref, "Unnamed"),
                    "wikidata": wd_qids.get(ref, None),
                    "osm_id": ref
                }
            ))

# --- Step 4: Write GeoJSON file ---

geojson_data = FeatureCollection(features)

with open("nature_reserves.geojson", "w", encoding="utf-8") as f:
    json.dump(geojson_data, f, indent=2, ensure_ascii=False)

print(f"✅ Saved 3 GeoJSON with {len(features)} features to 'nature_reserves.geojson'")
# Out:
# ✅ Saved 3 GeoJSON with 85 features to 'nature_reserves.geojson'

# %%
Also
