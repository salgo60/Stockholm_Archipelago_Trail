# %% [markdown]
# ### 221_event_openinghours
#
# * [Issue 221](https://github.com/salgo60/Stockholm_Archipelago_Trail/issues/221)

# %%
import time
import datetime  
start_time = time.time()
start_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
print(f"Started: {start_str}")
# Out:
# Started: 2025-10-04 14:55

# %%
import requests
import json
import time
import feedparser

WD_SPARQL_ENDPOINT = "https://query.wikidata.org/sparql"

def fetch_sat_objects():
    query = """
    SELECT ?item ?itemLabel ?website ?commonscat ?svwiki
    WHERE {
      # ?item wdt:P6104 wd:Q134294510 .
      OPTIONAL { ?item wdt:P856 ?website }
      OPTIONAL { ?item wdt:P373 ?commonscat }
      OPTIONAL {
        # ?svwiki schema:about ?item ;
                schema:isPartOf <https://sv.wikipedia.org/> .
      }
      SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
    }
    """
    r = requests.get(WD_SPARQL_ENDPOINT, params={"query": query, "format": "json"}, headers={"User-Agent":"SAT-Watcher/1.0"})
    r.raise_for_status()
    data = r.json()
    items = []
    for b in data["results"]["bindings"]:
        items.append({
            "qid": b["item"]["value"].split("/")[-1],
            "label": b.get("itemLabel", {}).get("value"),
            "website": b.get("website", {}).get("value"),
            "commonscat": b.get("commonscat", {}).get("value"),
            "svwiki": b.get("svwiki", {}).get("value")
        })
    return items


def check_website(website_url):
    """Try to detect if a website has RSS or last-modified"""
    try:
        r = requests.get(website_url, timeout=10, headers={"User-Agent":"SAT-Watcher/1.0"})
        lastmod = r.headers.get("Last-Modified")

        # crude RSS check
        if "xml" in r.headers.get("Content-Type",""):
            return {"status": "rss-feed", "lastmod": lastmod}
        if "<rss" in r.text.lower():
            return {"status": "rss-feed-embedded", "lastmod": lastmod}
        if lastmod:
            return {"status": "ok", "lastmod": lastmod}
        return {"status": "ok"}
    except Exception as e:
        return {"status": "error", "error": str(e)}


def build_activity_feed():
    sat_items = fetch_sat_objects()
    feed = []

    for it in sat_items:
        entry = {"qid": it["qid"], "label": it["label"]}
        if it.get("website"):
            entry["website_check"] = check_website(it["website"])
        if it.get("commonscat"):
            entry["commons_url"] = f"https://commons.wikimedia.org/wiki/Category:{it['commonscat']}"
        if it.get("svwiki"):
            entry["svwiki"] = it["svwiki"]
        feed.append(entry)

    # save snapshot
    with open("sat_activity_feed.json", "w", encoding="utf-8") as f:
        json.dump(feed, f, ensure_ascii=False, indent=2)

    return feed


if __name__ == "__main__":
    print("Building activity feed…")
    data = build_activity_feed()
    print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# Building activity feed…
# [
#   {
#     "qid": "Q294787",
#     "label": "Öja",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Öja (Stockholm archipelago)"
#   },
#   {
#     "qid": "Q28375391",
#     "label": "Yxlans fyr",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Yxlan, lighthouse"
#   },
#   {
#     "qid": "Q28934440",
#     "label": "Björkö-Arholma sjömannaförening",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Fri, 26 Sep 2025 11:16:06 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Björkö-Arholma Sjömannaförening"
#   },
#   {
#     "qid": "Q28934474",
#     "label": "Sandhamns museum",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamns museum"
#   },
#   {
#     "qid": "Q29528279",
#     "label": "Pestkyrkogård, Öja-Landsort",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Öja- Landsort Pestkyrkogård"
#   },
#   {
#     "qid": "Q30315439",
#     "label": "Sandhamns tullhus",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamn customs house"
#   },
#   {
#     "qid": "Q32247988",
#     "label": "Halsudden",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Halsudden"
#   },
#   {
#     "qid": "Q32278807",
#     "label": "Lilla Jolpan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lilla Jolpan"
#   },
#   {
#     "qid": "Q32301589",
#     "label": "Nåttaröhals"
#   },
#   {
#     "qid": "Q33180827",
#     "label": "Sandhamns lotsstation",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamn customs house"
#   },
#   {
#     "qid": "Q46946584",
#     "label": "Sandön"
#   },
#   {
#     "qid": "Q63345339",
#     "label": "Drottninggrottan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Drottninggrottan"
#   },
#   {
#     "qid": "Q63432491",
#     "label": "Konstnären Axel Sjöberg 1866–1950",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Axel Sjöberg av Carl Eldh"
#   },
#   {
#     "qid": "Q63615597",
#     "label": "Strindbergsgården",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Strindbergsgården"
#   },
#   {
#     "qid": "Q81263800",
#     "label": "Batteri Sandö-Oxudde",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Batteri Sandö-Oxudde"
#   },
#   {
#     "qid": "Q89197643",
#     "label": "Ornö skola",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ornö skola"
#   },
#   {
#     "qid": "Q89197643",
#     "label": "Ornö skola",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ornö skola"
#   },
#   {
#     "qid": "Q106575390",
#     "label": "Möja Bio",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möja Bio"
#   },
#   {
#     "qid": "Q106653497",
#     "label": "Sandhamn, Fläskberget",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Klippbad Sandhamn, Fläskberget"
#   },
#   {
#     "qid": "Q106653509",
#     "label": "Stora Trouvillestranden",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Stora Trouvillestranden"
#   },
#   {
#     "qid": "Q106653538",
#     "label": "Östervikens badplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östervikens badplats"
#   },
#   {
#     "qid": "Q106678630",
#     "label": "Jerkers uddes badplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Jerkers uddes badplats"
#   },
#   {
#     "qid": "Q106680381",
#     "label": "Ålö Storsand",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ålö storsand"
#   },
#   {
#     "qid": "Q107290890",
#     "label": "Ornöboda badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ornöboda badplats"
#   },
#   {
#     "qid": "Q108067637",
#     "label": "Gruvbyns utegym",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö, utegym"
#   },
#   {
#     "qid": "Q111335301",
#     "label": "Runmarö skola",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Mon, 04 Apr 2022 08:47:04 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Runmarö school"
#   },
#   {
#     "qid": "Q111335438",
#     "label": "Svartsö skola",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Svartsö skola"
#   },
#   {
#     "qid": "Q111335439",
#     "label": "Möja skola",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möja skola"
#   },
#   {
#     "qid": "Q113481847",
#     "label": "Finnhamn, utegym",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamn, outdoorgym"
#   },
#   {
#     "qid": "Q114039794",
#     "label": "Storsand, Nåttarö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Storsand, Nåttarö"
#   },
#   {
#     "qid": "Q114574693",
#     "label": "Vandringsled Ålö runt",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ålö runt"
#   },
#   {
#     "qid": "Q115094918",
#     "label": "Långvik yttre badplats"
#   },
#   {
#     "qid": "Q115303226",
#     "label": "Nämndö kyrkogård",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 12:56:01 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nämdö cemetery"
#   },
#   {
#     "qid": "Q115303225",
#     "label": "Möja kyrkogård",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möja kyrkogård"
#   },
#   {
#     "qid": "Q115303256",
#     "label": "Ornö kyrkogård",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 12:56:03 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ornö kyrkogård"
#   },
#   {
#     "qid": "Q115303257",
#     "label": "Utö kyrkogård",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö kyrkogård"
#   },
#   {
#     "qid": "Q115305305",
#     "label": "Sandhamns kyrkogård",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Familjegrav Sundén Cullberg Sandhamn"
#   },
#   {
#     "qid": "Q116730327",
#     "label": "Båtluffarleden",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Båtluffarleden"
#   },
#   {
#     "qid": "Q121352030",
#     "label": "Grillplats, Storsand Ålö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Storsand Ålö bbq"
#   },
#   {
#     "qid": "Q121361352",
#     "label": "Grillplats Grinda södra bryggan",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats Grinda södra bryggan"
#   },
#   {
#     "qid": "Q121361588",
#     "label": "Källvikens badstrand",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Badstranden på Grinda"
#   },
#   {
#     "qid": "Q121409629",
#     "label": "Grillplats Ålö Storsand 2"
#   },
#   {
#     "qid": "Q121409637",
#     "label": "Grillplats Ålö storsand 3"
#   },
#   {
#     "qid": "Q121409712",
#     "label": "SAT grill Storsand",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT grill Storsand"
#   },
#   {
#     "qid": "Q121412621",
#     "label": "Grillplats Storsand",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats Nåttarö storsand 2"
#   },
#   {
#     "qid": "Q121433209",
#     "label": "Grillplats vid badstrand, Grinda",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats vid badstrand, Grinda"
#   },
#   {
#     "qid": "Q121433242",
#     "label": "Grillplats Grinda tältplats syd västra 2",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats Grinda tältplats västra 2"
#   },
#   {
#     "qid": "Q121433258",
#     "label": "Östra grillplatsen vid tältplatsen 2",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östra grillplatsen vid tältplatsen 2"
#   },
#   {
#     "qid": "Q121433272",
#     "label": "Östra grillplatsen vid tältplatsen 1",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östra grillplatsen vid tältplatsen 1"
#   },
#   {
#     "qid": "Q121714588",
#     "label": "Grinda Klubbudden grillplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grinda Klubbudden, grillplats"
#   },
#   {
#     "qid": "Q121715058",
#     "label": "Rast- och grillplats Öja-Landsort",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rast- och grillplats Öja-Landsort"
#   },
#   {
#     "qid": "Q121754355",
#     "label": "Kålgårdsöns naturreservat, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Kålgårdsöns naturreservat, grillplats"
#   },
#   {
#     "qid": "Q121887829",
#     "label": "Finnhamn badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamn badplats"
#   },
#   {
#     "qid": "Q122018561",
#     "label": "Sandtagets utegym Sandhamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandtagets utegym Sandhamn"
#   },
#   {
#     "qid": "Q130338597",
#     "label": "Norra sand, Utö, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Norra sand, Utö, grillplats"
#   },
#   {
#     "qid": "Q130338761",
#     "label": "Norra sand, Utö, grillplats 2",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Norra sand, Utö, grillplats 2"
#   },
#   {
#     "qid": "Q130338821",
#     "label": "Barnens bad",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Norra sands badplats, Utö"
#   },
#   {
#     "qid": "Q133374147",
#     "label": "SAT Arholma",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Arholma"
#   },
#   {
#     "qid": "Q133374147",
#     "label": "SAT Arholma",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Arholma"
#   },
#   {
#     "qid": "Q133374185",
#     "label": "SAT Lidö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Lidö"
#   },
#   {
#     "qid": "Q133374185",
#     "label": "SAT Lidö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Lidö"
#   },
#   {
#     "qid": "Q133449160",
#     "label": "SAT Landsort",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Landsort"
#   },
#   {
#     "qid": "Q133449160",
#     "label": "SAT Landsort",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Landsort"
#   },
#   {
#     "qid": "Q133453469",
#     "label": "Grillplats Arholma Nord",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats Arholma Nord"
#   },
#   {
#     "qid": "Q133459438",
#     "label": "Labyrint, Öja-Landsort",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Labyrint, Öja-Landsort"
#   },
#   {
#     "qid": "Q133459454",
#     "label": "Albert Holms minnessten",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Albert Holms minnessten"
#   },
#   {
#     "qid": "Q133459632",
#     "label": "Helveteskällan, Landsort",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Helveteskällan, Landsort"
#   },
#   {
#     "qid": "Q133502246",
#     "label": "SAT Grinda",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Grinda"
#   },
#   {
#     "qid": "Q133502246",
#     "label": "SAT Grinda",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Grinda"
#   },
#   {
#     "qid": "Q133502889",
#     "label": "Grinda Wärdshus",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 10:06:03 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grinda Wärdshus"
#   },
#   {
#     "qid": "Q133554956",
#     "label": "SAT Nämdö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Nämdö"
#   },
#   {
#     "qid": "Q133554956",
#     "label": "SAT Nämdö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Nämdö"
#   },
#   {
#     "qid": "Q133567320",
#     "label": "Vita stigen, Nämdö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Vita stigen, Nämdö"
#   },
#   {
#     "qid": "Q133724230",
#     "label": "SAT Nåttarö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Nåttarö"
#   },
#   {
#     "qid": "Q133724230",
#     "label": "SAT Nåttarö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Nåttarö"
#   },
#   {
#     "qid": "Q133724231",
#     "label": "SAT Rånö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Rånö"
#   },
#   {
#     "qid": "Q133724231",
#     "label": "SAT Rånö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Rånö"
#   },
#   {
#     "qid": "Q133724234",
#     "label": "SAT Utö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Utö"
#   },
#   {
#     "qid": "Q133724234",
#     "label": "SAT Utö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Utö"
#   },
#   {
#     "qid": "Q133724232",
#     "label": "SAT Ålö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Ålö"
#   },
#   {
#     "qid": "Q133724232",
#     "label": "SAT Ålö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Ålö"
#   },
#   {
#     "qid": "Q133724239",
#     "label": "SAT Svartsö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Svartsö"
#   },
#   {
#     "qid": "Q133724239",
#     "label": "SAT Svartsö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Svartsö"
#   },
#   {
#     "qid": "Q133724236",
#     "label": "SAT Ornö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Ornö"
#   },
#   {
#     "qid": "Q133724236",
#     "label": "SAT Ornö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Ornö"
#   },
#   {
#     "qid": "Q133724237",
#     "label": "SAT Fjärdlång",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Fjärdlång"
#   },
#   {
#     "qid": "Q133724237",
#     "label": "SAT Fjärdlång",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Fjärdlång"
#   },
#   {
#     "qid": "Q133724240",
#     "label": "SAT Brottö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Brottö"
#   },
#   {
#     "qid": "Q133724240",
#     "label": "SAT Brottö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Brottö"
#   },
#   {
#     "qid": "Q133724246",
#     "label": "SAT Runmarö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Runmarö"
#   },
#   {
#     "qid": "Q133724246",
#     "label": "SAT Runmarö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Runmarö"
#   },
#   {
#     "qid": "Q133724247",
#     "label": "SAT Ingmarsö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Ingmarsö"
#   },
#   {
#     "qid": "Q133724247",
#     "label": "SAT Ingmarsö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Ingmarsö"
#   },
#   {
#     "qid": "Q133724250",
#     "label": "SAT Yxlan",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Yxlan"
#   },
#   {
#     "qid": "Q133724250",
#     "label": "SAT Yxlan",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Yxlan"
#   },
#   {
#     "qid": "Q133724249",
#     "label": "SAT Finnhamn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Finnhamn"
#   },
#   {
#     "qid": "Q133724249",
#     "label": "SAT Finnhamn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Finnhamn"
#   },
#   {
#     "qid": "Q133724254",
#     "label": "SAT Furusund",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Furusund"
#   },
#   {
#     "qid": "Q133724254",
#     "label": "SAT Furusund",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Furusund"
#   },
#   {
#     "qid": "Q133724255",
#     "label": "SAT Sandhamn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Sandhamn"
#   },
#   {
#     "qid": "Q133724255",
#     "label": "SAT Sandhamn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Sandhamn"
#   },
#   {
#     "qid": "Q133724252",
#     "label": "SAT Möja",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Möja"
#   },
#   {
#     "qid": "Q133724252",
#     "label": "SAT Möja",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Möja"
#   },
#   {
#     "qid": "Q133800514",
#     "label": "Runmarö kyrkogård",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Runmarö kyrkogård"
#   },
#   {
#     "qid": "Q133802175",
#     "label": "Runmarö Hembygdsgård",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Mon, 04 Apr 2022 08:47:04 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Runmarö Hembygdsgård"
#   },
#   {
#     "qid": "Q133812457",
#     "label": "Roland Svensson Museet",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Roland Svensson Museet"
#   },
#   {
#     "qid": "Q133812552",
#     "label": "STF Möja vandrarhem",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:STF Möja vandrarhem"
#   },
#   {
#     "qid": "Q133812569",
#     "label": "Möja Värdshus",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möja värdshus"
#   },
#   {
#     "qid": "Q133812682",
#     "label": "Jeppes Gästgiveri",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Jeppes Gästgiveri"
#   },
#   {
#     "qid": "Q133825090",
#     "label": "Utö Värdshus vandrarhem",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö Värdshus vandrarhem"
#   },
#   {
#     "qid": "Q133825195",
#     "label": "Rävstavik badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rävstavik badplats"
#   },
#   {
#     "qid": "Q133827327",
#     "label": "Nämdö bageri",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nämdö bageri"
#   },
#   {
#     "qid": "Q133829368",
#     "label": "Bistro Sågen",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Bistro Sågen"
#   },
#   {
#     "qid": "Q133829728",
#     "label": "grillplats Sydfladen",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats Finnhamn Sydfladen"
#   },
#   {
#     "qid": "Q133829736",
#     "label": "STF Finnhamn vandrarhem",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:STF Finnhamn hostel"
#   },
#   {
#     "qid": "Q133829773",
#     "label": "Finnhamn Lammuddens vindskydd",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lammuddens vindskydd"
#   },
#   {
#     "qid": "Q133830137",
#     "label": "Lammuddens grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lammuddens Grillplats"
#   },
#   {
#     "qid": "Q133830267",
#     "label": "Vindskydd Talludden",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Talluddens vindskydd"
#   },
#   {
#     "qid": "Q133830659",
#     "label": "Grillplats Talludden",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Talluddens grillplats"
#   },
#   {
#     "qid": "Q133830825",
#     "label": "Ragnars kiosk, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ragnars kiosk grillplats"
#   },
#   {
#     "qid": "Q133830844",
#     "label": "Vandrarhemmet, grillplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:STF Finnhamn hostel, firepit"
#   },
#   {
#     "qid": "Q133834915",
#     "label": "Grillplats, Storsand Ålö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats, Storsand Ålö"
#   },
#   {
#     "qid": "Q133838591",
#     "label": "Utö gästhamn, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö gästhamn, grillplats"
#   },
#   {
#     "qid": "Q133839813",
#     "label": "Södra fladen Utö, grillplats"
#   },
#   {
#     "qid": "Q133839829",
#     "label": "Södra fladen Utö, vindskydd",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Södra fladens vindskydd"
#   },
#   {
#     "qid": "Q133840505",
#     "label": "Utö Värdshus",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö Värdshus"
#   },
#   {
#     "qid": "Q133840685",
#     "label": "Utö camping grillplats 2",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö camping grillplats 2"
#   },
#   {
#     "qid": "Q133840790",
#     "label": "Utö camping grillplats 1",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö camping grillplats 1"
#   },
#   {
#     "qid": "Q133841438",
#     "label": "Utö camping grillplats 3",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö camping grillplats 3"
#   },
#   {
#     "qid": "Q133841778",
#     "label": "Utö camping grillplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö camping grillplats"
#   },
#   {
#     "qid": "Q133847886",
#     "label": "Telegrafbergets torn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Telegrafbergets torn"
#   },
#   {
#     "qid": "Q133848057",
#     "label": "Telegrafberget",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Telegrafberget Ornö"
#   },
#   {
#     "qid": "Q133848174",
#     "label": "Vindskydd Ornö museum",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Talluddens vindskydd"
#   },
#   {
#     "qid": "Q133848185",
#     "label": "grillplats, Ornö museum",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Kyrkviken Ornö bbq"
#   },
#   {
#     "qid": "Q133848344",
#     "label": "Rosirska gravkoret",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rosirska gravkoret"
#   },
#   {
#     "qid": "Q133848857",
#     "label": "Västanviks grillplats, Ornö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Västanviks grillplats"
#   },
#   {
#     "qid": "Q133849105",
#     "label": "Lervassastigen",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lervassastigen"
#   },
#   {
#     "qid": "Q133849105",
#     "label": "Lervassastigen",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lervassastigen"
#   },
#   {
#     "qid": "Q133850783",
#     "label": "Skärgårdsmuseet Nämdö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skärgådsmuseet Nämdö"
#   },
#   {
#     "qid": "Q133863310",
#     "label": "Astrid Lindgrens sommarhus Stenhällan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Astrid Lindgrens sommarhus Stenhällan"
#   },
#   {
#     "qid": "Q133863316",
#     "label": "Furusund grillplats Fotbollsplan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Furusund grillplats Fotbollsplan"
#   },
#   {
#     "qid": "Q133863462",
#     "label": "Villa Romanov",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Villa Romanov"
#   },
#   {
#     "qid": "Q133863715",
#     "label": "Skärlkarlshamn strand",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skärlkarlshamn badplats"
#   },
#   {
#     "qid": "Q133864055",
#     "label": "Förängsbadet",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Förängsbadet"
#   },
#   {
#     "qid": "Q133864087",
#     "label": "Långviks badplats",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Tue, 16 Sep 2025 12:34:22 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Långvik, badplats"
#   },
#   {
#     "qid": "Q133864132",
#     "label": "Saltviks badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Saltviks badplats"
#   },
#   {
#     "qid": "Q133864303",
#     "label": "Hästholmsvikens badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Hästholmsvikens badplats"
#   },
#   {
#     "qid": "Q133864464",
#     "label": "Svartsö Hembygdsgård",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Svartsö Hembygdsgård"
#   },
#   {
#     "qid": "Q133864497",
#     "label": "södra stranden, Sandhamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Södra Sandhamn, badplats"
#   },
#   {
#     "qid": "Q133864540",
#     "label": "Harviken, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Harviken, grillplats"
#   },
#   {
#     "qid": "Q133864593",
#     "label": "Harvikens badstrand",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Harvikens badstrand"
#   },
#   {
#     "qid": "Q133864622",
#     "label": "Knicksand enkel grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Knicksand enkel grillplats"
#   },
#   {
#     "qid": "Q133864761",
#     "label": "Knicksand grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Knicksand grillplats"
#   },
#   {
#     "qid": "Q133864801",
#     "label": "Knicksand grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Knicksand grillplats 2"
#   },
#   {
#     "qid": "Q133864847",
#     "label": "Sandön, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandön, grillplats"
#   },
#   {
#     "qid": "Q133864944",
#     "label": "Myrudden, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Furusund grillplats Myrudden"
#   },
#   {
#     "qid": "Q133867299",
#     "label": "Lidö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lidö ferry stop"
#   },
#   {
#     "qid": "Q133872120",
#     "label": "Lidö Österhamn grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Österhamn, grillplats"
#   },
#   {
#     "qid": "Q133880548",
#     "label": "Femsundvikens badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ingmarsö Femsundvikens badplats"
#   },
#   {
#     "qid": "Q133883699",
#     "label": "Ingmarsö Brottö Hembygdsmuseum",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ingmarsö Brottö Hembygdsmuseum"
#   },
#   {
#     "qid": "Q133884437",
#     "label": "Isola Bella",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Wed, 08 May 2024 13:36:47 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Isola Bella, Furusund"
#   },
#   {
#     "qid": "Q133884655",
#     "label": "Roddbåtar att korsa mellan Ingmarsö till Finnhamn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rowboats for crossing Ingmarsö Finnhamn"
#   },
#   {
#     "qid": "Q133884690",
#     "label": "Norra Ingmarsö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Norra Ingmarsö Ferry stop"
#   },
#   {
#     "qid": "Q133884712",
#     "label": "Åsättra brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Åsättra brygga ferry stop"
#   },
#   {
#     "qid": "Q133884785",
#     "label": "Spränga brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Spränga ferry stop"
#   },
#   {
#     "qid": "Q133884836",
#     "label": "Gruvbryggan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Gruvbryggan ferry stop"
#   },
#   {
#     "qid": "Q133884947",
#     "label": "Brottö kulturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Brottö kulturreservat"
#   },
#   {
#     "qid": "Q133885585",
#     "label": "Arholma brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Arholma ferry stop"
#   },
#   {
#     "qid": "Q133885677",
#     "label": "Simpnäs brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Simpnäs ferry stop"
#   },
#   {
#     "qid": "Q133885997",
#     "label": "badplats på norra Grinda",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Badplatsen på norra Grinda"
#   },
#   {
#     "qid": "Q133886133",
#     "label": "Nåttarö badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö badplats"
#   },
#   {
#     "qid": "Q133886292",
#     "label": "Nåttarö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö brygga"
#   },
#   {
#     "qid": "Q133886565",
#     "label": "Själudden, tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Tältplats Själudden, Nämdö"
#   },
#   {
#     "qid": "Q133895106",
#     "label": "Vindskydd lilla Jolpan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lilla Jolpan vindskydd"
#   },
#   {
#     "qid": "Q133980758",
#     "label": "Thielska villan, Fjärdlång",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Thielska villan, Fjärdlång"
#   },
#   {
#     "qid": "Q133993440",
#     "label": "Fjärdlång bryggan, grillplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Fjärdlång bryggan, grillplats"
#   },
#   {
#     "qid": "Q133993942",
#     "label": "Fjärdlång tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Fjärdlång camp site"
#   },
#   {
#     "qid": "Q133993978",
#     "label": "Fjärdlång brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Fjärdlång ferry stop"
#   },
#   {
#     "qid": "Q133994022",
#     "label": "Ragnars kiosk badplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ragnars kiosk badplats"
#   },
#   {
#     "qid": "Q133994161",
#     "label": "Styrsvik brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Styrsvik ferry stop"
#   },
#   {
#     "qid": "Q133994206",
#     "label": "Skälviks brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skälvik ferry stop"
#   },
#   {
#     "qid": "Q134000657",
#     "label": "Söderboudd brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Söderboudd ferry stop"
#   },
#   {
#     "qid": "Q134005778",
#     "label": "Thielska villan, grillplats, Fjärdlång",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Thielska villan, grillplats, Fjärdlång"
#   },
#   {
#     "qid": "Q134005834",
#     "label": "Tysta Klint",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Tysta Klint, Fjärdlång"
#   },
#   {
#     "qid": "Q134006267",
#     "label": "Fjärdlång tältplats, grillplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Fjärdlång tältplatsen, grillplats"
#   },
#   {
#     "qid": "Q134006727",
#     "label": "Pojkarnas udde grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:SAT Finnhamn Pojkarnas udde grillplats"
#   },
#   {
#     "qid": "Q134006996",
#     "label": "Lanthandel på Finnhamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lanthandel på Finnhamn"
#   },
#   {
#     "qid": "Q134007206",
#     "label": "Södra Ingmarsö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Södra Ingmarsö Ferry stop"
#   },
#   {
#     "qid": "Q134007303",
#     "label": "Landsort västra hamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Landsort western harbor"
#   },
#   {
#     "qid": "Q134007357",
#     "label": "Landsort östra hamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Landsort eastern harbor"
#   },
#   {
#     "qid": "Q134007558",
#     "label": "Sand brygga, Nämdö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sand ferry stop, Nämdö"
#   },
#   {
#     "qid": "Q134007589",
#     "label": "Nämdöböte brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nämdöböte ferry stop"
#   },
#   {
#     "qid": "Q134007653",
#     "label": "Solvik brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Solvik ferry stop"
#   },
#   {
#     "qid": "Q134007692",
#     "label": "Östanvik brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östanvik ferry stop"
#   },
#   {
#     "qid": "Q134007891",
#     "label": "Arholma handel",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Arholma handel"
#   },
#   {
#     "qid": "Q134008052",
#     "label": "Brottö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Brottö Ferry stop"
#   },
#   {
#     "qid": "Q134008562",
#     "label": "Rånö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rånö ferry stop"
#   },
#   {
#     "qid": "Q134078770",
#     "label": "Nåttarö snorklingsled",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö snorklingsled"
#   },
#   {
#     "qid": "Q134082069",
#     "label": "Vänsviken, Nåttarö BBQ",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Vänsviken, Nåttarö BBQ"
#   },
#   {
#     "qid": "Q134082140",
#     "label": "Östemar grillplats gamla",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östemar grillplats gamla"
#   },
#   {
#     "qid": "Q134082502",
#     "label": "Grillplats vid Ångbatsbryggan, Nåttarö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grillplats vid Angbatsbryggan, Nåttarö"
#   },
#   {
#     "qid": "Q134082735",
#     "label": "Östemar grillplats nya",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östemar grillplats nya"
#   },
#   {
#     "qid": "Q134083897",
#     "label": "Nåttarö tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö Camping"
#   },
#   {
#     "qid": "Q134176668",
#     "label": "Kvarnvikens badstrand",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Kvarnviken, Nåttarö"
#   },
#   {
#     "qid": "Q134176709",
#     "label": "Skarsand, Nåttarö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skarsand, Nåttarö"
#   },
#   {
#     "qid": "Q134290283",
#     "label": "Furusundsbadplats, grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Furusundsbadplats, grillplats"
#   },
#   {
#     "qid": "Q134290334",
#     "label": "Furusundsbadplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Furusundsbadplats"
#   },
#   {
#     "qid": "Q134297092",
#     "label": "Gatan, brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Gatan, Runmarö ferry stops"
#   },
#   {
#     "qid": "Q134306927",
#     "label": "Saltboden, Landsort",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Tue, 26 Aug 2025 12:24:22 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Saltboden, Landsort"
#   },
#   {
#     "qid": "Q134306989",
#     "label": "Vandra i Stockholms skärgård",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 12:57:12 GMT"
#     }
#   },
#   {
#     "qid": "Q134307047",
#     "label": "Landsort norra hamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Landsort northern harbor"
#   },
#   {
#     "qid": "Q134310117",
#     "label": "Grinda Lanthandel och Cafe",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 07:38:07 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grinda Lanthandel"
#   },
#   {
#     "qid": "Q134310449",
#     "label": "Södra Grinda brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Södra Grinda ferry stop"
#   },
#   {
#     "qid": "Q134311495",
#     "label": "Nåttarö handelsbod",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö handelsbod"
#   },
#   {
#     "qid": "Q134311548",
#     "label": "Livsmedelbutiken på Nämdö Solvik",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Handlaren, Nämdö"
#   },
#   {
#     "qid": "Q134311974",
#     "label": "Runmarö lanthandel",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Runmarö lanthandel"
#   },
#   {
#     "qid": "Q134312278",
#     "label": "Utö livs",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö livs"
#   },
#   {
#     "qid": "Q134366690",
#     "label": "Lidö tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lidö camp site"
#   },
#   {
#     "qid": "Q134366761",
#     "label": "Arholma tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Arholma camp site"
#   },
#   {
#     "qid": "Q134366886",
#     "label": "Utö tältplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö camp site"
#   },
#   {
#     "qid": "Q134367350",
#     "label": "Norra Svartsö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Norra Svartsö ferry stop"
#   },
#   {
#     "qid": "Q134369418",
#     "label": "Grinda tältplats",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 11:55:51 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grinda camp site"
#   },
#   {
#     "qid": "Q134369594",
#     "label": "Långviks brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Långvik, Runmarö ferry stop"
#   },
#   {
#     "qid": "Q134369828",
#     "label": "Nämdö tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nämdö camp site"
#   },
#   {
#     "qid": "Q134369914",
#     "label": "Köpmanholm brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Köpmanholm ferry stop"
#   },
#   {
#     "qid": "Q134370050",
#     "label": "Sandhamn brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamn ferry stop"
#   },
#   {
#     "qid": "Q134373707",
#     "label": "Yxlö brygga grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Yxlö brygga grillplats"
#   },
#   {
#     "qid": "Q134380404",
#     "label": "Hamnvikens badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Hamnvikens badplats, Yxlan"
#   },
#   {
#     "qid": "Q134442339",
#     "label": "Utö gula villan",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö gula villan"
#   },
#   {
#     "qid": "Q134442663",
#     "label": "Norrö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Norrö ferry stop"
#   },
#   {
#     "qid": "Q134442879",
#     "label": "Norra Grinda brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Norra Grinda ferry stop"
#   },
#   {
#     "qid": "Q134443436",
#     "label": "Utö bykrog",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö bykrog"
#   },
#   {
#     "qid": "Q134443760",
#     "label": "Källarstugan, Arholma",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Källarstugan, Arholma"
#   },
#   {
#     "qid": "Q134444030",
#     "label": "Österhamns pensionat",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Österhamns pensionat, Arholma"
#   },
#   {
#     "qid": "Q134444768",
#     "label": "Finnhamn brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamn ferry stop"
#   },
#   {
#     "qid": "Q134444827",
#     "label": "Nya Dannekrogen",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö Dannekrogen"
#   },
#   {
#     "qid": "Q134445091",
#     "label": "Aktiv Skärgård Utö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Aktiv Skärgård Utö"
#   },
#   {
#     "qid": "Q134451025",
#     "label": "Möja Coop",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Mon, 15 Sep 2025 07:32:18 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möja Coop"
#   },
#   {
#     "qid": "Q134452061",
#     "label": "Rånö tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rånö camp site"
#   },
#   {
#     "qid": "Q134452244",
#     "label": "Idholmens gårdsbutik",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Idholmens Gårdsbutik"
#   },
#   {
#     "qid": "Q134452251",
#     "label": "Idholmens badplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Idholmens badplats"
#   },
#   {
#     "qid": "Q134461524",
#     "label": "Idholmens grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamn Idholmen grillplats"
#   },
#   {
#     "qid": "Q134461930",
#     "label": "Finnhamns Krog",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamns Krog"
#   },
#   {
#     "qid": "Q134462751",
#     "label": "Finnhamns norra tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamn camp site"
#   },
#   {
#     "qid": "Q134463083",
#     "label": "Finnhamn södra tältplats",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamn camp site south"
#   },
#   {
#     "qid": "Q134465290",
#     "label": "Tempo, Sandhamn",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Mon, 15 Sep 2025 08:14:34 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Tempo, Sandhamn"
#   },
#   {
#     "qid": "Q134473761",
#     "label": "Sandhamns värdshus",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Wed, 01 Oct 2025 07:53:57 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamns värdshus"
#   },
#   {
#     "qid": "Q134510130",
#     "label": "Landsort vandrarhemmet",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Landsort vandrarhemmet"
#   },
#   {
#     "qid": "Q134513852",
#     "label": "Landsorts lotsutkik",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Landsorts lotsutkik"
#   },
#   {
#     "qid": "Q134513890",
#     "label": "Sandhamn gamla skola",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamn old school"
#   },
#   {
#     "qid": "Q134519154",
#     "label": "Östemar badstrand",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östemar, Nåttarö"
#   },
#   {
#     "qid": "Q134519179",
#     "label": "Nåttarö vandrarhem",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö hostel"
#   },
#   {
#     "qid": "Q134519257",
#     "label": "Nåttarö vandrarhem grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö hostel bbq"
#   },
#   {
#     "qid": "Q134521444",
#     "label": "Möjaström brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möjaström ferry stop"
#   },
#   {
#     "qid": "Q134522797",
#     "label": "Bergs brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Berg ferry stop"
#   },
#   {
#     "qid": "Q134522835",
#     "label": "Ramsmora brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ramsmora ferry stop"
#   },
#   {
#     "qid": "Q134523091",
#     "label": "Långviks brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Långvik ferry stop"
#   },
#   {
#     "qid": "Q134527130",
#     "label": "Furusunds brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Furusund ferry stop"
#   },
#   {
#     "qid": "Q134527143",
#     "label": "Yxlö brygga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Yxlö ferry stop"
#   },
#   {
#     "qid": "Q134527248",
#     "label": "Köpmanholms Lanthandel och Grill",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Köpmanholms lanthandel"
#   },
#   {
#     "qid": "Q134529043",
#     "label": "Ornö Brödbod Deli",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Brödboden Kyrkviken Ornö"
#   },
#   {
#     "qid": "Q134529162",
#     "label": "Ornö macken",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ornö macken"
#   },
#   {
#     "qid": "Q134529240",
#     "label": "Svartsö lanthandel",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Svartsö lanthandel"
#   },
#   {
#     "qid": "Q134529646",
#     "label": "Rånö livs",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rånö livs"
#   },
#   {
#     "qid": "Q134529993",
#     "label": "Coop Ingmarsö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Coop Ingmarsö"
#   },
#   {
#     "qid": "Q134531012",
#     "label": "Ingmarsö krog",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ingmarsö krog"
#   },
#   {
#     "qid": "Q134537879",
#     "label": "Vänsvik udd, Nåttarö grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Vänsvik udd, Nåttarö BBQ"
#   },
#   {
#     "qid": "Q134537980",
#     "label": "Vänsviken, Nåttarö",
#     "website_check": {
# ...
#   },
#   {
#     "qid": "Q10605049",
#     "label": "Nämdö kyrka",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nämdö kyrka",
#     "svwiki": "https://sv.wikipedia.org/wiki/N%C3%A4md%C3%B6_kyrka"
#   },
#   {
#     "qid": "Q10605513",
#     "label": "Nåttarö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö",
#     "svwiki": "https://sv.wikipedia.org/wiki/N%C3%A5ttar%C3%B6"
#   },
#   {
#     "qid": "Q10611874",
#     "label": "Ornö kyrka",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 12:58:49 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ornö kyrka",
#     "svwiki": "https://sv.wikipedia.org/wiki/Orn%C3%B6_kyrka"
#   },
#   {
#     "qid": "Q10657821",
#     "label": "Runmarö kapell",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Runmarö kapell",
#     "svwiki": "https://sv.wikipedia.org/wiki/Runmar%C3%B6_kapell"
#   },
#   {
#     "qid": "Q10658747",
#     "label": "Rånö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Rånö",
#     "svwiki": "https://sv.wikipedia.org/wiki/R%C3%A5n%C3%B6"
#   },
#   {
#     "qid": "Q10661170",
#     "label": "Sandhamns kapell",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamns kapell",
#     "svwiki": "https://sv.wikipedia.org/wiki/Sandhamns_kapell"
#   },
#   {
#     "qid": "Q10683742",
#     "label": "Sundby herrgård",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sundby herrgård",
#     "svwiki": "https://sv.wikipedia.org/wiki/Sundby,_Orn%C3%B6"
#   },
#   {
#     "qid": "Q10711619",
#     "label": "Utö gruvor",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö gruvor",
#     "svwiki": "https://sv.wikipedia.org/wiki/Ut%C3%B6_gruvor"
#   },
#   {
#     "qid": "Q10711622",
#     "label": "Utö skjutfält",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö skjutfält",
#     "svwiki": "https://sv.wikipedia.org/wiki/Ut%C3%B6_skjutf%C3%A4lt"
#   },
#   {
#     "qid": "Q10711621",
#     "label": "Utö kyrka",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö kyrka",
#     "svwiki": "https://sv.wikipedia.org/wiki/Ut%C3%B6_kyrka"
#   },
#   {
#     "qid": "Q10726505",
#     "label": "Ålö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ålö",
#     "svwiki": "https://sv.wikipedia.org/wiki/%C3%85l%C3%B6,_Haninge_kommun"
#   },
#   {
#     "qid": "Q10727792",
#     "label": "Östanviks gård",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Östanviks gård",
#     "svwiki": "https://sv.wikipedia.org/wiki/%C3%96stanviks_g%C3%A5rd"
#   },
#   {
#     "qid": "Q15695240",
#     "label": "Bygdemuseet Ornö sockenstuga",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Bygdemuseet Ornö sockenstuga",
#     "svwiki": "https://sv.wikipedia.org/wiki/Bygdemuseet_Orn%C3%B6_sockenstuga"
#   },
#   {
#     "qid": "Q17634097",
#     "label": "Silverträsket",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Silverträsket",
#     "svwiki": "https://sv.wikipedia.org/wiki/Silvertr%C3%A4sket,_Uppland"
#   },
#   {
#     "qid": "Q17634106",
#     "label": "Styrsvikträsket",
#     "svwiki": "https://sv.wikipedia.org/wiki/Styrsviktr%C3%A4sket"
#   },
#   {
#     "qid": "Q18290939",
#     "label": "Ingmarsö",
#     "svwiki": "https://sv.wikipedia.org/wiki/Ingmars%C3%B6_(ort)"
#   },
#   {
#     "qid": "Q18291743",
#     "label": "Lidö värdshus",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lidö herrgård",
#     "svwiki": "https://sv.wikipedia.org/wiki/Lid%C3%B6_herrg%C3%A5rd"
#   },
#   {
#     "qid": "Q18292099",
#     "label": "Långvik",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Långvik, Möja",
#     "svwiki": "https://sv.wikipedia.org/wiki/L%C3%A5ngvik,_M%C3%B6ja_socken"
#   },
#   {
#     "qid": "Q20205108",
#     "label": "M/S Sunnan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sunnan (ship, 1968)",
#     "svwiki": "https://sv.wikipedia.org/wiki/M/S_Sunnan"
#   },
#   {
#     "qid": "Q26253472",
#     "label": "Ramsmora",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ramsmora",
#     "svwiki": "https://sv.wikipedia.org/wiki/Ramsmora"
#   },
#   {
#     "qid": "Q30158128",
#     "label": "Lidö naturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Lidö naturreservat",
#     "svwiki": "https://sv.wikipedia.org/wiki/Lid%C3%B6_naturreservat"
#   },
#   {
#     "qid": "Q30161368",
#     "label": "Finnhamns naturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamns naturreservat",
#     "svwiki": "https://sv.wikipedia.org/wiki/Finnhamns_naturreservat"
#   },
#   {
#     "qid": "Q30162906",
#     "label": "Kålgårdsöns naturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Kålgårdsön nature reserve",
#     "svwiki": "https://sv.wikipedia.org/wiki/K%C3%A5lg%C3%A5rds%C3%B6ns_naturreservat"
#   },
#   {
#     "qid": "Q30164971",
#     "label": "Ålö-Rånö naturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ålö-Rånö nature reserv",
#     "svwiki": "https://sv.wikipedia.org/wiki/%C3%85l%C3%B6-R%C3%A5n%C3%B6_naturreservat"
#   },
#   {
#     "qid": "Q30165452",
#     "label": "Arholma-Idö naturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Arholma-Idö",
#     "svwiki": "https://sv.wikipedia.org/wiki/Arholma-Id%C3%B6_naturreservat"
#   },
#   {
#     "qid": "Q30167695",
#     "label": "Grinda naturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grinda naturreservat",
#     "svwiki": "https://sv.wikipedia.org/wiki/Grinda_naturreservat"
#   },
#   {
#     "qid": "Q30242782",
#     "label": "Berg",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Berg, Möja",
#     "svwiki": "https://sv.wikipedia.org/wiki/Berg,_M%C3%B6ja"
#   },
#   {
#     "qid": "Q31891076",
#     "label": "Österhamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Österhamn, Arholma",
#     "svwiki": "https://sv.wikipedia.org/wiki/%C3%96sterhamn,_Arholma"
#   },
#   {
#     "qid": "Q31892331",
#     "label": "Kolsvik",
#     "svwiki": "https://sv.wikipedia.org/wiki/Kolsvik"
#   },
#   {
#     "qid": "Q31895480",
#     "label": "Edesnäs",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Edesnäs",
#     "svwiki": "https://sv.wikipedia.org/wiki/Edesn%C3%A4s"
#   },
#   {
#     "qid": "Q32904803",
#     "label": "Batteri Arholma",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Batteri Arholma",
#     "svwiki": "https://sv.wikipedia.org/wiki/Batteri_Arholma"
#   },
#   {
#     "qid": "Q33108739",
#     "label": "Ornö",
#     "svwiki": "https://sv.wikipedia.org/wiki/Orn%C3%B6_(ort)"
#   },
#   {
#     "qid": "Q33108886",
#     "label": "Yxlö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Yxlö, Yxlan",
#     "svwiki": "https://sv.wikipedia.org/wiki/Yxl%C3%B6,_Norrt%C3%A4lje_kommun"
#   },
#   {
#     "qid": "Q48890062",
#     "label": "Nämdö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nämdö",
#     "svwiki": "https://sv.wikipedia.org/wiki/N%C3%A4md%C3%B6"
#   },
#   {
#     "qid": "Q2120552",
#     "label": "Möja",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möja",
#     "svwiki": "https://sv.wikipedia.org/wiki/M%C3%B6ja"
#   },
#   {
#     "qid": "Q2301512",
#     "label": "Utö naturreservat",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Utö naturreservat",
#     "svwiki": "https://sv.wikipedia.org/wiki/Ut%C3%B6_naturreservat"
#   },
#   {
#     "qid": "Q2530171",
#     "label": "Landsorts fågelstation",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Landsort Bird Observatory",
#     "svwiki": "https://sv.wikipedia.org/wiki/Landsorts_f%C3%A5gelstation"
#   },
#   {
#     "qid": "Q2837232",
#     "label": "Sandhamn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamn",
#     "svwiki": "https://sv.wikipedia.org/wiki/Sandhamn"
#   },
#   {
#     "qid": "Q3105747",
#     "label": "Runmarö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Runmarö",
#     "svwiki": "https://sv.wikipedia.org/wiki/Runmar%C3%B6"
#   },
#   {
#     "qid": "Q3355818",
#     "label": "Finnhamn",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Finnhamn",
#     "svwiki": "https://sv.wikipedia.org/wiki/Finnhamn"
#   },
#   {
#     "qid": "Q3772710",
#     "label": "Arholma",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Arholma",
#     "svwiki": "https://sv.wikipedia.org/wiki/Arholma"
#   },
#   {
#     "qid": "Q5245979",
#     "label": "Ingmarsö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Ingmarsö",
#     "svwiki": "https://sv.wikipedia.org/wiki/Ingmars%C3%B6"
#   },
#   {
#     "qid": "Q6976423",
#     "label": "Yxlan",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Yxlan",
#     "svwiki": "https://sv.wikipedia.org/wiki/Yxlan"
#   },
#   {
#     "qid": "Q6976731",
#     "label": "Svartsö",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Svartsö",
#     "svwiki": "https://sv.wikipedia.org/wiki/Svarts%C3%B6"
#   },
#   {
#     "qid": "Q10397095",
#     "label": "15,2 cm-batteriet på Landsort",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:15,2 cm batteriet, Landsort",
#     "svwiki": "https://sv.wikipedia.org/wiki/15,2_cm-batteriet_p%C3%A5_Landsort"
#   },
#   {
#     "qid": "Q10417838",
#     "label": "Arholma kyrka",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Arholma kyrka",
#     "svwiki": "https://sv.wikipedia.org/wiki/Arholma_kyrka"
#   },
#   {
#     "qid": "Q10417837",
#     "label": "Arholma båk",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Mon, 04 Jul 2022 10:03:07 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Arholma båk",
#     "svwiki": "https://sv.wikipedia.org/wiki/Arholma_b%C3%A5k"
#   },
#   {
#     "qid": "Q10436177",
#     "label": "Brottö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Brottö",
#     "svwiki": "https://sv.wikipedia.org/wiki/Brott%C3%B6"
#   },
#   {
#     "qid": "Q10478848",
#     "label": "ERSTA-batteriet på Landsort",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 11:57:40 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:ERSTA-batteriet Landsort",
#     "svwiki": "https://sv.wikipedia.org/wiki/ERSTA-batteriet_p%C3%A5_Landsort"
#   },
#   {
#     "qid": "Q10531797",
#     "label": "Hässelmara",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Hässelmara",
#     "svwiki": "https://sv.wikipedia.org/wiki/H%C3%A4sselmara"
#   },
#   {
#     "qid": "Q10552209",
#     "label": "Köpmanholm",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Köpmanholm",
#     "svwiki": "https://sv.wikipedia.org/wiki/K%C3%B6pmanholm"
#   },
#   {
#     "qid": "Q10553968",
#     "label": "Landsorts kapell",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Landsorts kapell",
#     "svwiki": "https://sv.wikipedia.org/wiki/Landsorts_kapell"
#   },
#   {
#     "qid": "Q133863446",
#     "label": "Skomakarens stuga",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skomakarens stuga",
#     "svwiki": "https://sv.wikipedia.org/wiki/Skomakarens_stuga"
#   },
#   {
#     "qid": "Q135091732",
#     "label": "Christiansborg",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Christiansborg, Furusund",
#     "svwiki": "https://sv.wikipedia.org/wiki/Christiansborg,_Furusund"
#   },
#   {
#     "qid": "Q135091854",
#     "label": "Bellevue",
#     "svwiki": "https://sv.wikipedia.org/wiki/Bellevue,_Furusund"
#   },
#   {
#     "qid": "Q135102475",
#     "label": "Hotell Dagmar",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Hotell Dagmar",
#     "svwiki": "https://sv.wikipedia.org/wiki/Hotell_Dagmar"
#   },
#   {
#     "qid": "Q136193620",
#     "label": "Finnhamns bastu",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sauna at Finnhamn"
#   },
#   {
#     "qid": "Q136196939",
#     "label": "Bastu servicehuset Nåttarö",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö bastu servicehuset"
#   },
#   {
#     "qid": "Q136198240",
#     "label": "Nåttarö bastu vid stugbyn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Nåttarö bastu vid stugbyn"
#   },
#   {
#     "qid": "Q136202829",
#     "label": "Svartsö skärgårdshotell och vandrarhem Hjärtstartare",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Svartsö skärgårdshotell och vandrarhem AED"
#   },
#   {
#     "qid": "Q136207068",
#     "label": "Bastuflotte Sandhamn",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Bastuflotte Sandhamn"
#   },
#   {
#     "qid": "Q136207103",
#     "label": "Sandhamns hotell, bastu",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Sandhamns hotell, bastu"
#   },
#   {
#     "qid": "Q136214806",
#     "label": "Vandringsskylt SAT Arholma"
#   },
#   {
#     "qid": "Q136214817",
#     "label": "Vandringsskylt SAT Arholma"
#   },
#   {
#     "qid": "Q136214840",
#     "label": "Vandringsskylt SAT Arholma"
#   },
#   {
#     "qid": "Q136298469",
#     "label": "Grinda grillplats Klubbudden 2",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grinda Klubbudden, grillplats 2"
#   },
#   {
#     "qid": "Q136337568",
#     "label": "Saltvik grillplats, Möja",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Saltvik grillplats, Möja"
#   },
#   {
#     "qid": "Q136337707",
#     "label": "Möja Turistförening",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Möja turistbod"
#   },
#   {
#     "qid": "Q136341620",
#     "label": "Vandringsskylt SAT Finnhamn"
#   },
#   {
#     "qid": "Q136342609",
#     "label": "Pentaboden",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Wed, 01 Oct 2025 07:52:19 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Pentaboden, Sandhamn"
#   },
#   {
#     "qid": "Q136342734",
#     "label": "Grinda Sea Lodge bastu",
#     "website_check": {
#       "status": "ok",
#       "lastmod": "Sat, 04 Oct 2025 07:18:46 GMT"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Grinda Sea Lodge sauna"
#   },
#   {
#     "qid": "Q136349659",
#     "label": "Vandringsskylt SAT Rånö"
#   },
#   {
#     "qid": "Q136356030",
#     "label": "Vandringsskylt SAT Möja"
#   },
#   {
#     "qid": "Q136363283",
#     "label": "Södra Storsand Ålö grillplats"
#   },
#   {
#     "qid": "Q136374336",
#     "label": "Skarsand norra grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skarsand norra grillplats"
#   },
#   {
#     "qid": "Q136374419",
#     "label": "Skarsand enkel grillplats",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skarsand enkel grillplats"
#   },
#   {
#     "qid": "Q136374558",
#     "label": "Skarsand norra 2",
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Skarsand norra 2"
#   },
#   {
#     "qid": "Q136390034",
#     "label": "Vandringsskylt SAT Rånö"
#   },
#   {
#     "qid": "Q136390863",
#     "label": "Vandringsskylt SAT Rånö"
#   },
#   {
#     "qid": "Q136391100",
#     "label": "Vandringsskylt SAT Ingmarsö"
#   },
#   {
#     "qid": "Q136433169",
#     "label": "Seglarbaren",
#     "website_check": {
#       "status": "ok"
#     },
#     "commons_url": "https://commons.wikimedia.org/wiki/Category:Seglarbaren,_Utö"
#   }
# ]

# %%
import os, html, requests, folium, datetime
from jinja2 import Template
from datetime import datetime as dt, timedelta
from datetime import datetime, timedelta, timezone

# ========================
# Config
# ========================
MAP_CENTER = [59.5, 18.8]
MAP_ZOOM   = 7
OUTPUT_PREFIX = "SAT_event_openinghours_tracker"

HEADERS = {
    "User-Agent": (
        "SAT_event_openinghours_tracker/1.0 "
        "(https://github.com/salgo60/Stockholm_Archipelago_Trail; salgo60@example.com)"
    )
}

# ========================
# Commons latest uploads
# ========================
def fetch_depicts(title):
    """Get depicts (P180) Wikidata IDs for a Commons file"""
    url = "https://commons.wikimedia.org/w/api.php"
    params = {
        "action": "wbgetentities",
        "sites": "commonswiki",
        "titles": title,
        "props": "claims",
        "format": "json"
    }
    r = requests.get(url, params=params, headers=HEADERS)
    r.raise_for_status()
    depicts_data = r.json()
    depicts = []
    for entity in depicts_data.get("entities", {}).values():
        for pid, claims in entity.get("claims", {}).items():
            if pid == "P180":
                for c in claims:
                    if "mainsnak" in c and "datavalue" in c["mainsnak"]:
                        depicts.append(c["mainsnak"]["datavalue"]["value"]["id"])
    return depicts

def get_coords_from_wikidata(qid):
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{qid}.json"
    r = requests.get(url, headers=HEADERS)
    if r.status_code != 200:
        return None
    entity = r.json()["entities"].get(qid, {})
    coords = entity.get("claims", {}).get("P625")
    if not coords:
        return None
    val = coords[0]["mainsnak"]["datavalue"]["value"]
    return val["latitude"], val["longitude"]

def fetch_commons_latest(category="Stockholm_Archipelago_Trail", limit=50):
    url = "https://commons.wikimedia.org/w/api.php"
    params = {
        "action": "query",
        "generator": "categorymembers",
        "gcmtitle": f"Category:{category}",
        "gcmnamespace": "6",
        "gcmlimit": limit,
        "gcmsort": "timestamp",
        "gcmdir": "desc",
        "prop": "imageinfo",
        "iiprop": "url|timestamp|user",
        "format": "json",
        "formatversion": 2
    }
    r = requests.get(url, params=params, headers=HEADERS)
    r.raise_for_status()
    data = r.json()
    files = {}
    for page in data.get("query", {}).get("pages", []):
        title = page["title"]
        info  = page["imageinfo"][0]
        files[title] = {
            "title": title,
            "url": info["url"],
            "timestamp": info["timestamp"],
            "user": info["user"],
            "depicts": fetch_depicts(title)
        }
    return files

def add_commons_latest_layer(m, category="Stockholm_Archipelago_Trail", limit=50):
    fg = folium.FeatureGroup(name="📷 Latest Commons SAT uploads", show=True)
    files = fetch_commons_latest(category, limit)
    for f in files.values():
        latlon = None
        for qid in f["depicts"]:
            coords = get_coords_from_wikidata(qid)
            if coords:
                latlon = coords
                break

        popup_html = f"""
        <div style="min-width:220px;font-size:13px;">
          <b>{html.escape(f['title'])}</b><br>
          <img src="{f['url']}" width="200"><br>
          📤 {html.escape(f['user'])}<br>
          🕒 {f['timestamp']}<br>
          <a href="{f['url']}" target="_blank">Open on Commons</a>
        </div>
        """

        folium.Marker(
            latlon if latlon else MAP_CENTER,
            icon=folium.Icon(color="blue" if latlon else "gray", icon="camera", prefix="fa"),
            popup=folium.Popup(popup_html, max_width=250)
        ).add_to(fg)

    fg.add_to(m)

# ========================
# Wikidata recent edits
# ========================
def fetch_recent_wikidata_edits(days=1):
    cutoff = (datetime.now(timezone.utc) - timedelta(days=days)).strftime("%Y-%m-%dT%H:%M:%SZ")
    query = f"""
    SELECT ?item ?coord ?modified WHERE {{
      # ?item schema:dateModified ?modified ;
            wdt:P625 ?coord .
      FILTER (?modified > "{cutoff}"^^xsd:dateTime)
    }}
    LIMIT 200
    """
    r = requests.get("https://query.wikidata.org/sparql",
                     params={"query": query, "format": "json"},
                     headers=HEADERS, timeout=60)
    r.raise_for_status()
    data = r.json()
    edits = []
    for b in data["results"]["bindings"]:
        coord_val = b["coord"]["value"]
        # Ensure it's a WKT literal ("Point(" ...)
        if not coord_val.startswith("Point("):
            continue
        coord = coord_val.replace("Point(", "").replace(")", "")
        try:
            lon, lat = map(float, coord.split())
        except Exception:
            continue
        qid = b["item"]["value"].split("/")[-1]
        edits.append({
            "qid": qid,
            "lat": lat,
            "lon": lon,
            "modified": b["modified"]["value"]
        })
    return edits



def add_recent_edits_layer(m, days=1):
    edits = fetch_recent_wikidata_edits(days=days)
    fg = folium.FeatureGroup(name=f"🟢 Wikidata edits (last {days} days)", show=True)
    for e in edits:
        popup_html = f"""
        <div style="min-width:220px;font-size:13px;">
          <b>{html.escape(e['label'] or e['qid'])}</b><br>
          <i>{html.escape(e['desc'])}</i><br>
          🕒 {e['modified']}<br>
          <a href="https://www.wikidata.org/wiki/{e['qid']}" target="_blank">🔗 Wikidata</a> |
          <a href="https://www.wikidata.org/w/index.php?title={e['qid']}&action=history" target="_blank">📜 History</a>
        </div>
        """
        folium.CircleMarker(
            [e["lat"], e["lon"]],
            radius=6,
            color="green",
            fill=True,
            fill_opacity=0.7,
            popup=folium.Popup(popup_html, max_width=300)
        ).add_to(fg)
    fg.add_to(m)

# ========================
# About box
# ========================
def add_about_box(
    m,
    issue_number: int,
    map_name: str,
    created_date: str | None = None,
    repo: str = "salgo60/Stockholm_Archipelago_Trail",
    collapsed: bool = False,
    offset_px=(10, 54),
):
    if created_date is None:
        created_date = dt.now().strftime("%Y-%m-%d %H:%M")

    map_dom_id = m.get_name()
    box_id     = f"sat-about-{map_dom_id}"
    header_id  = f"{box_id}-hdr"
    issue_url  = f"https://github.com/{repo}/issues/{issue_number}"
    top, left  = offset_px
    collapsed_class = "sat-about-collapsed" if collapsed else ""

    links = [
        ("SAT Dashboard", "https://raw.githack.com/salgo60/Stockholm_Archipelago_Trail/main/notebook/output/SAT_ALL_IN_ONE_142_3_dashboard_latest.html"),
        ("Project repo issues", "https://github.com/salgo60/Stockholm_Archipelago_Trail/issues?q=is%3Aissue"),
        ("Trail on OSM (rel 19012437)", "https://www.openstreetmap.org/relation/19012437"),
        ("Trail on Wikicommons", "https://commons.wikimedia.org/wiki/Category:Stockholm_Archipelago_Trail"),
        ("Official page", "https://stockholmarchipelagotrail.com/"),
        ("Unofficial FB group", "https://www.facebook.com/groups/2875020699552247"),
        ("Visit Sweden", "https://traveltrade.visitsweden.com/plan/news-sweden/Stockholm-Archipelago-Trail/"),
    ]
    links_html = "".join(
        f'<div><a href="{html.escape(u)}" target="_blank" style="text-decoration:none;">🔗 {html.escape(t)}</a></div>'
        for t, u in links
    )

    tpl = Template("""<style>
  .sat-about {
    position: fixed; z-index: 10000;
    top: {{top}}px; left: {{left}}px;
    background: rgba(255,255,255,0.97);
    border: 2px solid #666; border-radius: 10px;
    box-shadow: 0 2px 6px rgba(0,0,0,0.25);
    font: 12px/1.35 -apple-system, system-ui, Segoe UI, Roboto, Helvetica, Arial, sans-serif;
    min-width: 240px; max-width: 320px; pointer-events: auto;
  }
  .sat-about-header { cursor: pointer; padding: 8px 10px; font-weight: 700;
    display: flex; align-items: center; gap: 6px; user-select: none;
    background: rgba(248,248,248,.9); border-bottom: 1px solid #e5e7eb; }
  .sat-about-body { padding: 8px 10px 10px 10px; }
  .sat-about-collapsed .sat-about-body { display: none; }
  .sat-chevron { margin-left: auto; transition: transform .15s ease-in-out; }
  .sat-about-collapsed .sat-chevron { transform: rotate(-90deg); }
  .sat-links { margin-top: 6px; padding-top: 6px; border-top: 1px solid #e5e7eb; }
</style>

<div id="{{box_id}}" class="sat-about {{collapsed_class}}">
  <div id="{{header_id}}" class="sat-about-header" title="Click to collapse/expand">
    <span>ℹ️ About</span><span class="sat-chevron">▸</span>
  </div>
  <div class="sat-about-body">
    <div style="font-weight:700;margin-bottom:4px;">Stockholm Archipelago Trail Map</div>
    <div>Issue: <a href="{{issue_url}}" target="_blank">#{{issue_number}}</a>&nbsp;&nbsp; Map: {{map_name}}</div>
    <div>Created: {{created_date}}</div>
    <div>Latest updates: saved as <i>_latest.html</i></div>
    <div class="sat-links">{{links_html}}</div>
  </div>
</div>
<script>(function(){var boxId="{{box_id}}",hdrId="{{header_id}}",
storageKey="satAboutCollapsed_{{map_dom_id}}_#{{issue_number}}";
function setCollapsed(b,c){if(!b)return;if(c)b.classList.add("sat-about-collapsed");
else b.classList.remove("sat-about-collapsed");
try{localStorage.setItem(storageKey,c?"1":"0");}catch(e){}}
function init(){var b=document.getElementById(boxId),h=document.getElementById(hdrId);
if(!b||!h)return;try{var s=localStorage.getItem(storageKey);
if(s==="1")setCollapsed(b,true);if(s==="0")setCollapsed(b,false);}catch(e){}
h.addEventListener("click",function(e){e.stopPropagation();
setCollapsed(b,!b.classList.contains("sat-about-collapsed"));});}
if(document.readyState==="loading"){document.addEventListener("DOMContentLoaded",init);}else{init();}})();</script>""")

    html_code = tpl.render(
        box_id=box_id, header_id=header_id,
        issue_number=issue_number, issue_url=issue_url,
        map_name=html.escape(map_name),
        created_date=created_date,
        links_html=links_html,
        collapsed_class=collapsed_class,
        map_dom_id=map_dom_id,
        top=top, left=left,
    )
    m.get_root().html.add_child(folium.Element(html_code))

# ========================
# Build combined map
# ========================
m = folium.Map(location=MAP_CENTER, zoom_start=MAP_ZOOM, tiles="OpenStreetMap")

add_commons_latest_layer(m, category="Stockholm_Archipelago_Trail", limit=100)
add_recent_edits_layer(m, days=1)
add_about_box(m, issue_number=221, map_name=OUTPUT_PREFIX)

folium.LayerControl(collapsed=False).add_to(m)

# --- Save outputs ---
os.makedirs("output", exist_ok=True)
ts = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
out_ts = os.path.join("output", f"{OUTPUT_PREFIX}_{ts}.html")
out_latest = os.path.join("output", f"{OUTPUT_PREFIX}_latest.html")

m.save(out_ts)
m.save(out_latest)

print("Klar:")
print("  ", out_ts)
print("  ", out_latest)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 278
#     275 m = folium.Map(location=MAP_CENTER, zoom_start=MAP_ZOOM, tiles="OpenStreetMap")
#     277 add_commons_latest_layer(m, category="Stockholm_Archipelago_Trail", limit=100)
# --> 278 add_recent_edits_layer(m, days=1)
#     279 add_about_box(m, issue_number=221, map_name=OUTPUT_PREFIX)
#     281 folium.LayerControl(collapsed=False).add_to(m)
#
# Cell In[7], line 163, in add_recent_edits_layer(m, days)
#     159 fg = folium.FeatureGroup(name=f"🟢 Wikidata edits (last {days} days)", show=True)
#     160 for e in edits:
#     161     popup_html = f"""
#     162     <div style="min-width:220px;font-size:13px;">
# --> 163       <b>{html.escape(e['label'] or e['qid'])}</b><br>
#     164       <i>{html.escape(e['desc'])}</i><br>
#     165       🕒 {e['modified']}<br>
#     166       <a href="https://www.wikidata.org/wiki/{e['qid']}" target="_blank">🔗 Wikidata</a> |
#     167       <a href="https://www.wikidata.org/w/index.php?title={e['qid']}&action=history" target="_blank">📜 History</a>
#     168     </div>
#     169     """
#     170     folium.CircleMarker(
#     171         [e["lat"], e["lon"]],
#     172         radius=6,
#    (...)
#     176         popup=folium.Popup(popup_html, max_width=300)
#     177     ).add_to(fg)
#     178 fg.add_to(m)
#
# KeyError: 'label'

# %%
end_time = time.time()
duration = end_time - start_time
print(f"Finished in {duration:.2f} seconds.")
